# %%
5 + 5
# Out:
# 10

# %% [markdown]
# take notes, this is text, lalalal
# \

# %% [markdown]
# ### AHHHHHHHH

# %%
19
# Out:
# 19

# %%
/ 12 6
# Out:
# (12, 6)

# %%
* 12 6
# Out:
#   File "<ipython-input-7-87fd873be967>", line 1
#     * 12 6
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## operators of inequality

# %% [markdown]
# ## variables

# %%
x = (4+5)*6

# %%
x
# Out:
# 54

# %% [markdown]
# # Valentine's Day Notes

# %%
# length

len('three')
# Out:
# 5

# %%
len('     ')
# Out:
# 5

# %%
#operator in

"pig" in "evaluates to string"
# Out:
# False

# %%
# strings have methods because they are objects
# almost everything in python is case sensitive

type('string')
# Out:
# str

# %%
message = 'Suppose there is a pigeon, suppose there is'

# %%
message.startswith('Sup')
# Out:
# True

# %%
message.lower()
# Out:
# 'suppose there is a pigeon, suppose there is'

# %%
message.lower().startswith('sup')
# Out:
# True

# %% [markdown]
# ### dot methods can be put onto any expression that evaluates to a string *
#
# if you . tab, will show list of possible methods (only if string variable is predeclared
#
# Useful methods:

# %%
'1235'.isdigit()
# Out:
# True

# %%
'hello there'.islower()
# Out:
# True

# %%
# returns index that the string starts at:

message.find('pig')
# Out:
# 19

# %%
'hello' == 'hello'
# Out:
# True

# %% [markdown]
# ### string transformations

# %%
'this is title case'.title()
# Out:
# 'This Is Title Case'

# %%
# how to tell if a spam email was written in python

"allison's favorite weird thing about python".title()
# Out:
# "Allison'S Favorite Weird Thing About Python"

# %%
# surrounding spaces, newline characters, tabs

"       this is  a test      ".strip()
# Out:
# 'this is  a test'

# %%
message.replace('pig', 'elephant')
# Out:
# 'Suppose there is a elephanteon, suppose there is'

# %% [markdown]
# to assign the copy of the string, create new variable (don't overwrite, can be source of bugs)

# %% [markdown]
# ## reading a text file into a string

# %%
text = open('./txt/frost.txt').read()

# %%
text
# Out:
# 'Two roads diverged in a yellow wood,\nAnd sorry I could not travel both\nAnd be one traveler, long I stood\nAnd looked down one as far as I could\nTo where it bent in the undergrowth;\n\nThen took the other, as just as fair,\nAnd having perhaps the better claim,\nBecause it was grassy and wanted wear;\nThough as for that the passing there\nHad worn them really about the same,\n\nAnd both that morning equally lay\nIn leaves no step had trodden black.\nOh, I kept the first for another day!\nYet knowing how way leads on to way,\nI doubted if I should ever come back.\n\nI shall be telling this with a sigh\nSomewhere ages and ages hence:\nTwo roads diverged in a wood, and I---\nI took the one less travelled by,\nAnd that has made all the difference.\n'

# %%
print(text)
# Out:
# Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim,
# Because it was grassy and wanted wear;
# Though as for that the passing there
# Had worn them really about the same,
#
# And both that morning equally lay
# In leaves no step had trodden black.
# Oh, I kept the first for another day!
# Yet knowing how way leads on to way,
# I doubted if I should ever come back.
#
# I shall be telling this with a sigh
# Somewhere ages and ages hence:
# Two roads diverged in a wood, and I---
# I took the one less travelled by,
# And that has made all the difference.

# %%
print(text.replace('I', "This Guy").replace('r', 'rrrrrrr'))
# Out:
# Two rrrrrrroads diverrrrrrrged in a yellow wood,
# And sorrrrrrrrrrrrrry This Guy could not trrrrrrravel both
# And be one trrrrrrravelerrrrrrr, long This Guy stood
# And looked down one as farrrrrrr as This Guy could
# To wherrrrrrre it bent in the underrrrrrrgrrrrrrrowth;
#
# Then took the otherrrrrrr, as just as fairrrrrrr,
# And having perrrrrrrhaps the betterrrrrrr claim,
# Because it was grrrrrrrassy and wanted wearrrrrrr;
# Though as forrrrrrr that the passing therrrrrrre
# Had worrrrrrrn them rrrrrrreally about the same,
#
# And both that morrrrrrrning equally lay
# This Guyn leaves no step had trrrrrrrodden black.
# Oh, This Guy kept the firrrrrrrst forrrrrrr anotherrrrrrr day!
# Yet knowing how way leads on to way,
# This Guy doubted if This Guy should everrrrrrr come back.
#
# This Guy shall be telling this with a sigh
# Somewherrrrrrre ages and ages hence:
# Two rrrrrrroads diverrrrrrrged in a wood, and This Guy---
# This Guy took the one less trrrrrrravelled by,
# And that has made all the differrrrrrrence.

# %% [markdown]
# eventually could make a list of the elements you want to replace and iterate in a loop inside of replace()

# %%
# a ? at the end gives you documentation

text.replace?

# %% [markdown]
# ### string indexing

# %%
message
# Out:
# 'Suppose there is a pigeon, suppose there is'

# %%
# square brackets (inside expression evaluates to a number)

message[4]
# Out:
# 'o'

# %%
type(message[4])
# Out:
# str

# %%
type('')
# Out:
# str

# %%
x = 3
message[x*2]
# Out:
# 'e'

# %%
'hello'[2]
# Out:
# 'l'

# %%
# -1 is the last character in the string
message[-1]
# Out:
# 's'

# %% [markdown]
# ### slices

# %%
# up to but not including

message[4:13]
# Out:
# 'ose there'

# %%
# assumes 0 index
message[:10]
# Out:
# 'Suppose th'

# %%
#assumes end index
message[10:]
# Out:
# 'ere is a pigeon, suppose there is'

# %%
# first 20 characters
message[:20]
# Out:
# 'Suppose there is a p'

# %%
# can do negative ranges

message[15:-5]
# Out:
# 's a pigeon, suppose the'

# %%
message[-5:-15]
# Out:
# ''

# %%
message[-10:]
# Out:
# 'e there is'

# %%
message[:-10]
# Out:
# 'Suppose there is a pigeon, suppos'

# %%
import random

# %%
random.randrange(100)
# Out:
# 95

# %%
text[:random.randrange(len(text))]
# Out:
# 'Two roads diverged in a yellow wood,\nAn'

# %%
#type of result of division is always floating point

len(text)
# Out:
# 733

# %%
len(text) *0.5
# Out:
# 366.5

# %%
int(len(text) * 0.5)
# Out:
# 366

# %% [markdown]
# # 2/21 Notes

# %% [markdown]
# statements end at EOL
# python only recommends plain text quotes
#
# """ in a row is special python syntax that lets you past multiple lines
#
# other escape codes/characters:
# /t is for a tab

# %% [markdown]
# ### lists

# %% [markdown]
# represents sequence of values

# %% [markdown]
# [ ____ for ___ in ____ if ___]

# %% [markdown]
# (expression) for (temp var) in (expr list) if (expression t/f)

# %% [markdown]
# # 2/28 Notes

# %% [markdown]
# ### if / else

# %%
words =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c77a99a3b1d5> in <module>
# ----> 1 if true:
#       2     executed
#
# NameError: name 'true' is not defined

# %%
# list comprehension

[item for item in text if item[0] == 'a']
# Out:
# ['a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a']

# %%
# for loop

for item in text:
    if item[0] == 'a':
        print(item)
    elif item[0] == 'b':
        print('bee!')
    else:
        print('not a')
# Out:
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# bee!
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# bee!
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# bee!
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a
# not a

# %%
# list comprehension as a for loop
a_words = []
for item in text:
    if item[0] == 'a':
        a_words.append(item)
        
a_words
# Out:
# ['a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a']

# %% [markdown]
# ### computational acrostic
#
# write an acrostic where each line is a word that begins with the letter from the seed phrase

# %%
import random

# %% [markdown]
# ## if you hold alt and drag, can change multiple text at once

# %%
words = text.split()
print(words)
# Out:
# ['Two', 'roads', 'diverged', 'in', 'a', 'yellow', 'wood,', 'And', 'sorry', 'I', 'could', 'not', 'travel', 'both', 'And', 'be', 'one', 'traveler,', 'long', 'I', 'stood', 'And', 'looked', 'down', 'one', 'as', 'far', 'as', 'I', 'could', 'To', 'where', 'it', 'bent', 'in', 'the', 'undergrowth;', 'Then', 'took', 'the', 'other,', 'as', 'just', 'as', 'fair,', 'And', 'having', 'perhaps', 'the', 'better', 'claim,', 'Because', 'it', 'was', 'grassy', 'and', 'wanted', 'wear;', 'Though', 'as', 'for', 'that', 'the', 'passing', 'there', 'Had', 'worn', 'them', 'really', 'about', 'the', 'same,', 'And', 'both', 'that', 'morning', 'equally', 'lay', 'In', 'leaves', 'no', 'step', 'had', 'trodden', 'black.', 'Oh,', 'I', 'kept', 'the', 'first', 'for', 'another', 'day!', 'Yet', 'knowing', 'how', 'way', 'leads', 'on', 'to', 'way,', 'I', 'doubted', 'if', 'I', 'should', 'ever', 'come', 'back.', 'I', 'shall', 'be', 'telling', 'this', 'with', 'a', 'sigh', 'Somewhere', 'ages', 'and', 'ages', 'hence:', 'Two', 'roads', 'diverged', 'in', 'a', 'wood,', 'and', 'I---', 'I', 'took', 'the', 'one', 'less', 'travelled', 'by,', 'And', 'that', 'has', 'made', 'all', 'the', 'difference.']

# %%
seed = 'robert'
for item in seed:
    matches = [word for word in words if word.startswith(item)]
    print(random.choice(matches))
# Out:
# really
# one
# back.
# ever
# really
# the

# %% [markdown]
# | letter | words-that-start-with-a |
# | ------ | ----------------------- |
# | a | a, an, apple |

# %% [markdown]
# ## dictionary

# %% [markdown]
# spreadsheet with two columns
# keys and values (words and definitions)

# %%
# only one value per key, but that one value can be a list
planets = {
    'Mercury' : 0.357, 
    'Venus' : 0.723, 
    'Earth' : 1.0, 
    'Mars' : 1.523
}

# %%
planets['Venus']
# Out:
# 0.723

# %%
planets['Jupiter'] = 5.2

# %%
planets
# Out:
# {'Mercury': 0.357, 'Venus': 0.723, 'Earth': 1.0, 'Mars': 1.523, 'Jupiter': 5.2}

# %% [markdown]
# ## dictionaries don't have any inherent interal ordering
#
# so you can't rely on an order

# %%
planets['Earth'] = 1.01

# %%
planets
# Out:
# {'Mercury': 0.357,
#  'Venus': 0.723,
#  'Earth': 1.01,
#  'Mars': 1.523,
#  'Jupiter': 5.2}

# %%
planets['Venus'] = 0.72

# %%
planets
# Out:
# {'Mercury': 0.357, 'Venus': 0.72, 'Earth': 1.01, 'Mars': 1.523, 'Jupiter': 5.2}

# %%
5.2 in planets
# Out:
# False

# %%
# only returns true if key
'Venus' in planets
# Out:
# True

# %%
5.2 in planets.values()
# Out:
# True

# %%
planet_moons = {
    'Mercury' : [],
    'Venus' : [],
    'Earth' : ["moon"],
    'Mars' : ["Phobos", "Deimos"]
}

# %%
planet_moons['Mars']
# Out:
# ['Phobos', 'Deimos']

# %%
len(planet_moons['Mars'])
# Out:
# 2

# %%
numbers = [1, 2, 3, 4, 5]

# %%
numbers.append(234)

# %%
numbers
# Out:
# [1, 2, 3, 4, 5, 234]

# %%
planet_moons['Venus'].append('Allison')

# %%
planet_moons
# Out:
# {'Mercury': [],
#  'Venus': ['Allison'],
#  'Earth': ['moon'],
#  'Mars': ['Phobos', 'Deimos']}

# %%
words = open('txt/frost.txt').read().split()
initials = {}
for item in words:
    first_let = item[0].lower()
    if first_let in initials:
        initials[first_let].append(item)
    else:
        initials[first_let] = []
        initials[first_let].append(item)

# %%
initials
# Out:
# {'t': ['Two',
#   'travel',
#   'traveler,',
#   'To',
#   'the',
#   'Then',
#   'took',
#   'the',
#   'the',
#   'Though',
#   'that',
#   'the',
#   'there',
#   'them',
#   'the',
#   'that',
#   'trodden',
#   'the',
#   'to',
#   'telling',
#   'this',
#   'Two',
#   'took',
#   'the',
#   'travelled',
#   'that',
#   'the'],
#  'r': ['roads', 'really', 'roads'],
#  'd': ['diverged', 'down', 'day!', 'doubted', 'diverged', 'difference.'],
#  'i': ['in',
#   'I',
#   'I',
#   'I',
#   'it',
#   'in',
#   'it',
#   'In',
#   'I',
#   'I',
#   'if',
#   'I',
#   'I',
#   'in',
#   'I---',
#   'I'],
#  'a': ['a',
#   'And',
#   'And',
#   'And',
#   'as',
#   'as',
#   'as',
#   'as',
#   'And',
#   'and',
#   'as',
#   'about',
#   'And',
#   'another',
#   'a',
#   'ages',
#   'and',
#   'ages',
#   'a',
#   'and',
#   'And',
#   'all'],
#  'y': ['yellow', 'Yet'],
#  'w': ['wood,',
#   'where',
#   'was',
#   'wanted',
#   'wear;',
#   'worn',
#   'way',
#   'way,',
#   'with',
#   'wood,'],
#  's': ['sorry',
#   'stood',
#   'same,',
#   'step',
#   'should',
#   'shall',
#   'sigh',
#   'Somewhere'],
#  'c': ['could', 'could', 'claim,', 'come'],
#  'n': ['not', 'no'],
#  'b': ['both',
#   'be',
#   'bent',
#   'better',
#   'Because',
#   'both',
#   'black.',
#   'back.',
#   'be',
#   'by,'],
#  'o': ['one', 'one', 'other,', 'Oh,', 'on', 'one'],
#  'l': ['long', 'looked', 'lay', 'leaves', 'leads', 'less'],
#  'f': ['far', 'fair,', 'for', 'first', 'for'],
#  'u': ['undergrowth;'],
#  'j': ['just'],
#  'h': ['having', 'Had', 'had', 'how', 'hence:', 'has'],
#  'p': ['perhaps', 'passing'],
#  'g': ['grassy'],
#  'm': ['morning', 'made'],
#  'e': ['equally', 'ever'],
#  'k': ['kept', 'knowing']}

# %%
for key, val in initials.items():
    print(key, len(val))
# Out:
# t 27
# r 3
# d 6
# i 16
# a 22
# y 2
# w 10
# s 8
# c 4
# n 2
# b 10
# o 6
# l 6
# f 5
# u 1
# j 1
# h 6
# p 2
# g 1
# m 2
# e 2
# k 2

# %%
seed = 'girlfriend'
for ch in seed:
    print(random.choice(initials[ch]))
# Out:
# grassy
# I
# really
# leaves
# far
# roads
# I
# equally
# not
# day!

# %%
print('\n'.join([random.choice(initials[ch]) for ch in seed]))
# Out:
# grassy
# I
# roads
# lay
# far
# roads
# in
# ever
# no
# diverged

# %%
initials.get('c')
# Out:
# ['could', 'could', 'claim,', 'come']

# %%
initials['c']
# Out:
# ['could', 'could', 'claim,', 'come']

# %%
initials.get('z', '???')
# Out:
# '???'

# %%
seed = 'pizza'
for ch in seed:
    print(random.choice(initials.get(ch, '?')).capitalize())
# Out:
# Passing
# I
# ?
# ?
# Ages

# %% [markdown]
# # 3/7 Notes

# %% [markdown]
# ### counting things

# %%
words = open("./txt/genesis.txt").read().split();

# %%
words[:10]
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth.']

# %% [markdown]
# in python you can't do ++

# %%
#word counter
from collections import Counter

# %%
count = Counter(words)

# %%
count
# Out:
# Counter({'In': 1,
#          'the': 108,
#          'beginning': 1,
#          'God': 32,
#          'created': 5,
#          'heaven': 5,
#          'and': 63,
#          'earth.': 4,
#          'And': 33,
#          'earth': 8,
#          'was': 17,
#          'without': 1,
#          'form,': 1,
#          'void;': 1,
#          'darkness': 2,
#          'upon': 10,
#          'face': 3,
#          'of': 20,
#          'deep.': 1,
#          'Spirit': 1,
#          'moved': 1,
#          'waters.': 2,
#          'said,': 9,
#          'Let': 8,
#          'there': 5,
#          'be': 7,
#          'light:': 1,
#          'light.': 1,
#          'saw': 7,
#          'light,': 1,
#          'that': 14,
#          'it': 15,
#          'good:': 1,
#          'divided': 2,
#          'light': 7,
#          'from': 5,
#          'darkness.': 1,
#          'called': 5,
#          'Day,': 1,
#          'he': 6,
#          'Night.': 1,
#          'evening': 6,
#          'morning': 6,
#          'were': 8,
#          'first': 1,
#          'day.': 6,
#          'a': 2,
#          'firmament': 7,
#          'in': 13,
#          'midst': 1,
#          'waters,': 1,
#          'let': 6,
#          'divide': 3,
#          'waters': 8,
#          'made': 4,
#          'firmament,': 1,
#          'which': 5,
#          'under': 2,
#          'above': 2,
#          'firmament:': 1,
#          'so.': 6,
#          'Heaven.': 1,
#          'second': 1,
#          'gathered': 1,
#          'together': 2,
#          'unto': 2,
#          'one': 1,
#          'place,': 1,
#          'dry': 2,
#          'land': 2,
#          'appear:': 1,
#          'Earth;': 1,
#          'gathering': 1,
#          'Seas:': 1,
#          'good.': 6,
#          'bring': 3,
#          'forth': 5,
#          'grass,': 2,
#          'herb': 4,
#          'yielding': 5,
#          'seed,': 2,
#          'fruit': 3,
#          'tree': 3,
#          'after': 11,
#          'his': 9,
#          'kind,': 6,
#          'whose': 2,
#          'seed': 3,
#          'is': 4,
#          'itself,': 2,
#          'earth:': 2,
#          'brought': 2,
#          'fruit,': 1,
#          'kind:': 4,
#          'third': 1,
#          'lights': 2,
#          'to': 11,
#          'day': 2,
#          'night;': 1,
#          'them': 4,
#          'for': 6,
#          'signs,': 1,
#          'seasons,': 1,
#          'days,': 1,
#          'years:': 1,
#          'give': 2,
#          'two': 1,
#          'great': 2,
#          'lights;': 1,
#          'greater': 1,
#          'rule': 3,
#          'day,': 1,
#          'lesser': 1,
#          'night:': 1,
#          'stars': 1,
#          'also.': 1,
#          'set': 1,
#          'earth,': 6,
#          'over': 10,
#          'night,': 1,
#          'darkness:': 1,
#          'fourth': 1,
#          'abundantly': 1,
#          'moving': 1,
#          'creature': 3,
#          'hath': 1,
#          'life,': 2,
#          'fowl': 6,
#          'may': 1,
#          'fly': 1,
#          'open': 1,
#          'heaven.': 1,
#          'whales,': 1,
#          'every': 12,
#          'living': 3,
#          'moveth,': 1,
#          'abundantly,': 1,
#          'their': 2,
#          'winged': 1,
#          'blessed': 2,
#          'them,': 3,
#          'saying,': 1,
#          'Be': 2,
#          'fruitful,': 2,
#          'multiply,': 2,
#          'fill': 1,
#          'seas,': 1,
#          'multiply': 1,
#          'fifth': 1,
#          'cattle,': 2,
#          'creeping': 2,
#          'thing,': 1,
#          'beast': 3,
#          'cattle': 1,
#          'thing': 5,
#          'creepeth': 3,
#          'us': 1,
#          'make': 1,
#          'man': 2,
#          'our': 2,
#          'image,': 2,
#          'likeness:': 1,
#          'have': 4,
#          'dominion': 2,
#          'fish': 2,
#          'sea,': 2,
#          'air,': 3,
#          'all': 2,
#          'So': 1,
#          'own': 1,
#          'image': 1,
#          'him;': 1,
#          'male': 1,
#          'female': 1,
#          'them.': 1,
#          'said': 1,
#          'replenish': 1,
#          'subdue': 1,
#          'it:': 1,
#          'moveth': 1,
#          'Behold,': 1,
#          'I': 2,
#          'given': 2,
#          'you': 2,
#          'bearing': 1,
#          'tree,': 1,
#          'seed;': 1,
#          'shall': 1,
#          'meat.': 1,
#          'wherein': 1,
#          'green': 1,
#          'meat:': 1,
#          'had': 1,
#          'made,': 1,
#          'and,': 1,
#          'behold,': 1,
#          'very': 1,
#          'sixth': 1})

# %%
count['God']
# Out:
# 32

# %%
count.most_common()
# Out:
# [('the', 108),
#  ('and', 63),
#  ('And', 33),
#  ('God', 32),
#  ('of', 20),
#  ('was', 17),
#  ('it', 15),
#  ('that', 14),
#  ('in', 13),
#  ('every', 12),
#  ('after', 11),
#  ('to', 11),
#  ('upon', 10),
#  ('over', 10),
#  ('said,', 9),
#  ('his', 9),
#  ('earth', 8),
#  ('Let', 8),
#  ('were', 8),
#  ('waters', 8),
#  ('be', 7),
#  ('saw', 7),
#  ('light', 7),
#  ('firmament', 7),
#  ('he', 6),
#  ('evening', 6),
#  ('morning', 6),
#  ('day.', 6),
#  ('let', 6),
#  ('so.', 6),
#  ('good.', 6),
#  ('kind,', 6),
#  ('for', 6),
#  ('earth,', 6),
#  ('fowl', 6),
#  ('created', 5),
#  ('heaven', 5),
#  ('there', 5),
#  ('from', 5),
#  ('called', 5),
#  ('which', 5),
#  ('forth', 5),
#  ('yielding', 5),
#  ('thing', 5),
#  ('earth.', 4),
#  ('made', 4),
#  ('herb', 4),
#  ('is', 4),
#  ('kind:', 4),
#  ('them', 4),
#  ('have', 4),
#  ('face', 3),
#  ('divide', 3),
#  ('bring', 3),
#  ('fruit', 3),
#  ('tree', 3),
#  ('seed', 3),
#  ('rule', 3),
#  ('creature', 3),
#  ('living', 3),
#  ('them,', 3),
#  ('beast', 3),
#  ('creepeth', 3),
#  ('air,', 3),
#  ('darkness', 2),
#  ('waters.', 2),
#  ('divided', 2),
#  ('a', 2),
#  ('under', 2),
#  ('above', 2),
#  ('together', 2),
#  ('unto', 2),
#  ('dry', 2),
#  ('land', 2),
#  ('grass,', 2),
#  ('seed,', 2),
#  ('whose', 2),
#  ('itself,', 2),
#  ('earth:', 2),
#  ('brought', 2),
#  ('lights', 2),
#  ('day', 2),
#  ('give', 2),
#  ('great', 2),
#  ('life,', 2),
#  ('their', 2),
#  ('blessed', 2),
#  ('Be', 2),
#  ('fruitful,', 2),
#  ('multiply,', 2),
#  ('cattle,', 2),
#  ('creeping', 2),
#  ('man', 2),
#  ('our', 2),
#  ('image,', 2),
#  ('dominion', 2),
#  ('fish', 2),
#  ('sea,', 2),
#  ('all', 2),
#  ('I', 2),
#  ('given', 2),
#  ('you', 2),
#  ('In', 1),
#  ('beginning', 1),
#  ('without', 1),
#  ('form,', 1),
#  ('void;', 1),
#  ('deep.', 1),
#  ('Spirit', 1),
#  ('moved', 1),
#  ('light:', 1),
#  ('light.', 1),
#  ('light,', 1),
#  ('good:', 1),
#  ('darkness.', 1),
#  ('Day,', 1),
#  ('Night.', 1),
#  ('first', 1),
#  ('midst', 1),
#  ('waters,', 1),
#  ('firmament,', 1),
#  ('firmament:', 1),
#  ('Heaven.', 1),
#  ('second', 1),
#  ('gathered', 1),
#  ('one', 1),
#  ('place,', 1),
#  ('appear:', 1),
#  ('Earth;', 1),
#  ('gathering', 1),
#  ('Seas:', 1),
#  ('fruit,', 1),
#  ('third', 1),
#  ('night;', 1),
#  ('signs,', 1),
#  ('seasons,', 1),
#  ('days,', 1),
#  ('years:', 1),
#  ('two', 1),
#  ('lights;', 1),
#  ('greater', 1),
#  ('day,', 1),
#  ('lesser', 1),
#  ('night:', 1),
#  ('stars', 1),
#  ('also.', 1),
#  ('set', 1),
#  ('night,', 1),
#  ('darkness:', 1),
#  ('fourth', 1),
#  ('abundantly', 1),
#  ('moving', 1),
#  ('hath', 1),
#  ('may', 1),
#  ('fly', 1),
#  ('open', 1),
#  ('heaven.', 1),
#  ('whales,', 1),
#  ('moveth,', 1),
#  ('abundantly,', 1),
#  ('winged', 1),
#  ('saying,', 1),
#  ('fill', 1),
#  ('seas,', 1),
#  ('multiply', 1),
#  ('fifth', 1),
#  ('thing,', 1),
#  ('cattle', 1),
#  ('us', 1),
#  ('make', 1),
#  ('likeness:', 1),
#  ('So', 1),
#  ('own', 1),
#  ('image', 1),
#  ('him;', 1),
#  ('male', 1),
#  ('female', 1),
#  ('them.', 1),
#  ('said', 1),
#  ('replenish', 1),
#  ('subdue', 1),
#  ('it:', 1),
#  ('moveth', 1),
#  ('Behold,', 1),
#  ('bearing', 1),
#  ('tree,', 1),
#  ('seed;', 1),
#  ('shall', 1),
#  ('meat.', 1),
#  ('wherein', 1),
#  ('green', 1),
#  ('meat:', 1),
#  ('had', 1),
#  ('made,', 1),
#  ('and,', 1),
#  ('behold,', 1),
#  ('very', 1),
#  ('sixth', 1)]

# %% [markdown]
# tuples

# %%
count.most_common(1)[0][0]
# Out:
# 'the'

# %%
letter_count = Counter(open("./txt/genesis.txt").read())

# %%
letter_count.most_common()
# Out:
# [(' ', 797),
#  ('e', 450),
#  ('t', 339),
#  ('a', 267),
#  ('h', 255),
#  ('n', 233),
#  ('d', 232),
#  ('i', 195),
#  ('r', 186),
#  ('o', 167),
#  ('s', 128),
#  ('f', 87),
#  ('l', 86),
#  ('g', 82),
#  (',', 68),
#  ('m', 65),
#  ('w', 62),
#  ('v', 59),
#  ('u', 44),
#  ('y', 42),
#  ('.', 33),
#  ('A', 33),
#  ('G', 32),
#  ('c', 31),
#  ('\n', 31),
#  ('b', 29),
#  ('p', 25),
#  (':', 17),
#  ('k', 16),
#  ('L', 8),
#  (';', 6),
#  ('I', 3),
#  ('S', 3),
#  ('B', 3),
#  ('D', 1),
#  ('N', 1),
#  ('H', 1),
#  ('E', 1),
#  ('x', 1)]

# %% [markdown]
# ## tracery

# %%
#allison wrote python port, this is how to install
#exclamation points = unix commands on command line
# !pip install tracery
# Out:
# Requirement already satisfied: tracery in /home/dangalf/anaconda3/lib/python3.7/site-packages (0.1.1)

# %%
import tracery
from tracery.modifiers import base_english

# %%
rules = {
    "origin": "#greeting.capitalize#, #noun.a#! I'm #profession.a#",
    "noun": ["galaxy", "world", "solar system", "dimensional plane", "evil being"],
    "greeting": ["Howdy", "Hello", "hihihihi"],
    "profession": 
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"))
# Out:
# Hello, a dimensional plane!

# %% [markdown]
# keep things general, you can modify later

# %%
base_english
# Out:
# {'replace': <function tracery.modifiers.replace(text, *params)>,
#  'capitalizeAll': <function tracery.modifiers.capitalizeAll(text, *params)>,
#  'capitalize': <function tracery.modifiers.capitalize_(text, *params)>,
#  'a': <function tracery.modifiers.a(text, *params)>,
#  'firstS': <function tracery.modifiers.firstS(text, *params)>,
#  's': <function tracery.modifiers.s(text, *params)>,
#  'ed': <function tracery.modifiers.ed(text, *params)>,
#  'uppercase': <function tracery.modifiers.uppercase(text, *params)>,
#  'lowercase': <function tracery.modifiers.lowercase(text, *params)>}

# %% [markdown]
# ed = verb in past tense
#
# can have multiple grammar strcutures as elements in the orgin list

# %%
import pronouncing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-cef61b1e601c> in <module>
# ----> 1 import pronouncing
#
# ModuleNotFoundError: No module named 'pronouncing'

# %% [markdown]
# tracery variables

# %% [markdown]
# ## a picture of a kitten
#
# ![a picture of a kitten]('https://placekitten.com/400/400')

# %% [markdown]
# # spacy 3/15

# %% [markdown]
# ### terms of language
#
# word-game-workshop.decontextualize.com/language-vocab/
#
# ### layers of analysis
#
# - orthography (writing system / spelling)
# - lexicon (list of words / vocab)
# - phonology (system of sounds)
# - morphology (system of affixes)
# - syntax (rules for ordering words SVO vs SOV vs VSO, etc)
# - semantics (meaning)
# - discourse (higher-level organization)
#
#
# CMU pronoucing database

# %% [markdown]
# # 3/28
#
# ## Predictive Language Models
#
# ### Markov Chain Text Generation

# %% [markdown]
# ### tuples
#
# a weird kind of list

# %%
x = [1, 2, 3, 4]

# %%
type (x)
# Out:
# list

# %%
x.append(10)

# %%
x
# Out:
# [1, 2, 3, 4, 10]

# %%
y = (1, 2, 3, 4, 5)

# %%
type(y)
# Out:
# tuple

# %%
y[3]
# Out:
# 4

# %%
#  you can't modify a tuple
y.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-4a943d704049> in <module>
#       1 #  you can't modify a tuple
# ----> 2 y.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#but are less computationally intensive
#because lists have proactively allocated memory

# %%
hello = {}

# %%
hello['x'] = 10

# %%
hello[x] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b4359d3c7391> in <module>
# ----> 1 hello[x] = 20
#
# TypeError: unhashable type: 'list'

# %%
#but! you can use a tuple as a dict key

hello[y] = 'tlele'

# %%
hello
# Out:
# {'x': 10, (1, 2, 3, 4, 5): 'tlele'}

# %%
#maybe to check sequences, like a phrase

# %% [markdown]
# ### n-grams

# %%
text = open('txt/genesis.txt').read().split()

# %%
from collections import Counter

# %%
Counter(text).most_common(20)
# Out:
# [('the', 108),
#  ('and', 63),
#  ('And', 33),
#  ('God', 32),
#  ('of', 20),
#  ('was', 17),
#  ('it', 15),
#  ('that', 14),
#  ('in', 13),
#  ('every', 12),
#  ('after', 11),
#  ('to', 11),
#  ('upon', 10),
#  ('over', 10),
#  ('said,', 9),
#  ('his', 9),
#  ('earth', 8),
#  ('Let', 8),
#  ('were', 8),
#  ('waters', 8)]

# %% [markdown]
# "unigram" text analysis

# %%
#instead counting pairs of words
# can change between tuple and list
pairs = []
for i in range(len(text)-1):
    pairs.append(tuple(text[i:i+2]))

# %%
pairs
# Out:
# [['In', 'the'],
#  ['the', 'beginning'],
#  ['beginning', 'God'],
#  ['God', 'created'],
#  ['created', 'the'],
#  ['the', 'heaven'],
#  ['heaven', 'and'],
#  ['and', 'the'],
#  ['the', 'earth.'],
#  ['earth.', 'And'],
#  ['And', 'the'],
#  ['the', 'earth'],
#  ['earth', 'was'],
#  ['was', 'without'],
#  ['without', 'form,'],
#  ['form,', 'and'],
#  ['and', 'void;'],
#  ['void;', 'and'],
#  ['and', 'darkness'],
#  ['darkness', 'was'],
#  ['was', 'upon'],
#  ['upon', 'the'],
#  ['the', 'face'],
#  ['face', 'of'],
#  ['of', 'the'],
#  ['the', 'deep.'],
#  ['deep.', 'And'],
#  ['And', 'the'],
#  ['the', 'Spirit'],
#  ['Spirit', 'of'],
#  ['of', 'God'],
#  ['God', 'moved'],
#  ['moved', 'upon'],
#  ['upon', 'the'],
#  ['the', 'face'],
#  ['face', 'of'],
#  ['of', 'the'],
#  ['the', 'waters.'],
#  ['waters.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Let'],
#  ['Let', 'there'],
#  ['there', 'be'],
#  ['be', 'light:'],
#  ['light:', 'and'],
#  ['and', 'there'],
#  ['there', 'was'],
#  ['was', 'light.'],
#  ['light.', 'And'],
#  ['And', 'God'],
#  ['God', 'saw'],
#  ['saw', 'the'],
#  ['the', 'light,'],
#  ['light,', 'that'],
#  ['that', 'it'],
#  ['it', 'was'],
#  ['was', 'good:'],
#  ['good:', 'and'],
#  ['and', 'God'],
#  ['God', 'divided'],
#  ['divided', 'the'],
#  ['the', 'light'],
#  ['light', 'from'],
#  ['from', 'the'],
#  ['the', 'darkness.'],
#  ['darkness.', 'And'],
#  ['And', 'God'],
#  ['God', 'called'],
#  ['called', 'the'],
#  ['the', 'light'],
#  ['light', 'Day,'],
#  ['Day,', 'and'],
#  ['and', 'the'],
#  ['the', 'darkness'],
#  ['darkness', 'he'],
#  ['he', 'called'],
#  ['called', 'Night.'],
#  ['Night.', 'And'],
#  ['And', 'the'],
#  ['the', 'evening'],
#  ['evening', 'and'],
#  ['and', 'the'],
#  ['the', 'morning'],
#  ['morning', 'were'],
#  ['were', 'the'],
#  ['the', 'first'],
#  ['first', 'day.'],
#  ['day.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Let'],
#  ['Let', 'there'],
#  ['there', 'be'],
#  ['be', 'a'],
#  ['a', 'firmament'],
#  ['firmament', 'in'],
#  ['in', 'the'],
#  ['the', 'midst'],
#  ['midst', 'of'],
#  ['of', 'the'],
#  ['the', 'waters,'],
#  ['waters,', 'and'],
#  ['and', 'let'],
#  ['let', 'it'],
#  ['it', 'divide'],
#  ['divide', 'the'],
#  ['the', 'waters'],
#  ['waters', 'from'],
#  ['from', 'the'],
#  ['the', 'waters.'],
#  ['waters.', 'And'],
#  ['And', 'God'],
#  ['God', 'made'],
#  ['made', 'the'],
#  ['the', 'firmament,'],
#  ['firmament,', 'and'],
#  ['and', 'divided'],
#  ['divided', 'the'],
#  ['the', 'waters'],
#  ['waters', 'which'],
#  ['which', 'were'],
#  ['were', 'under'],
#  ['under', 'the'],
#  ['the', 'firmament'],
#  ['firmament', 'from'],
#  ['from', 'the'],
#  ['the', 'waters'],
#  ['waters', 'which'],
#  ['which', 'were'],
#  ['were', 'above'],
#  ['above', 'the'],
#  ['the', 'firmament:'],
#  ['firmament:', 'and'],
#  ['and', 'it'],
#  ['it', 'was'],
#  ['was', 'so.'],
#  ['so.', 'And'],
#  ['And', 'God'],
#  ['God', 'called'],
#  ['called', 'the'],
#  ['the', 'firmament'],
#  ['firmament', 'Heaven.'],
#  ['Heaven.', 'And'],
#  ['And', 'the'],
#  ['the', 'evening'],
#  ['evening', 'and'],
#  ['and', 'the'],
#  ['the', 'morning'],
#  ['morning', 'were'],
#  ['were', 'the'],
#  ['the', 'second'],
#  ['second', 'day.'],
#  ['day.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Let'],
#  ['Let', 'the'],
#  ['the', 'waters'],
#  ['waters', 'under'],
#  ['under', 'the'],
#  ['the', 'heaven'],
#  ['heaven', 'be'],
#  ['be', 'gathered'],
#  ['gathered', 'together'],
#  ['together', 'unto'],
#  ['unto', 'one'],
#  ['one', 'place,'],
#  ['place,', 'and'],
#  ['and', 'let'],
#  ['let', 'the'],
#  ['the', 'dry'],
#  ['dry', 'land'],
#  ['land', 'appear:'],
#  ['appear:', 'and'],
#  ['and', 'it'],
#  ['it', 'was'],
#  ['was', 'so.'],
#  ['so.', 'And'],
#  ['And', 'God'],
#  ['God', 'called'],
#  ['called', 'the'],
#  ['the', 'dry'],
#  ['dry', 'land'],
#  ['land', 'Earth;'],
#  ['Earth;', 'and'],
#  ['and', 'the'],
#  ['the', 'gathering'],
#  ['gathering', 'together'],
#  ['together', 'of'],
#  ['of', 'the'],
#  ['the', 'waters'],
#  ['waters', 'called'],
#  ['called', 'he'],
#  ['he', 'Seas:'],
#  ['Seas:', 'and'],
#  ['and', 'God'],
#  ['God', 'saw'],
#  ['saw', 'that'],
#  ['that', 'it'],
#  ['it', 'was'],
#  ['was', 'good.'],
#  ['good.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Let'],
#  ['Let', 'the'],
#  ['the', 'earth'],
#  ['earth', 'bring'],
#  ['bring', 'forth'],
#  ['forth', 'grass,'],
#  ['grass,', 'the'],
#  ['the', 'herb'],
#  ['herb', 'yielding'],
#  ['yielding', 'seed,'],
#  ['seed,', 'and'],
#  ['and', 'the'],
#  ['the', 'fruit'],
#  ['fruit', 'tree'],
#  ['tree', 'yielding'],
#  ['yielding', 'fruit'],
#  ['fruit', 'after'],
#  ['after', 'his'],
#  ['his', 'kind,'],
#  ['kind,', 'whose'],
#  ['whose', 'seed'],
#  ['seed', 'is'],
#  ['is', 'in'],
#  ['in', 'itself,'],
#  ['itself,', 'upon'],
#  ['upon', 'the'],
#  ['the', 'earth:'],
#  ['earth:', 'and'],
#  ['and', 'it'],
#  ['it', 'was'],
#  ['was', 'so.'],
#  ['so.', 'And'],
#  ['And', 'the'],
#  ['the', 'earth'],
#  ['earth', 'brought'],
#  ['brought', 'forth'],
#  ['forth', 'grass,'],
#  ['grass,', 'and'],
#  ['and', 'herb'],
#  ['herb', 'yielding'],
#  ['yielding', 'seed'],
#  ['seed', 'after'],
#  ['after', 'his'],
#  ['his', 'kind,'],
#  ['kind,', 'and'],
#  ['and', 'the'],
#  ['the', 'tree'],
#  ['tree', 'yielding'],
#  ['yielding', 'fruit,'],
#  ['fruit,', 'whose'],
#  ['whose', 'seed'],
#  ['seed', 'was'],
#  ['was', 'in'],
#  ['in', 'itself,'],
#  ['itself,', 'after'],
#  ['after', 'his'],
#  ['his', 'kind:'],
#  ['kind:', 'and'],
#  ['and', 'God'],
#  ['God', 'saw'],
#  ['saw', 'that'],
#  ['that', 'it'],
#  ['it', 'was'],
#  ['was', 'good.'],
#  ['good.', 'And'],
#  ['And', 'the'],
#  ['the', 'evening'],
#  ['evening', 'and'],
#  ['and', 'the'],
#  ['the', 'morning'],
#  ['morning', 'were'],
#  ['were', 'the'],
#  ['the', 'third'],
#  ['third', 'day.'],
#  ['day.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Let'],
#  ['Let', 'there'],
#  ['there', 'be'],
#  ['be', 'lights'],
#  ['lights', 'in'],
#  ['in', 'the'],
#  ['the', 'firmament'],
#  ['firmament', 'of'],
#  ['of', 'the'],
#  ['the', 'heaven'],
#  ['heaven', 'to'],
#  ['to', 'divide'],
#  ['divide', 'the'],
#  ['the', 'day'],
#  ['day', 'from'],
#  ['from', 'the'],
#  ['the', 'night;'],
#  ['night;', 'and'],
#  ['and', 'let'],
#  ['let', 'them'],
#  ['them', 'be'],
#  ['be', 'for'],
#  ['for', 'signs,'],
#  ['signs,', 'and'],
#  ['and', 'for'],
#  ['for', 'seasons,'],
#  ['seasons,', 'and'],
#  ['and', 'for'],
#  ['for', 'days,'],
#  ['days,', 'and'],
#  ['and', 'years:'],
#  ['years:', 'And'],
#  ['And', 'let'],
#  ['let', 'them'],
#  ['them', 'be'],
#  ['be', 'for'],
#  ['for', 'lights'],
#  ['lights', 'in'],
#  ['in', 'the'],
#  ['the', 'firmament'],
#  ['firmament', 'of'],
#  ['of', 'the'],
#  ['the', 'heaven'],
#  ['heaven', 'to'],
#  ['to', 'give'],
#  ['give', 'light'],
#  ['light', 'upon'],
#  ['upon', 'the'],
#  ['the', 'earth:'],
#  ['earth:', 'and'],
#  ['and', 'it'],
#  ['it', 'was'],
#  ['was', 'so.'],
#  ['so.', 'And'],
#  ['And', 'God'],
#  ['God', 'made'],
#  ['made', 'two'],
#  ['two', 'great'],
#  ['great', 'lights;'],
#  ['lights;', 'the'],
#  ['the', 'greater'],
#  ['greater', 'light'],
#  ['light', 'to'],
#  ['to', 'rule'],
#  ['rule', 'the'],
#  ['the', 'day,'],
#  ['day,', 'and'],
#  ['and', 'the'],
#  ['the', 'lesser'],
#  ['lesser', 'light'],
#  ['light', 'to'],
#  ['to', 'rule'],
#  ['rule', 'the'],
#  ['the', 'night:'],
#  ['night:', 'he'],
#  ['he', 'made'],
#  ['made', 'the'],
#  ['the', 'stars'],
#  ['stars', 'also.'],
#  ['also.', 'And'],
#  ['And', 'God'],
#  ['God', 'set'],
#  ['set', 'them'],
#  ['them', 'in'],
#  ['in', 'the'],
#  ['the', 'firmament'],
#  ['firmament', 'of'],
#  ['of', 'the'],
#  ['the', 'heaven'],
#  ['heaven', 'to'],
#  ['to', 'give'],
#  ['give', 'light'],
#  ['light', 'upon'],
#  ['upon', 'the'],
#  ['the', 'earth,'],
#  ['earth,', 'And'],
#  ['And', 'to'],
#  ['to', 'rule'],
#  ['rule', 'over'],
#  ['over', 'the'],
#  ['the', 'day'],
#  ['day', 'and'],
#  ['and', 'over'],
#  ['over', 'the'],
#  ['the', 'night,'],
#  ['night,', 'and'],
#  ['and', 'to'],
#  ['to', 'divide'],
#  ['divide', 'the'],
#  ['the', 'light'],
#  ['light', 'from'],
#  ['from', 'the'],
#  ['the', 'darkness:'],
#  ['darkness:', 'and'],
#  ['and', 'God'],
#  ['God', 'saw'],
#  ['saw', 'that'],
#  ['that', 'it'],
#  ['it', 'was'],
#  ['was', 'good.'],
#  ['good.', 'And'],
#  ['And', 'the'],
#  ['the', 'evening'],
#  ['evening', 'and'],
#  ['and', 'the'],
#  ['the', 'morning'],
#  ['morning', 'were'],
#  ['were', 'the'],
#  ['the', 'fourth'],
#  ['fourth', 'day.'],
#  ['day.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Let'],
#  ['Let', 'the'],
#  ['the', 'waters'],
#  ['waters', 'bring'],
#  ['bring', 'forth'],
#  ['forth', 'abundantly'],
#  ['abundantly', 'the'],
#  ['the', 'moving'],
#  ['moving', 'creature'],
#  ['creature', 'that'],
#  ['that', 'hath'],
#  ['hath', 'life,'],
#  ['life,', 'and'],
#  ['and', 'fowl'],
#  ['fowl', 'that'],
#  ['that', 'may'],
#  ['may', 'fly'],
#  ['fly', 'above'],
#  ['above', 'the'],
#  ['the', 'earth'],
#  ['earth', 'in'],
#  ['in', 'the'],
#  ['the', 'open'],
#  ['open', 'firmament'],
#  ['firmament', 'of'],
#  ['of', 'heaven.'],
#  ['heaven.', 'And'],
#  ['And', 'God'],
#  ['God', 'created'],
#  ['created', 'great'],
#  ['great', 'whales,'],
#  ['whales,', 'and'],
#  ['and', 'every'],
#  ['every', 'living'],
#  ['living', 'creature'],
#  ['creature', 'that'],
#  ['that', 'moveth,'],
#  ['moveth,', 'which'],
#  ['which', 'the'],
#  ['the', 'waters'],
#  ['waters', 'brought'],
#  ['brought', 'forth'],
#  ['forth', 'abundantly,'],
#  ['abundantly,', 'after'],
#  ['after', 'their'],
#  ['their', 'kind,'],
#  ['kind,', 'and'],
#  ['and', 'every'],
#  ['every', 'winged'],
#  ['winged', 'fowl'],
#  ['fowl', 'after'],
#  ['after', 'his'],
#  ['his', 'kind:'],
#  ['kind:', 'and'],
#  ['and', 'God'],
#  ['God', 'saw'],
#  ['saw', 'that'],
#  ['that', 'it'],
#  ['it', 'was'],
#  ['was', 'good.'],
#  ['good.', 'And'],
#  ['And', 'God'],
#  ['God', 'blessed'],
#  ['blessed', 'them,'],
#  ['them,', 'saying,'],
#  ['saying,', 'Be'],
#  ['Be', 'fruitful,'],
#  ['fruitful,', 'and'],
#  ['and', 'multiply,'],
#  ['multiply,', 'and'],
#  ['and', 'fill'],
#  ['fill', 'the'],
#  ['the', 'waters'],
#  ['waters', 'in'],
#  ['in', 'the'],
#  ['the', 'seas,'],
#  ['seas,', 'and'],
#  ['and', 'let'],
#  ['let', 'fowl'],
#  ['fowl', 'multiply'],
#  ['multiply', 'in'],
#  ['in', 'the'],
#  ['the', 'earth.'],
#  ['earth.', 'And'],
#  ['And', 'the'],
#  ['the', 'evening'],
#  ['evening', 'and'],
#  ['and', 'the'],
#  ['the', 'morning'],
#  ['morning', 'were'],
#  ['were', 'the'],
#  ['the', 'fifth'],
#  ['fifth', 'day.'],
#  ['day.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Let'],
#  ['Let', 'the'],
#  ['the', 'earth'],
#  ['earth', 'bring'],
#  ['bring', 'forth'],
#  ['forth', 'the'],
#  ['the', 'living'],
#  ['living', 'creature'],
#  ['creature', 'after'],
#  ['after', 'his'],
#  ['his', 'kind,'],
#  ['kind,', 'cattle,'],
#  ['cattle,', 'and'],
#  ['and', 'creeping'],
#  ['creeping', 'thing,'],
#  ['thing,', 'and'],
#  ['and', 'beast'],
#  ['beast', 'of'],
#  ['of', 'the'],
#  ['the', 'earth'],
#  ['earth', 'after'],
#  ['after', 'his'],
#  ['his', 'kind:'],
#  ['kind:', 'and'],
#  ['and', 'it'],
#  ['it', 'was'],
#  ['was', 'so.'],
#  ['so.', 'And'],
#  ['And', 'God'],
#  ['God', 'made'],
#  ['made', 'the'],
#  ['the', 'beast'],
#  ['beast', 'of'],
#  ['of', 'the'],
#  ['the', 'earth'],
#  ['earth', 'after'],
#  ['after', 'his'],
#  ['his', 'kind,'],
#  ['kind,', 'and'],
#  ['and', 'cattle'],
#  ['cattle', 'after'],
#  ['after', 'their'],
#  ['their', 'kind,'],
#  ['kind,', 'and'],
#  ['and', 'every'],
#  ['every', 'thing'],
#  ['thing', 'that'],
#  ['that', 'creepeth'],
#  ['creepeth', 'upon'],
#  ['upon', 'the'],
#  ['the', 'earth'],
#  ['earth', 'after'],
#  ['after', 'his'],
#  ['his', 'kind:'],
#  ['kind:', 'and'],
#  ['and', 'God'],
#  ['God', 'saw'],
#  ['saw', 'that'],
#  ['that', 'it'],
#  ['it', 'was'],
#  ['was', 'good.'],
#  ['good.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Let'],
#  ['Let', 'us'],
#  ['us', 'make'],
#  ['make', 'man'],
#  ['man', 'in'],
#  ['in', 'our'],
#  ['our', 'image,'],
#  ['image,', 'after'],
#  ['after', 'our'],
#  ['our', 'likeness:'],
#  ['likeness:', 'and'],
#  ['and', 'let'],
#  ['let', 'them'],
#  ['them', 'have'],
#  ['have', 'dominion'],
#  ['dominion', 'over'],
#  ['over', 'the'],
#  ['the', 'fish'],
#  ['fish', 'of'],
#  ['of', 'the'],
#  ['the', 'sea,'],
#  ['sea,', 'and'],
#  ['and', 'over'],
#  ['over', 'the'],
#  ['the', 'fowl'],
#  ['fowl', 'of'],
#  ['of', 'the'],
#  ['the', 'air,'],
#  ['air,', 'and'],
#  ['and', 'over'],
#  ['over', 'the'],
#  ['the', 'cattle,'],
#  ['cattle,', 'and'],
#  ['and', 'over'],
#  ['over', 'all'],
#  ['all', 'the'],
#  ['the', 'earth,'],
#  ['earth,', 'and'],
#  ['and', 'over'],
#  ['over', 'every'],
#  ['every', 'creeping'],
#  ['creeping', 'thing'],
#  ['thing', 'that'],
#  ['that', 'creepeth'],
#  ['creepeth', 'upon'],
#  ['upon', 'the'],
#  ['the', 'earth.'],
#  ['earth.', 'So'],
#  ['So', 'God'],
#  ['God', 'created'],
#  ['created', 'man'],
#  ['man', 'in'],
#  ['in', 'his'],
#  ['his', 'own'],
#  ['own', 'image,'],
#  ['image,', 'in'],
#  ['in', 'the'],
#  ['the', 'image'],
#  ['image', 'of'],
#  ['of', 'God'],
#  ['God', 'created'],
#  ['created', 'he'],
#  ['he', 'him;'],
#  ['him;', 'male'],
#  ['male', 'and'],
#  ['and', 'female'],
#  ['female', 'created'],
#  ['created', 'he'],
#  ['he', 'them.'],
#  ['them.', 'And'],
#  ['And', 'God'],
#  ['God', 'blessed'],
#  ['blessed', 'them,'],
#  ['them,', 'and'],
#  ['and', 'God'],
#  ['God', 'said'],
#  ['said', 'unto'],
#  ['unto', 'them,'],
#  ['them,', 'Be'],
#  ['Be', 'fruitful,'],
#  ['fruitful,', 'and'],
#  ['and', 'multiply,'],
#  ['multiply,', 'and'],
#  ['and', 'replenish'],
#  ['replenish', 'the'],
#  ['the', 'earth,'],
#  ['earth,', 'and'],
#  ['and', 'subdue'],
#  ['subdue', 'it:'],
#  ['it:', 'and'],
#  ['and', 'have'],
#  ['have', 'dominion'],
#  ['dominion', 'over'],
#  ['over', 'the'],
#  ['the', 'fish'],
#  ['fish', 'of'],
#  ['of', 'the'],
#  ['the', 'sea,'],
#  ['sea,', 'and'],
#  ['and', 'over'],
#  ['over', 'the'],
#  ['the', 'fowl'],
#  ['fowl', 'of'],
#  ['of', 'the'],
#  ['the', 'air,'],
#  ['air,', 'and'],
#  ['and', 'over'],
#  ['over', 'every'],
#  ['every', 'living'],
#  ['living', 'thing'],
#  ['thing', 'that'],
#  ['that', 'moveth'],
#  ['moveth', 'upon'],
#  ['upon', 'the'],
#  ['the', 'earth.'],
#  ['earth.', 'And'],
#  ['And', 'God'],
#  ['God', 'said,'],
#  ['said,', 'Behold,'],
#  ['Behold,', 'I'],
#  ['I', 'have'],
#  ['have', 'given'],
#  ['given', 'you'],
#  ['you', 'every'],
#  ['every', 'herb'],
#  ['herb', 'bearing'],
#  ['bearing', 'seed,'],
#  ['seed,', 'which'],
#  ['which', 'is'],
#  ['is', 'upon'],
#  ['upon', 'the'],
#  ['the', 'face'],
#  ['face', 'of'],
#  ['of', 'all'],
#  ['all', 'the'],
#  ['the', 'earth,'],
#  ['earth,', 'and'],
#  ['and', 'every'],
#  ['every', 'tree,'],
#  ['tree,', 'in'],
#  ['in', 'the'],
#  ['the', 'which'],
#  ['which', 'is'],
#  ['is', 'the'],
#  ['the', 'fruit'],
#  ['fruit', 'of'],
#  ['of', 'a'],
#  ['a', 'tree'],
#  ['tree', 'yielding'],
#  ['yielding', 'seed;'],
#  ['seed;', 'to'],
#  ['to', 'you'],
#  ['you', 'it'],
#  ['it', 'shall'],
#  ['shall', 'be'],
#  ['be', 'for'],
#  ['for', 'meat.'],
#  ['meat.', 'And'],
#  ['And', 'to'],
#  ['to', 'every'],
#  ['every', 'beast'],
#  ['beast', 'of'],
#  ['of', 'the'],
#  ['the', 'earth,'],
#  ['earth,', 'and'],
#  ['and', 'to'],
#  ['to', 'every'],
#  ['every', 'fowl'],
#  ['fowl', 'of'],
#  ['of', 'the'],
#  ['the', 'air,'],
#  ['air,', 'and'],
#  ['and', 'to'],
#  ['to', 'every'],
#  ['every', 'thing'],
#  ['thing', 'that'],
#  ['that', 'creepeth'],
#  ['creepeth', 'upon'],
#  ['upon', 'the'],
#  ['the', 'earth,'],
#  ['earth,', 'wherein'],
#  ['wherein', 'there'],
#  ['there', 'is'],
#  ['is', 'life,'],
#  ['life,', 'I'],
#  ['I', 'have'],
#  ['have', 'given'],
#  ['given', 'every'],
#  ['every', 'green'],
#  ['green', 'herb'],
#  ['herb', 'for'],
#  ['for', 'meat:'],
#  ['meat:', 'and'],
#  ['and', 'it'],
#  ['it', 'was'],
#  ['was', 'so.'],
#  ['so.', 'And'],
#  ['And', 'God'],
#  ['God', 'saw'],
#  ['saw', 'every'],
#  ['every', 'thing'],
#  ['thing', 'that'],
#  ['that', 'he'],
#  ['he', 'had'],
#  ['had', 'made,'],
#  ['made,', 'and,'],
#  ['and,', 'behold,'],
#  ['behold,', 'it'],
#  ['it', 'was'],
#  ['was', 'very'],
#  ['very', 'good.'],
#  ['good.', 'And'],
#  ['And', 'the'],
#  ['the', 'evening'],
#  ['evening', 'and'],
#  ['and', 'the'],
#  ['the', 'morning'],
#  ['morning', 'were'],
#  ['were', 'the'],
#  ['the', 'sixth'],
#  ['sixth', 'day.']]

# %%
#doesnt work because uses dict. interally, need to change to tuple
Counter(pairs).most_common(12)
# Out:
# [(('And', 'God'), 21),
#  (('of', 'the'), 15),
#  (('it', 'was'), 13),
#  (('and', 'the'), 12),
#  (('upon', 'the'), 10),
#  (('And', 'the'), 9),
#  (('God', 'said,'), 9),
#  (('in', 'the'), 9),
#  (('the', 'earth'), 8),
#  (('said,', 'Let'), 8),
#  (('the', 'waters'), 8),
#  (('after', 'his'), 8)]

# %% [markdown]
# "bi-gram" (paired) text analysis
#
# n-gram (order aka size)|

# %%
def ngrams_for_sequence(n, seq):
    return [tuple(seq[i:i+n]) for i in range(len(seq)-n+1)]

# %%
ngrams_for_sequence(2, text)
# Out:
# [('In', 'the'),
#  ('the', 'beginning'),
#  ('beginning', 'God'),
#  ('God', 'created'),
#  ('created', 'the'),
#  ('the', 'heaven'),
#  ('heaven', 'and'),
#  ('and', 'the'),
#  ('the', 'earth.'),
#  ('earth.', 'And'),
#  ('And', 'the'),
#  ('the', 'earth'),
#  ('earth', 'was'),
#  ('was', 'without'),
#  ('without', 'form,'),
#  ('form,', 'and'),
#  ('and', 'void;'),
#  ('void;', 'and'),
#  ('and', 'darkness'),
#  ('darkness', 'was'),
#  ('was', 'upon'),
#  ('upon', 'the'),
#  ('the', 'face'),
#  ('face', 'of'),
#  ('of', 'the'),
#  ('the', 'deep.'),
#  ('deep.', 'And'),
#  ('And', 'the'),
#  ('the', 'Spirit'),
#  ('Spirit', 'of'),
#  ('of', 'God'),
#  ('God', 'moved'),
#  ('moved', 'upon'),
#  ('upon', 'the'),
#  ('the', 'face'),
#  ('face', 'of'),
#  ('of', 'the'),
#  ('the', 'waters.'),
#  ('waters.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Let'),
#  ('Let', 'there'),
#  ('there', 'be'),
#  ('be', 'light:'),
#  ('light:', 'and'),
#  ('and', 'there'),
#  ('there', 'was'),
#  ('was', 'light.'),
#  ('light.', 'And'),
#  ('And', 'God'),
#  ('God', 'saw'),
#  ('saw', 'the'),
#  ('the', 'light,'),
#  ('light,', 'that'),
#  ('that', 'it'),
#  ('it', 'was'),
#  ('was', 'good:'),
#  ('good:', 'and'),
#  ('and', 'God'),
#  ('God', 'divided'),
#  ('divided', 'the'),
#  ('the', 'light'),
#  ('light', 'from'),
#  ('from', 'the'),
#  ('the', 'darkness.'),
#  ('darkness.', 'And'),
#  ('And', 'God'),
#  ('God', 'called'),
#  ('called', 'the'),
#  ('the', 'light'),
#  ('light', 'Day,'),
#  ('Day,', 'and'),
#  ('and', 'the'),
#  ('the', 'darkness'),
#  ('darkness', 'he'),
#  ('he', 'called'),
#  ('called', 'Night.'),
#  ('Night.', 'And'),
#  ('And', 'the'),
#  ('the', 'evening'),
#  ('evening', 'and'),
#  ('and', 'the'),
#  ('the', 'morning'),
#  ('morning', 'were'),
#  ('were', 'the'),
#  ('the', 'first'),
#  ('first', 'day.'),
#  ('day.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Let'),
#  ('Let', 'there'),
#  ('there', 'be'),
#  ('be', 'a'),
#  ('a', 'firmament'),
#  ('firmament', 'in'),
#  ('in', 'the'),
#  ('the', 'midst'),
#  ('midst', 'of'),
#  ('of', 'the'),
#  ('the', 'waters,'),
#  ('waters,', 'and'),
#  ('and', 'let'),
#  ('let', 'it'),
#  ('it', 'divide'),
#  ('divide', 'the'),
#  ('the', 'waters'),
#  ('waters', 'from'),
#  ('from', 'the'),
#  ('the', 'waters.'),
#  ('waters.', 'And'),
#  ('And', 'God'),
#  ('God', 'made'),
#  ('made', 'the'),
#  ('the', 'firmament,'),
#  ('firmament,', 'and'),
#  ('and', 'divided'),
#  ('divided', 'the'),
#  ('the', 'waters'),
#  ('waters', 'which'),
#  ('which', 'were'),
#  ('were', 'under'),
#  ('under', 'the'),
#  ('the', 'firmament'),
#  ('firmament', 'from'),
#  ('from', 'the'),
#  ('the', 'waters'),
#  ('waters', 'which'),
#  ('which', 'were'),
#  ('were', 'above'),
#  ('above', 'the'),
#  ('the', 'firmament:'),
#  ('firmament:', 'and'),
#  ('and', 'it'),
#  ('it', 'was'),
#  ('was', 'so.'),
#  ('so.', 'And'),
#  ('And', 'God'),
#  ('God', 'called'),
#  ('called', 'the'),
#  ('the', 'firmament'),
#  ('firmament', 'Heaven.'),
#  ('Heaven.', 'And'),
#  ('And', 'the'),
#  ('the', 'evening'),
#  ('evening', 'and'),
#  ('and', 'the'),
#  ('the', 'morning'),
#  ('morning', 'were'),
#  ('were', 'the'),
#  ('the', 'second'),
#  ('second', 'day.'),
#  ('day.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Let'),
#  ('Let', 'the'),
#  ('the', 'waters'),
#  ('waters', 'under'),
#  ('under', 'the'),
#  ('the', 'heaven'),
#  ('heaven', 'be'),
#  ('be', 'gathered'),
#  ('gathered', 'together'),
#  ('together', 'unto'),
#  ('unto', 'one'),
#  ('one', 'place,'),
#  ('place,', 'and'),
#  ('and', 'let'),
#  ('let', 'the'),
#  ('the', 'dry'),
#  ('dry', 'land'),
#  ('land', 'appear:'),
#  ('appear:', 'and'),
#  ('and', 'it'),
#  ('it', 'was'),
#  ('was', 'so.'),
#  ('so.', 'And'),
#  ('And', 'God'),
#  ('God', 'called'),
#  ('called', 'the'),
#  ('the', 'dry'),
#  ('dry', 'land'),
#  ('land', 'Earth;'),
#  ('Earth;', 'and'),
#  ('and', 'the'),
#  ('the', 'gathering'),
#  ('gathering', 'together'),
#  ('together', 'of'),
#  ('of', 'the'),
#  ('the', 'waters'),
#  ('waters', 'called'),
#  ('called', 'he'),
#  ('he', 'Seas:'),
#  ('Seas:', 'and'),
#  ('and', 'God'),
#  ('God', 'saw'),
#  ('saw', 'that'),
#  ('that', 'it'),
#  ('it', 'was'),
#  ('was', 'good.'),
#  ('good.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Let'),
#  ('Let', 'the'),
#  ('the', 'earth'),
#  ('earth', 'bring'),
#  ('bring', 'forth'),
#  ('forth', 'grass,'),
#  ('grass,', 'the'),
#  ('the', 'herb'),
#  ('herb', 'yielding'),
#  ('yielding', 'seed,'),
#  ('seed,', 'and'),
#  ('and', 'the'),
#  ('the', 'fruit'),
#  ('fruit', 'tree'),
#  ('tree', 'yielding'),
#  ('yielding', 'fruit'),
#  ('fruit', 'after'),
#  ('after', 'his'),
#  ('his', 'kind,'),
#  ('kind,', 'whose'),
#  ('whose', 'seed'),
#  ('seed', 'is'),
#  ('is', 'in'),
#  ('in', 'itself,'),
#  ('itself,', 'upon'),
#  ('upon', 'the'),
#  ('the', 'earth:'),
#  ('earth:', 'and'),
#  ('and', 'it'),
#  ('it', 'was'),
#  ('was', 'so.'),
#  ('so.', 'And'),
#  ('And', 'the'),
#  ('the', 'earth'),
#  ('earth', 'brought'),
#  ('brought', 'forth'),
#  ('forth', 'grass,'),
#  ('grass,', 'and'),
#  ('and', 'herb'),
#  ('herb', 'yielding'),
#  ('yielding', 'seed'),
#  ('seed', 'after'),
#  ('after', 'his'),
#  ('his', 'kind,'),
#  ('kind,', 'and'),
#  ('and', 'the'),
#  ('the', 'tree'),
#  ('tree', 'yielding'),
#  ('yielding', 'fruit,'),
#  ('fruit,', 'whose'),
#  ('whose', 'seed'),
#  ('seed', 'was'),
#  ('was', 'in'),
#  ('in', 'itself,'),
#  ('itself,', 'after'),
#  ('after', 'his'),
#  ('his', 'kind:'),
#  ('kind:', 'and'),
#  ('and', 'God'),
#  ('God', 'saw'),
#  ('saw', 'that'),
#  ('that', 'it'),
#  ('it', 'was'),
#  ('was', 'good.'),
#  ('good.', 'And'),
#  ('And', 'the'),
#  ('the', 'evening'),
#  ('evening', 'and'),
#  ('and', 'the'),
#  ('the', 'morning'),
#  ('morning', 'were'),
#  ('were', 'the'),
#  ('the', 'third'),
#  ('third', 'day.'),
#  ('day.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Let'),
#  ('Let', 'there'),
#  ('there', 'be'),
#  ('be', 'lights'),
#  ('lights', 'in'),
#  ('in', 'the'),
#  ('the', 'firmament'),
#  ('firmament', 'of'),
#  ('of', 'the'),
#  ('the', 'heaven'),
#  ('heaven', 'to'),
#  ('to', 'divide'),
#  ('divide', 'the'),
#  ('the', 'day'),
#  ('day', 'from'),
#  ('from', 'the'),
#  ('the', 'night;'),
#  ('night;', 'and'),
#  ('and', 'let'),
#  ('let', 'them'),
#  ('them', 'be'),
#  ('be', 'for'),
#  ('for', 'signs,'),
#  ('signs,', 'and'),
#  ('and', 'for'),
#  ('for', 'seasons,'),
#  ('seasons,', 'and'),
#  ('and', 'for'),
#  ('for', 'days,'),
#  ('days,', 'and'),
#  ('and', 'years:'),
#  ('years:', 'And'),
#  ('And', 'let'),
#  ('let', 'them'),
#  ('them', 'be'),
#  ('be', 'for'),
#  ('for', 'lights'),
#  ('lights', 'in'),
#  ('in', 'the'),
#  ('the', 'firmament'),
#  ('firmament', 'of'),
#  ('of', 'the'),
#  ('the', 'heaven'),
#  ('heaven', 'to'),
#  ('to', 'give'),
#  ('give', 'light'),
#  ('light', 'upon'),
#  ('upon', 'the'),
#  ('the', 'earth:'),
#  ('earth:', 'and'),
#  ('and', 'it'),
#  ('it', 'was'),
#  ('was', 'so.'),
#  ('so.', 'And'),
#  ('And', 'God'),
#  ('God', 'made'),
#  ('made', 'two'),
#  ('two', 'great'),
#  ('great', 'lights;'),
#  ('lights;', 'the'),
#  ('the', 'greater'),
#  ('greater', 'light'),
#  ('light', 'to'),
#  ('to', 'rule'),
#  ('rule', 'the'),
#  ('the', 'day,'),
#  ('day,', 'and'),
#  ('and', 'the'),
#  ('the', 'lesser'),
#  ('lesser', 'light'),
#  ('light', 'to'),
#  ('to', 'rule'),
#  ('rule', 'the'),
#  ('the', 'night:'),
#  ('night:', 'he'),
#  ('he', 'made'),
#  ('made', 'the'),
#  ('the', 'stars'),
#  ('stars', 'also.'),
#  ('also.', 'And'),
#  ('And', 'God'),
#  ('God', 'set'),
#  ('set', 'them'),
#  ('them', 'in'),
#  ('in', 'the'),
#  ('the', 'firmament'),
#  ('firmament', 'of'),
#  ('of', 'the'),
#  ('the', 'heaven'),
#  ('heaven', 'to'),
#  ('to', 'give'),
#  ('give', 'light'),
#  ('light', 'upon'),
#  ('upon', 'the'),
#  ('the', 'earth,'),
#  ('earth,', 'And'),
#  ('And', 'to'),
#  ('to', 'rule'),
#  ('rule', 'over'),
#  ('over', 'the'),
#  ('the', 'day'),
#  ('day', 'and'),
#  ('and', 'over'),
#  ('over', 'the'),
#  ('the', 'night,'),
#  ('night,', 'and'),
#  ('and', 'to'),
#  ('to', 'divide'),
#  ('divide', 'the'),
#  ('the', 'light'),
#  ('light', 'from'),
#  ('from', 'the'),
#  ('the', 'darkness:'),
#  ('darkness:', 'and'),
#  ('and', 'God'),
#  ('God', 'saw'),
#  ('saw', 'that'),
#  ('that', 'it'),
#  ('it', 'was'),
#  ('was', 'good.'),
#  ('good.', 'And'),
#  ('And', 'the'),
#  ('the', 'evening'),
#  ('evening', 'and'),
#  ('and', 'the'),
#  ('the', 'morning'),
#  ('morning', 'were'),
#  ('were', 'the'),
#  ('the', 'fourth'),
#  ('fourth', 'day.'),
#  ('day.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Let'),
#  ('Let', 'the'),
#  ('the', 'waters'),
#  ('waters', 'bring'),
#  ('bring', 'forth'),
#  ('forth', 'abundantly'),
#  ('abundantly', 'the'),
#  ('the', 'moving'),
#  ('moving', 'creature'),
#  ('creature', 'that'),
#  ('that', 'hath'),
#  ('hath', 'life,'),
#  ('life,', 'and'),
#  ('and', 'fowl'),
#  ('fowl', 'that'),
#  ('that', 'may'),
#  ('may', 'fly'),
#  ('fly', 'above'),
#  ('above', 'the'),
#  ('the', 'earth'),
#  ('earth', 'in'),
#  ('in', 'the'),
#  ('the', 'open'),
#  ('open', 'firmament'),
#  ('firmament', 'of'),
#  ('of', 'heaven.'),
#  ('heaven.', 'And'),
#  ('And', 'God'),
#  ('God', 'created'),
#  ('created', 'great'),
#  ('great', 'whales,'),
#  ('whales,', 'and'),
#  ('and', 'every'),
#  ('every', 'living'),
#  ('living', 'creature'),
#  ('creature', 'that'),
#  ('that', 'moveth,'),
#  ('moveth,', 'which'),
#  ('which', 'the'),
#  ('the', 'waters'),
#  ('waters', 'brought'),
#  ('brought', 'forth'),
#  ('forth', 'abundantly,'),
#  ('abundantly,', 'after'),
#  ('after', 'their'),
#  ('their', 'kind,'),
#  ('kind,', 'and'),
#  ('and', 'every'),
#  ('every', 'winged'),
#  ('winged', 'fowl'),
#  ('fowl', 'after'),
#  ('after', 'his'),
#  ('his', 'kind:'),
#  ('kind:', 'and'),
#  ('and', 'God'),
#  ('God', 'saw'),
#  ('saw', 'that'),
#  ('that', 'it'),
#  ('it', 'was'),
#  ('was', 'good.'),
#  ('good.', 'And'),
#  ('And', 'God'),
#  ('God', 'blessed'),
#  ('blessed', 'them,'),
#  ('them,', 'saying,'),
#  ('saying,', 'Be'),
#  ('Be', 'fruitful,'),
#  ('fruitful,', 'and'),
#  ('and', 'multiply,'),
#  ('multiply,', 'and'),
#  ('and', 'fill'),
#  ('fill', 'the'),
#  ('the', 'waters'),
#  ('waters', 'in'),
#  ('in', 'the'),
#  ('the', 'seas,'),
#  ('seas,', 'and'),
#  ('and', 'let'),
#  ('let', 'fowl'),
#  ('fowl', 'multiply'),
#  ('multiply', 'in'),
#  ('in', 'the'),
#  ('the', 'earth.'),
#  ('earth.', 'And'),
#  ('And', 'the'),
#  ('the', 'evening'),
#  ('evening', 'and'),
#  ('and', 'the'),
#  ('the', 'morning'),
#  ('morning', 'were'),
#  ('were', 'the'),
#  ('the', 'fifth'),
#  ('fifth', 'day.'),
#  ('day.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Let'),
#  ('Let', 'the'),
#  ('the', 'earth'),
#  ('earth', 'bring'),
#  ('bring', 'forth'),
#  ('forth', 'the'),
#  ('the', 'living'),
#  ('living', 'creature'),
#  ('creature', 'after'),
#  ('after', 'his'),
#  ('his', 'kind,'),
#  ('kind,', 'cattle,'),
#  ('cattle,', 'and'),
#  ('and', 'creeping'),
#  ('creeping', 'thing,'),
#  ('thing,', 'and'),
#  ('and', 'beast'),
#  ('beast', 'of'),
#  ('of', 'the'),
#  ('the', 'earth'),
#  ('earth', 'after'),
#  ('after', 'his'),
#  ('his', 'kind:'),
#  ('kind:', 'and'),
#  ('and', 'it'),
#  ('it', 'was'),
#  ('was', 'so.'),
#  ('so.', 'And'),
#  ('And', 'God'),
#  ('God', 'made'),
#  ('made', 'the'),
#  ('the', 'beast'),
#  ('beast', 'of'),
#  ('of', 'the'),
#  ('the', 'earth'),
#  ('earth', 'after'),
#  ('after', 'his'),
#  ('his', 'kind,'),
#  ('kind,', 'and'),
#  ('and', 'cattle'),
#  ('cattle', 'after'),
#  ('after', 'their'),
#  ('their', 'kind,'),
#  ('kind,', 'and'),
#  ('and', 'every'),
#  ('every', 'thing'),
#  ('thing', 'that'),
#  ('that', 'creepeth'),
#  ('creepeth', 'upon'),
#  ('upon', 'the'),
#  ('the', 'earth'),
#  ('earth', 'after'),
#  ('after', 'his'),
#  ('his', 'kind:'),
#  ('kind:', 'and'),
#  ('and', 'God'),
#  ('God', 'saw'),
#  ('saw', 'that'),
#  ('that', 'it'),
#  ('it', 'was'),
#  ('was', 'good.'),
#  ('good.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Let'),
#  ('Let', 'us'),
#  ('us', 'make'),
#  ('make', 'man'),
#  ('man', 'in'),
#  ('in', 'our'),
#  ('our', 'image,'),
#  ('image,', 'after'),
#  ('after', 'our'),
#  ('our', 'likeness:'),
#  ('likeness:', 'and'),
#  ('and', 'let'),
#  ('let', 'them'),
#  ('them', 'have'),
#  ('have', 'dominion'),
#  ('dominion', 'over'),
#  ('over', 'the'),
#  ('the', 'fish'),
#  ('fish', 'of'),
#  ('of', 'the'),
#  ('the', 'sea,'),
#  ('sea,', 'and'),
#  ('and', 'over'),
#  ('over', 'the'),
#  ('the', 'fowl'),
#  ('fowl', 'of'),
#  ('of', 'the'),
#  ('the', 'air,'),
#  ('air,', 'and'),
#  ('and', 'over'),
#  ('over', 'the'),
#  ('the', 'cattle,'),
#  ('cattle,', 'and'),
#  ('and', 'over'),
#  ('over', 'all'),
#  ('all', 'the'),
#  ('the', 'earth,'),
#  ('earth,', 'and'),
#  ('and', 'over'),
#  ('over', 'every'),
#  ('every', 'creeping'),
#  ('creeping', 'thing'),
#  ('thing', 'that'),
#  ('that', 'creepeth'),
#  ('creepeth', 'upon'),
#  ('upon', 'the'),
#  ('the', 'earth.'),
#  ('earth.', 'So'),
#  ('So', 'God'),
#  ('God', 'created'),
#  ('created', 'man'),
#  ('man', 'in'),
#  ('in', 'his'),
#  ('his', 'own'),
#  ('own', 'image,'),
#  ('image,', 'in'),
#  ('in', 'the'),
#  ('the', 'image'),
#  ('image', 'of'),
#  ('of', 'God'),
#  ('God', 'created'),
#  ('created', 'he'),
#  ('he', 'him;'),
#  ('him;', 'male'),
#  ('male', 'and'),
#  ('and', 'female'),
#  ('female', 'created'),
#  ('created', 'he'),
#  ('he', 'them.'),
#  ('them.', 'And'),
#  ('And', 'God'),
#  ('God', 'blessed'),
#  ('blessed', 'them,'),
#  ('them,', 'and'),
#  ('and', 'God'),
#  ('God', 'said'),
#  ('said', 'unto'),
#  ('unto', 'them,'),
#  ('them,', 'Be'),
#  ('Be', 'fruitful,'),
#  ('fruitful,', 'and'),
#  ('and', 'multiply,'),
#  ('multiply,', 'and'),
#  ('and', 'replenish'),
#  ('replenish', 'the'),
#  ('the', 'earth,'),
#  ('earth,', 'and'),
#  ('and', 'subdue'),
#  ('subdue', 'it:'),
#  ('it:', 'and'),
#  ('and', 'have'),
#  ('have', 'dominion'),
#  ('dominion', 'over'),
#  ('over', 'the'),
#  ('the', 'fish'),
#  ('fish', 'of'),
#  ('of', 'the'),
#  ('the', 'sea,'),
#  ('sea,', 'and'),
#  ('and', 'over'),
#  ('over', 'the'),
#  ('the', 'fowl'),
#  ('fowl', 'of'),
#  ('of', 'the'),
#  ('the', 'air,'),
#  ('air,', 'and'),
#  ('and', 'over'),
#  ('over', 'every'),
#  ('every', 'living'),
#  ('living', 'thing'),
#  ('thing', 'that'),
#  ('that', 'moveth'),
#  ('moveth', 'upon'),
#  ('upon', 'the'),
#  ('the', 'earth.'),
#  ('earth.', 'And'),
#  ('And', 'God'),
#  ('God', 'said,'),
#  ('said,', 'Behold,'),
#  ('Behold,', 'I'),
#  ('I', 'have'),
#  ('have', 'given'),
#  ('given', 'you'),
#  ('you', 'every'),
#  ('every', 'herb'),
#  ('herb', 'bearing'),
#  ('bearing', 'seed,'),
#  ('seed,', 'which'),
#  ('which', 'is'),
#  ('is', 'upon'),
#  ('upon', 'the'),
#  ('the', 'face'),
#  ('face', 'of'),
#  ('of', 'all'),
#  ('all', 'the'),
#  ('the', 'earth,'),
#  ('earth,', 'and'),
#  ('and', 'every'),
#  ('every', 'tree,'),
#  ('tree,', 'in'),
#  ('in', 'the'),
#  ('the', 'which'),
#  ('which', 'is'),
#  ('is', 'the'),
#  ('the', 'fruit'),
#  ('fruit', 'of'),
#  ('of', 'a'),
#  ('a', 'tree'),
#  ('tree', 'yielding'),
#  ('yielding', 'seed;'),
#  ('seed;', 'to'),
#  ('to', 'you'),
#  ('you', 'it'),
#  ('it', 'shall'),
#  ('shall', 'be'),
#  ('be', 'for'),
#  ('for', 'meat.'),
#  ('meat.', 'And'),
#  ('And', 'to'),
#  ('to', 'every'),
#  ('every', 'beast'),
#  ('beast', 'of'),
#  ('of', 'the'),
#  ('the', 'earth,'),
#  ('earth,', 'and'),
#  ('and', 'to'),
#  ('to', 'every'),
#  ('every', 'fowl'),
#  ('fowl', 'of'),
#  ('of', 'the'),
#  ('the', 'air,'),
#  ('air,', 'and'),
#  ('and', 'to'),
#  ('to', 'every'),
#  ('every', 'thing'),
#  ('thing', 'that'),
#  ('that', 'creepeth'),
#  ('creepeth', 'upon'),
#  ('upon', 'the'),
#  ('the', 'earth,'),
#  ('earth,', 'wherein'),
#  ('wherein', 'there'),
#  ('there', 'is'),
#  ('is', 'life,'),
#  ('life,', 'I'),
#  ('I', 'have'),
#  ('have', 'given'),
#  ('given', 'every'),
#  ('every', 'green'),
#  ('green', 'herb'),
#  ('herb', 'for'),
#  ('for', 'meat:'),
#  ('meat:', 'and'),
#  ('and', 'it'),
#  ('it', 'was'),
#  ('was', 'so.'),
#  ('so.', 'And'),
#  ('And', 'God'),
#  ('God', 'saw'),
#  ('saw', 'every'),
#  ('every', 'thing'),
#  ('thing', 'that'),
#  ('that', 'he'),
#  ('he', 'had'),
#  ('had', 'made,'),
#  ('made,', 'and,'),
#  ('and,', 'behold,'),
#  ('behold,', 'it'),
#  ('it', 'was'),
#  ('was', 'very'),
#  ('very', 'good.'),
#  ('good.', 'And'),
#  ('And', 'the'),
#  ('the', 'evening'),
#  ('evening', 'and'),
#  ('and', 'the'),
#  ('the', 'morning'),
#  ('morning', 'were'),
#  ('were', 'the'),
#  ('the', 'sixth'),
#  ('sixth', 'day.')]

# %%
bible_grams = ngrams_for_sequence(5, text)

# %%
Counter(bible_grams).most_common(10)
# Out:
# [(('And', 'the', 'evening', 'and', 'the'), 6),
#  (('the', 'evening', 'and', 'the', 'morning'), 6),
#  (('evening', 'and', 'the', 'morning', 'were'), 6),
#  (('and', 'the', 'morning', 'were', 'the'), 6),
#  (('and', 'it', 'was', 'so.', 'And'), 6),
#  (('day.', 'And', 'God', 'said,', 'Let'), 5),
#  (('it', 'was', 'so.', 'And', 'God'), 5),
#  (('and', 'God', 'saw', 'that', 'it'), 5),
#  (('God', 'saw', 'that', 'it', 'was'), 5),
#  (('saw', 'that', 'it', 'was', 'good.'), 5)]

# %%
Counter(ngrams_for_sequence(4, text)).most_common(3)
# Out:
# [(('And', 'God', 'said,', 'Let'), 8),
#  (('And', 'the', 'evening', 'and'), 6),
#  (('the', 'evening', 'and', 'the'), 6)]

# %%
frost_text = open("txt/frost.txt").read()

# %%
Counter(ngrams_for_sequence(4, frost_text)).most_common(12)
# Out:
# [((' ', 't', 'h', 'e'), 10),
#  (('t', 'h', 'e', ' '), 8),
#  (('\n', 'A', 'n', 'd'), 6),
#  (('A', 'n', 'd', ' '), 6),
#  ((' ', 'a', 's', ' '), 5),
#  (('i', 'n', 'g', ' '), 5),
#  (('a', 'd', 's', ' '), 3),
#  (('e', 'd', ' ', 'i'), 3),
#  ((' ', 'i', 'n', ' '), 3),
#  ((',', '\n', 'A', 'n'), 3),
#  (('o', 'u', 'l', 'd'), 3),
#  ((' ', 't', 'r', 'a'), 3)]

# %% [markdown]
# level // unit : how you break up the ngram
#
# words vs letters, or bars vs notes

# %% [markdown]
# markov model just relates n-gram to what comes next
# order 2 char level:
#
# MARKOV MODEL :
#
# "condescendences"
#     co : n
#     on : d
#     nd : e, e
#     de : s, n
#     es : c, EOW (' ')
#     sc : e
#     ce : n, s
#     en : d, c
#     nc : e
#
#  layers of n-gram markov models can be weighted statistically
#  -- common in text classification
#
#  can be used in other models, not just text
#  -- weather prediction
#
#  smaller n-grams produce more variety but are less coherent
#  larger = reversed
#
#  (RNN can n=infinite...)
#
#  Markov Chain Generation
#
#  "condencences"
#
#  could be done with images? (Itay) -- would need to flatten to 1-D ('a string')
#
#    list of all letters and their probabilities
#    vs
#    list of all possible words and their probabilities (RNN)
#
#  ## markovify

# %%
# !pip install markovify
# Out:
# Collecting markovify
#   Downloading https://files.pythonhosted.org/packages/94/b2/b4ce1e461bb3482b1fd63328a2097aed5917cdfa0dbfe9492a84ea46e2ab/markovify-0.7.1.tar.gz
# Collecting unidecode (from markovify)
#   Downloading https://files.pythonhosted.org/packages/31/39/53096f9217b057cb049fe872b7fc7ce799a1a89b76cf917d9639e7a558b5/Unidecode-1.0.23-py2.py3-none-any.whl (237kB)
#     100% |████████████████████████████████| 245kB 4.8MB/s ta 0:00:011
# Building wheels for collected packages: markovify
#   Running setup.py bdist_wheel for markovify ... done
#   Stored in directory: /home/dangalf/.cache/pip/wheels/66/fe/5b/07257dd2401d9835447a0f0223f967c998c153404d32612253
# Successfully built markovify
# Installing collected packages: unidecode, markovify
# Successfully installed markovify-0.7.1 unidecode-1.0.23

# %%
#by default works just with words

import markovify

# %%
text_a = open("txt/frankenstein.txt").read()

text_b = open("txt/austen.txt").read()

# %%
generator_a = markovify.Text(text_a, state_size=3)

# %%
generator_a.make_sentence()
# Out:
# 'M. Krempe was a little raised, so that it was the outward substance of things or the inner spirit of nature and show how she works in her hiding-places.'

# %%
generator_a.make_short_sentence(60)
# Out:
# 'A change indeed had taken place in our little household.'

# %% [markdown]
# ## textgenrnn
#
# temperature

# %%
#have to install tensorflow first
# !conda install -y keras
# Out:
# Collecting package metadata: done
# Solving environment: \

# %%
# !pip install textgenrnn

# %% [markdown]
# # VECTORS

# %%
import numpy as np

# %%
import json

# %%
color_data = json.loads(open("xkcd.json").read())

# %%
def hex_to_int(s):
    s = s.lstrip("#")
    return np.array([int(s[:2], 16), int(s[2:4], 16), int(s[4:6], 16)])

# %%
colors = {}
for item in color_data['colors']:
    colors[item["color"]] = hex_to_int(item["hex"])

# %%
colors
# Out:
# {'cloudy blue': array([172, 194, 217]),
#  'dark pastel green': array([ 86, 174,  87]),
#  'dust': array([178, 153, 110]),
#  'electric lime': array([168, 255,   4]),
#  'fresh green': array([105, 216,  79]),
#  'light eggplant': array([137,  69, 133]),
#  'nasty green': array([112, 178,  63]),
#  'really light blue': array([212, 255, 255]),
#  'tea': array([101, 171, 124]),
#  'warm purple': array([149,  46, 143]),
#  'yellowish tan': array([252, 252, 129]),
#  'cement': array([165, 163, 145]),
#  'dark grass green': array([ 56, 128,   4]),
#  'dusty teal': array([ 76, 144, 133]),
#  'grey teal': array([ 94, 155, 138]),
#  'macaroni and cheese': array([239, 180,  53]),
#  'pinkish tan': array([217, 155, 130]),
#  'spruce': array([10, 95, 56]),
#  'strong blue': array([ 12,   6, 247]),
#  'toxic green': array([ 97, 222,  42]),
#  'windows blue': array([ 55, 120, 191]),
#  'blue blue': array([ 34,  66, 199]),
#  'blue with a hint of purple': array([ 83,  60, 198]),
#  'booger': array([155, 181,  60]),
#  'bright sea green': array([  5, 255, 166]),
#  'dark green blue': array([31, 99, 87]),
#  'deep turquoise': array([  1, 115, 116]),
#  'green teal': array([ 12, 181, 119]),
#  'strong pink': array([255,   7, 137]),
#  'bland': array([175, 168, 139]),
#  'deep aqua': array([  8, 120, 127]),
#  'lavender pink': array([221, 133, 215]),
#  'light moss green': array([166, 200, 117]),
#  'light seafoam green': array([167, 255, 181]),
#  'olive yellow': array([194, 183,   9]),
#  'pig pink': array([231, 142, 165]),
#  'deep lilac': array([150, 110, 189]),
#  'desert': array([204, 173,  96]),
#  'dusty lavender': array([172, 134, 168]),
#  'purpley grey': array([148, 126, 148]),
#  'purply': array([152,  63, 178]),
#  'candy pink': array([255,  99, 233]),
#  'light pastel green': array([178, 251, 165]),
#  'boring green': array([ 99, 179, 101]),
#  'kiwi green': array([142, 229,  63]),
#  'light grey green': array([183, 225, 161]),
#  'orange pink': array([255, 111,  82]),
#  'tea green': array([189, 248, 163]),
#  'very light brown': array([211, 182, 131]),
#  'egg shell': array([255, 252, 196]),
#  'eggplant purple': array([67,  5, 65]),
#  'powder pink': array([255, 178, 208]),
#  'reddish grey': array([153, 117, 112]),
#  'baby shit brown': array([173, 144,  13]),
#  'liliac': array([196, 142, 253]),
#  'stormy blue': array([ 80, 123, 156]),
#  'ugly brown': array([125, 113,   3]),
#  'custard': array([255, 253, 120]),
#  'darkish pink': array([218,  70, 125]),
#  'deep brown': array([65,  2,  0]),
#  'greenish beige': array([201, 209, 121]),
#  'manilla': array([255, 250, 134]),
#  'off blue': array([ 86, 132, 174]),
#  'battleship grey': array([107, 124, 133]),
#  'browny green': array([111, 108,  10]),
#  'bruise': array([126,  64, 113]),
#  'kelley green': array([  0, 147,  55]),
#  'sickly yellow': array([208, 228,  41]),
#  'sunny yellow': array([255, 249,  23]),
#  'azul': array([ 29,  93, 236]),
#  'darkgreen': array([ 5, 73,  7]),
#  'green/yellow': array([181, 206,   8]),
#  'lichen': array([143, 182, 123]),
#  'light light green': array([200, 255, 176]),
#  'pale gold': array([253, 222, 108]),
#  'sun yellow': array([255, 223,  34]),
#  'tan green': array([169, 190, 112]),
#  'burple': array([104,  50, 227]),
#  'butterscotch': array([253, 177,  71]),
#  'toupe': array([199, 172, 125]),
#  'dark cream': array([255, 243, 154]),
#  'indian red': array([133,  14,   4]),
#  'light lavendar': array([239, 192, 254]),
#  'poison green': array([ 64, 253,  20]),
#  'baby puke green': array([182, 196,   6]),
#  'bright yellow green': array([157, 255,   0]),
#  'charcoal grey': array([60, 65, 66]),
#  'squash': array([242, 171,  21]),
#  'cinnamon': array([172,  79,   6]),
#  'light pea green': array([196, 254, 130]),
#  'radioactive green': array([ 44, 250,  31]),
#  'raw sienna': array([154,  98,   0]),
#  'baby purple': array([202, 155, 247]),
#  'cocoa': array([135,  95,  66]),
#  'light royal blue': array([ 58,  46, 254]),
#  'orangeish': array([253, 141,  73]),
#  'rust brown': array([139,  49,   3]),
#  'sand brown': array([203, 165,  96]),
#  'swamp': array([105, 131,  57]),
#  'tealish green': array([ 12, 220, 115]),
#  'burnt siena': array([183,  82,   3]),
#  'camo': array([127, 143,  78]),
#  'dusk blue': array([ 38,  83, 141]),
#  'fern': array([ 99, 169,  80]),
#  'old rose': array([200, 127, 137]),
#  'pale light green': array([177, 252, 153]),
#  'peachy pink': array([255, 154, 138]),
#  'rosy pink': array([246, 104, 142]),
#  'light bluish green': array([118, 253, 168]),
#  'light bright green': array([ 83, 254,  92]),
#  'light neon green': array([ 78, 253,  84]),
#  'light seafoam': array([160, 254, 191]),
#  'tiffany blue': array([123, 242, 218]),
#  'washed out green': array([188, 245, 166]),
#  'browny orange': array([202, 107,   2]),
#  'nice blue': array([ 16, 122, 176]),
#  'sapphire': array([ 33,  56, 171]),
#  'greyish teal': array([113, 159, 145]),
#  'orangey yellow': array([253, 185,  21]),
#  'parchment': array([254, 252, 175]),
#  'straw': array([252, 246, 121]),
#  'very dark brown': array([29,  2,  0]),
#  'terracota': array([203, 104,  67]),
#  'ugly blue': array([ 49, 102, 138]),
#  'clear blue': array([ 36, 122, 253]),
#  'creme': array([255, 255, 182]),
#  'foam green': array([144, 253, 169]),
#  'grey/green': array([134, 161, 125]),
#  'light gold': array([253, 220,  92]),
#  'seafoam blue': array([120, 209, 182]),
#  'topaz': array([ 19, 187, 175]),
#  'violet pink': array([251,  95, 252]),
#  'wintergreen': array([ 32, 249, 134]),
#  'yellow tan': array([255, 227, 110]),
#  'dark fuchsia': array([157,   7,  89]),
#  'indigo blue': array([ 58,  24, 177]),
#  'light yellowish green': array([194, 255, 137]),
#  'pale magenta': array([215, 103, 173]),
#  'rich purple': array([114,   0,  88]),
#  'sunflower yellow': array([255, 218,   3]),
#  'green/blue': array([  1, 192, 141]),
#  'leather': array([172, 116,  52]),
#  'racing green': array([ 1, 70,  0]),
#  'vivid purple': array([153,   0, 250]),
#  'dark royal blue': array([  2,   6, 111]),
#  'hazel': array([142, 118,  24]),
#  'muted pink': array([209, 118, 143]),
#  'booger green': array([150, 180,   3]),
#  'canary': array([253, 255,  99]),
#  'cool grey': array([149, 163, 166]),
#  'dark taupe': array([127, 104,  78]),
#  'darkish purple': array([117,  25, 115]),
#  'true green': array([  8, 148,   4]),
#  'coral pink': array([255,  97,  99]),
#  'dark sage': array([ 89, 133,  86]),
#  'dark slate blue': array([33, 71, 97]),
#  'flat blue': array([ 60, 115, 168]),
#  'mushroom': array([186, 158, 136]),
#  'rich blue': array([  2,  27, 249]),
#  'dirty purple': array([115,  74, 101]),
#  'greenblue': array([ 35, 196, 139]),
#  'icky green': array([143, 174,  34]),
#  'light khaki': array([230, 242, 162]),
#  'warm blue': array([ 75,  87, 219]),
#  'dark hot pink': array([217,   1, 102]),
#  'deep sea blue': array([  1,  84, 130]),
#  'carmine': array([157,   2,  22]),
#  'dark yellow green': array([114, 143,   2]),
#  'pale peach': array([255, 229, 173]),
#  'plum purple': array([78,  5, 80]),
#  'golden rod': array([249, 188,   8]),
#  'neon red': array([255,   7,  58]),
#  'old pink': array([199, 121, 134]),
#  'very pale blue': array([214, 255, 254]),
#  'blood orange': array([254,  75,   3]),
#  'grapefruit': array([253,  89,  86]),
#  'sand yellow': array([252, 225, 102]),
#  'clay brown': array([178, 113,  61]),
#  'dark blue grey': array([31, 59, 77]),
#  'flat green': array([105, 157,  76]),
#  'light green blue': array([ 86, 252, 162]),
#  'warm pink': array([251,  85, 129]),
#  'dodger blue': array([ 62, 130, 252]),
#  'gross green': array([160, 191,  22]),
#  'ice': array([214, 255, 250]),
#  'metallic blue': array([ 79, 115, 142]),
#  'pale salmon': array([255, 177, 154]),
#  'sap green': array([ 92, 139,  21]),
#  'algae': array([ 84, 172, 104]),
#  'bluey grey': array([137, 160, 176]),
#  'greeny grey': array([126, 160, 122]),
#  'highlighter green': array([ 27, 252,   6]),
#  'light light blue': array([202, 255, 251]),
#  'light mint': array([182, 255, 187]),
#  'raw umber': array([167,  94,   9]),
#  'vivid blue': array([ 21,  46, 255]),
#  'deep lavender': array([141,  94, 183]),
#  'dull teal': array([ 95, 158, 143]),
#  'light greenish blue': array([ 99, 247, 180]),
#  'mud green': array([ 96, 102,   2]),
#  'pinky': array([252, 134, 170]),
#  'red wine': array([140,   0,  52]),
#  'shit green': array([117, 128,   0]),
#  'tan brown': array([171, 126,  76]),
#  'darkblue': array([  3,   7, 100]),
#  'rosa': array([254, 134, 164]),
#  'lipstick': array([213,  23,  78]),
#  'pale mauve': array([254, 208, 252]),
#  'claret': array([104,   0,  24]),
#  'dandelion': array([254, 223,   8]),
#  'orangered': array([254,  66,  15]),
#  'poop green': array([111, 124,   0]),
#  'ruby': array([202,   1,  71]),
#  'dark': array([27, 36, 49]),
#  'greenish turquoise': array([  0, 251, 176]),
#  'pastel red': array([219,  88,  86]),
#  'piss yellow': array([221, 214,  24]),
#  'bright cyan': array([ 65, 253, 254]),
#  'dark coral': array([207,  82,  78]),
#  'algae green': array([ 33, 195, 111]),
#  'darkish red': array([169,   3,   8]),
#  'reddy brown': array([110,  16,   5]),
#  'blush pink': array([254, 130, 140]),
#  'camouflage green': array([75, 97, 19]),
#  'lawn green': array([ 77, 164,   9]),
#  'putty': array([190, 174, 138]),
#  'vibrant blue': array([  3,  57, 248]),
#  'dark sand': array([168, 143,  89]),
#  'purple/blue': array([ 93,  33, 208]),
#  'saffron': array([254, 178,   9]),
#  'twilight': array([ 78,  81, 139]),
#  'warm brown': array([150,  78,   2]),
#  'bluegrey': array([133, 163, 178]),
#  'bubble gum pink': array([255, 105, 175]),
#  'duck egg blue': array([195, 251, 244]),
#  'greenish cyan': array([ 42, 254, 183]),
#  'petrol': array([  0,  95, 106]),
#  'royal': array([ 12,  23, 147]),
#  'butter': array([255, 255, 129]),
#  'dusty orange': array([240, 131,  58]),
#  'off yellow': array([241, 243,  63]),
#  'pale olive green': array([177, 210, 123]),
#  'orangish': array([252, 130,  74]),
#  'leaf': array([113, 170,  52]),
#  'light blue grey': array([183, 201, 226]),
#  'dried blood': array([75,  1,  1]),
#  'lightish purple': array([165,  82, 230]),
#  'rusty red': array([175,  47,  13]),
#  'lavender blue': array([139, 136, 248]),
#  'light grass green': array([154, 247, 100]),
#  'light mint green': array([166, 251, 178]),
#  'sunflower': array([255, 197,  18]),
#  'velvet': array([117,   8,  81]),
#  'brick orange': array([193,  74,   9]),
#  'lightish red': array([254,  47,  74]),
#  'pure blue': array([  2,   3, 226]),
#  'twilight blue': array([ 10,  67, 122]),
#  'violet red': array([165,   0,  85]),
#  'yellowy brown': array([174, 139,  12]),
#  'carnation': array([253, 121, 143]),
#  'muddy yellow': array([191, 172,   5]),
#  'dark seafoam green': array([ 62, 175, 118]),
#  'deep rose': array([199,  71, 103]),
#  'dusty red': array([185,  72,  78]),
#  'grey/blue': array([100, 125, 142]),
#  'lemon lime': array([191, 254,  40]),
#  'purple/pink': array([215,  37, 222]),
#  'brown yellow': array([178, 151,   5]),
#  'purple brown': array([103,  58,  63]),
#  'wisteria': array([168, 125, 194]),
#  'banana yellow': array([250, 254,  75]),
#  'lipstick red': array([192,   2,  47]),
#  'water blue': array([ 14, 135, 204]),
#  'brown grey': array([141, 132, 104]),
#  'vibrant purple': array([173,   3, 222]),
#  'baby green': array([140, 255, 158]),
#  'barf green': array([148, 172,   2]),
#  'eggshell blue': array([196, 255, 247]),
#  'sandy yellow': array([253, 238, 115]),
#  'cool green': array([ 51, 184, 100]),
#  'pale': array([255, 249, 208]),
#  'blue/grey': array([117, 141, 163]),
#  'hot magenta': array([245,   4, 201]),
#  'greyblue': array([119, 161, 181]),
#  'purpley': array([135,  86, 228]),
#  'baby shit green': array([136, 151,  23]),
#  'brownish pink': array([194, 126, 121]),
#  'dark aquamarine': array([  1, 115, 113]),
#  'diarrhea': array([159, 131,   3]),
#  'light mustard': array([247, 213,  96]),
#  'pale sky blue': array([189, 246, 254]),
#  'turtle green': array([117, 184,  79]),
#  'bright olive': array([156, 187,   4]),
#  'dark grey blue': array([41, 70, 91]),
#  'greeny brown': array([105,  96,   6]),
#  'lemon green': array([173, 248,   2]),
#  'light periwinkle': array([193, 198, 252]),
#  'seaweed green': array([ 53, 173, 107]),
#  'sunshine yellow': array([255, 253,  55]),
#  'ugly purple': array([164,  66, 160]),
#  'medium pink': array([243,  97, 150]),
#  'puke brown': array([148, 119,   6]),
#  'very light pink': array([255, 244, 242]),
#  'viridian': array([ 30, 145, 103]),
#  'bile': array([181, 195,   6]),
#  'faded yellow': array([254, 255, 127]),
#  'very pale green': array([207, 253, 188]),
#  'vibrant green': array([ 10, 221,   8]),
#  'bright lime': array([135, 253,   5]),
#  'spearmint': array([ 30, 248, 118]),
#  'light aquamarine': array([123, 253, 199]),
#  'light sage': array([188, 236, 172]),
#  'yellowgreen': array([187, 249,  15]),
#  'baby poo': array([171, 144,   4]),
#  'dark seafoam': array([ 31, 181, 122]),
#  'deep teal': array([ 0, 85, 90]),
#  'heather': array([164, 132, 172]),
#  'rust orange': array([196,  85,   8]),
#  'dirty blue': array([ 63, 130, 157]),
#  'fern green': array([ 84, 141,  68]),
#  'bright lilac': array([201,  94, 251]),
#  'weird green': array([ 58, 229, 127]),
#  'peacock blue': array([  1, 103, 149]),
#  'avocado green': array([135, 169,  34]),
#  'faded orange': array([240, 148,  77]),
#  'grape purple': array([93, 20, 81]),
#  'hot green': array([ 37, 255,  41]),
#  'lime yellow': array([208, 254,  29]),
#  'mango': array([255, 166,  43]),
#  'shamrock': array([  1, 180,  76]),
#  'bubblegum': array([255, 108, 181]),
#  'purplish brown': array([107,  66,  71]),
#  'vomit yellow': array([199, 193,  12]),
#  'pale cyan': array([183, 255, 250]),
#  'key lime': array([174, 255, 110]),
#  'tomato red': array([236,  45,   1]),
#  'lightgreen': array([118, 255, 123]),
#  'merlot': array([115,   0,  57]),
#  'night blue': array([ 4,  3, 72]),
#  'purpleish pink': array([223,  78, 200]),
#  'apple': array([110, 203,  60]),
#  'baby poop green': array([143, 152,   5]),
#  'green apple': array([ 94, 220,  31]),
#  'heliotrope': array([217,  79, 245]),
#  'yellow/green': array([200, 253,  61]),
#  'almost black': array([ 7, 13, 13]),
#  'cool blue': array([ 73, 132, 184]),
#  'leafy green': array([ 81, 183,  59]),
#  'mustard brown': array([172, 126,   4]),
#  'dusk': array([ 78,  84, 129]),
#  'dull brown': array([135, 110,  75]),
#  'frog green': array([ 88, 188,   8]),
#  'vivid green': array([ 47, 239,  16]),
#  'bright light green': array([ 45, 254,  84]),
#  'fluro green': array([ 10, 255,   2]),
#  'kiwi': array([156, 239,  67]),
#  'seaweed': array([ 24, 209, 123]),
#  'navy green': array([53, 83, 10]),
#  'ultramarine blue': array([ 24,   5, 219]),
#  'iris': array([ 98,  88, 196]),
#  'pastel orange': array([255, 150,  79]),
#  'yellowish orange': array([255, 171,  15]),
#  'perrywinkle': array([143, 140, 231]),
#  'tealish': array([ 36, 188, 168]),
#  'dark plum': array([63,  1, 44]),
#  'pear': array([203, 248,  95]),
#  'pinkish orange': array([255, 114,  76]),
#  'midnight purple': array([40,  1, 55]),
#  'light urple': array([179, 111, 246]),
#  'dark mint': array([ 72, 192, 114]),
#  'greenish tan': array([188, 203, 122]),
#  'light burgundy': array([168,  65,  91]),
#  'turquoise blue': array([  6, 177, 196]),
#  'ugly pink': array([205, 117, 132]),
#  'sandy': array([241, 218, 122]),
#  'electric pink': array([255,   4, 144]),
#  'muted purple': array([128,  91, 135]),
#  'mid green': array([ 80, 167,  71]),
#  'greyish': array([168, 164, 149]),
#  'neon yellow': array([207, 255,   4]),
#  'banana': array([255, 255, 126]),
#  'carnation pink': array([255, 127, 167]),
#  'tomato': array([239,  64,  38]),
#  'sea': array([ 60, 153, 146]),
#  'muddy brown': array([136, 104,   6]),
#  'turquoise green': array([  4, 244, 137]),
#  'buff': array([254, 246, 158]),
#  'fawn': array([207, 175, 123]),
#  'muted blue': array([ 59, 113, 159]),
#  'pale rose': array([253, 193, 197]),
#  'dark mint green': array([ 32, 192, 115]),
#  'amethyst': array([155,  95, 192]),
#  'blue/green': array([ 15, 155, 142]),
#  'chestnut': array([116,  40,   2]),
#  'sick green': array([157, 185,  44]),
#  'pea': array([164, 191,  32]),
#  'rusty orange': array([205,  89,   9]),
#  'stone': array([173, 165, 135]),
#  'rose red': array([190,   1,  60]),
#  'pale aqua': array([184, 255, 235]),
#  'deep orange': array([220,  77,   1]),
#  'earth': array([162, 101,  62]),
#  'mossy green': array([ 99, 139,  39]),
#  'grassy green': array([ 65, 156,   3]),
#  'pale lime green': array([177, 255, 101]),
#  'light grey blue': array([157, 188, 212]),
#  'pale grey': array([253, 253, 254]),
#  'asparagus': array([119, 171,  86]),
#  'blueberry': array([ 70,  65, 150]),
#  'purple red': array([153,   1,  71]),
#  'pale lime': array([190, 253, 115]),
#  'greenish teal': array([ 50, 191, 132]),
#  'caramel': array([175, 111,   9]),
#  'deep magenta': array([160,   2,  92]),
#  'light peach': array([255, 216, 177]),
#  'milk chocolate': array([127,  78,  30]),
#  'ocher': array([191, 155,  12]),
#  'off green': array([107, 163,  83]),
#  'purply pink': array([240, 117, 230]),
#  'lightblue': array([123, 200, 246]),
#  'dusky blue': array([ 71,  95, 148]),
#  'golden': array([245, 191,   3]),
#  'light beige': array([255, 254, 182]),
#  'butter yellow': array([255, 253, 116]),
#  'dusky purple': array([137,  91, 123]),
#  'french blue': array([ 67, 107, 173]),
#  'ugly yellow': array([208, 193,   1]),
#  'greeny yellow': array([198, 248,   8]),
#  'orangish red': array([244,  54,   5]),
#  'shamrock green': array([  2, 193,  77]),
#  'orangish brown': array([178,  95,   3]),
#  'tree green': array([ 42, 126,  25]),
#  'deep violet': array([73,  6, 72]),
#  'gunmetal': array([ 83,  98, 103]),
#  'blue/purple': array([ 90,   6, 239]),
#  'cherry': array([207,   2,  52]),
#  'sandy brown': array([196, 166,  97]),
#  'warm grey': array([151, 138, 132]),
#  'dark indigo': array([31,  9, 84]),
#  'midnight': array([ 3,  1, 45]),
#  'bluey green': array([ 43, 177, 121]),
#  'grey pink': array([195, 144, 155]),
#  'soft purple': array([166, 111, 181]),
#  'blood': array([119,   0,   1]),
#  'brown red': array([146,  43,   5]),
#  'medium grey': array([125, 127, 124]),
#  'berry': array([153,  15,  75]),
#  'poo': array([143, 115,   3]),
#  'purpley pink': array([200,  60, 185]),
#  'light salmon': array([254, 169, 147]),
#  'snot': array([172, 187,  13]),
#  'easter purple': array([192, 113, 254]),
#  'light yellow green': array([204, 253, 127]),
#  'dark navy blue': array([ 0,  2, 46]),
#  'drab': array([130, 131,  68]),
#  'light rose': array([255, 197, 203]),
#  'rouge': array([171,  18,  57]),
#  'purplish red': array([176,   5,  75]),
#  'slime green': array([153, 204,   4]),
#  'baby poop': array([147, 124,   0]),
#  'irish green': array([  1, 149,  41]),
#  'pink/purple': array([239,  29, 231]),
#  'dark navy': array([ 0,  4, 53]),
#  'greeny blue': array([ 66, 179, 149]),
#  'light plum': array([157,  87, 131]),
#  'pinkish grey': array([200, 172, 169]),
#  'dirty orange': array([200, 118,   6]),
#  'rust red': array([170,  39,   4]),
#  'pale lilac': array([228, 203, 255]),
#  'orangey red': array([250,  66,  36]),
#  'primary blue': array([  8,   4, 249]),
#  'kermit green': array([ 92, 178,   0]),
#  'brownish purple': array([118,  66,  78]),
#  'murky green': array([108, 122,  14]),
#  'wheat': array([251, 221, 126]),
#  'very dark purple': array([42,  1, 52]),
#  'bottle green': array([ 4, 74,  5]),
#  'watermelon': array([253,  70,  89]),
#  'deep sky blue': array([ 13, 117, 248]),
#  'fire engine red': array([254,   0,   2]),
#  'yellow ochre': array([203, 157,   6]),
#  'pumpkin orange': array([251, 125,   7]),
#  'pale olive': array([185, 204, 129]),
#  'light lilac': array([237, 200, 255]),
#  'lightish green': array([ 97, 225,  96]),
#  'carolina blue': array([138, 184, 254]),
#  'mulberry': array([146,  10,  78]),
#  'shocking pink': array([254,   2, 162]),
#  'auburn': array([154,  48,   1]),
#  'bright lime green': array([101, 254,   8]),
#  'celadon': array([190, 253, 183]),
#  'pinkish brown': array([177, 114,  97]),
#  'poo brown': array([136,  95,   1]),
#  'bright sky blue': array([  2, 204, 254]),
#  'celery': array([193, 253, 149]),
#  'dirt brown': array([131, 101,  57]),
#  'strawberry': array([251,  41,  67]),
#  'dark lime': array([132, 183,   1]),
#  'copper': array([182,  99,  37]),
#  'medium brown': array([127,  81,  18]),
#  'muted green': array([ 95, 160,  82]),
#  "robin's egg": array([109, 237, 253]),
#  'bright aqua': array([ 11, 249, 234]),
#  'bright lavender': array([199,  96, 255]),
#  'ivory': array([255, 255, 203]),
#  'very light purple': array([246, 206, 252]),
#  'light navy': array([ 21,  80, 132]),
#  'pink red': array([245,   5,  79]),
#  'olive brown': array([100,  84,   3]),
#  'poop brown': array([122,  89,   1]),
#  'mustard green': array([168, 181,   4]),
#  'ocean green': array([ 61, 153, 115]),
#  'very dark blue': array([ 0,  1, 51]),
#  'dusty green': array([118, 169, 115]),
#  'light navy blue': array([ 46,  90, 136]),
#  'minty green': array([ 11, 247, 125]),
#  'adobe': array([189, 108,  72]),
#  'barney': array([172,  29, 184]),
#  'jade green': array([ 43, 175, 106]),
#  'bright light blue': array([ 38, 247, 253]),
#  'light lime': array([174, 253, 108]),
#  'dark khaki': array([155, 143,  85]),
#  'orange yellow': array([255, 173,   1]),
#  'ocre': array([198, 156,   4]),
#  'maize': array([244, 208,  84]),
#  'faded pink': array([222, 157, 172]),
#  'british racing green': array([ 5, 72, 13]),
#  'sandstone': array([201, 174, 116]),
#  'mud brown': array([96, 70, 15]),
#  'light sea green': array([152, 246, 176]),
#  'robin egg blue': array([138, 241, 254]),
#  'aqua marine': array([ 46, 232, 187]),
#  'dark sea green': array([ 17, 135,  93]),
#  'soft pink': array([253, 176, 192]),
#  'orangey brown': array([177,  96,   2]),
#  'cherry red': array([247,   2,  42]),
#  'burnt yellow': array([213, 171,   9]),
#  'brownish grey': array([134, 119,  95]),
#  'camel': array([198, 159,  89]),
#  'purplish grey': array([122, 104, 127]),
#  'marine': array([ 4, 46, 96]),
#  'greyish pink': array([200, 141, 148]),
#  'pale turquoise': array([165, 251, 213]),
#  'pastel yellow': array([255, 254, 113]),
#  'bluey purple': array([ 98,  65, 199]),
#  'canary yellow': array([255, 254,  64]),
#  'faded red': array([211,  73,  78]),
#  'sepia': array([152,  94,  43]),
#  'coffee': array([166, 129,  76]),
#  'bright magenta': array([255,   8, 232]),
#  'mocha': array([157, 118,  81]),
#  'ecru': array([254, 255, 202]),
#  'purpleish': array([152,  86, 141]),
#  'cranberry': array([158,   0,  58]),
#  'darkish green': array([ 40, 124,  55]),
#  'brown orange': array([185, 105,   2]),
#  'dusky rose': array([186, 104, 115]),
#  'melon': array([255, 120,  85]),
#  'sickly green': array([148, 178,  28]),
#  'silver': array([197, 201, 199]),
#  'purply blue': array([102,  26, 238]),
#  'purpleish blue': array([ 97,  64, 239]),
#  'hospital green': array([155, 229, 170]),
#  'shit brown': array([123,  88,   4]),
#  'mid blue': array([ 39, 106, 179]),
#  'amber': array([254, 179,   8]),
#  'easter green': array([140, 253, 126]),
#  'soft blue': array([100, 136, 234]),
#  'cerulean blue': array([  5, 110, 238]),
#  'golden brown': array([178, 122,   1]),
#  'bright turquoise': array([ 15, 254, 249]),
#  'red pink': array([250,  42,  85]),
#  'red purple': array([130,   7,  71]),
#  'greyish brown': array([122, 106,  79]),
#  'vermillion': array([244,  50,  12]),
#  'russet': array([161,  57,   5]),
#  'steel grey': array([111, 130, 138]),
#  'lighter purple': array([165,  90, 244]),
#  'bright violet': array([173,  10, 253]),
#  'prussian blue': array([  0,  69, 119]),
#  'slate green': array([101, 141, 109]),
#  'dirty pink': array([202, 123, 128]),
#  'dark blue green': array([ 0, 82, 73]),
#  'pine': array([43, 93, 52]),
#  'yellowy green': array([191, 241,  40]),
#  'dark gold': array([181, 148,  16]),
#  'bluish': array([ 41, 118, 187]),
#  'darkish blue': array([  1,  65, 130]),
#  'dull red': array([187,  63,  63]),
#  'pinky red': array([252,  38,  71]),
#  'bronze': array([168, 121,   0]),
#  'pale teal': array([130, 203, 178]),
#  'military green': array([102, 124,  62]),
#  'barbie pink': array([254,  70, 165]),
#  'bubblegum pink': array([254, 131, 204]),
#  'pea soup green': array([148, 166,  23]),
#  'dark mustard': array([168, 137,   5]),
#  'shit': array([127,  95,   0]),
#  'medium purple': array([158,  67, 162]),
#  'very dark green': array([ 6, 46,  3]),
#  'dirt': array([138, 110,  69]),
#  'dusky pink': array([204, 122, 139]),
#  'red violet': array([158,   1, 104]),
#  'lemon yellow': array([253, 255,  56]),
#  'pistachio': array([192, 250, 139]),
#  'dull yellow': array([238, 220,  91]),
#  'dark lime green': array([126, 189,   1]),
#  'denim blue': array([ 59,  91, 146]),
#  'teal blue': array([  1, 136, 159]),
#  'lightish blue': array([ 61, 122, 253]),
#  'purpley blue': array([ 95,  52, 231]),
#  'light indigo': array([109,  90, 207]),
#  'swamp green': array([116, 133,   0]),
#  'brown green': array([112, 108,  17]),
#  'dark maroon': array([60,  0,  8]),
#  'hot purple': array([203,   0, 245]),
#  'dark forest green': array([ 0, 45,  4]),
#  'faded blue': array([101, 140, 187]),
#  'drab green': array([116, 149,  81]),
#  'light lime green': array([185, 255, 102]),
#  'snot green': array([157, 193,   0]),
#  'yellowish': array([250, 238, 102]),
#  'light blue green': array([126, 251, 179]),
#  'bordeaux': array([123,   0,  44]),
#  'light mauve': array([194, 146, 161]),
#  'ocean': array([  1, 123, 146]),
#  'marigold': array([252, 192,   6]),
#  'muddy green': array([101, 116,  50]),
#  'dull orange': array([216, 134,  59]),
#  'steel': array([115, 133, 149]),
#  'electric purple': array([170,  35, 255]),
#  'fluorescent green': array([  8, 255,   8]),
#  'yellowish brown': array([155, 122,   1]),
#  'blush': array([242, 158, 142]),
#  'soft green': array([111, 194, 118]),
#  'bright orange': array([255,  91,   0]),
#  'lemon': array([253, 255,  82]),
#  'purple grey': array([134, 111, 133]),
#  'acid green': array([143, 254,   9]),
#  'pale lavender': array([238, 207, 254]),
#  'violet blue': array([ 81,  10, 201]),
#  'light forest green': array([ 79, 145,  83]),
#  'burnt red': array([159,  35,   5]),
#  'khaki green': array([114, 134,  57]),
#  'cerise': array([222,  12,  98]),
#  'faded purple': array([145, 110, 153]),
#  'apricot': array([255, 177, 109]),
#  'dark olive green': array([60, 77,  3]),
#  'grey brown': array([127, 112,  83]),
#  'green grey': array([119, 146, 111]),
#  'true blue': array([  1,  15, 204]),
#  'pale violet': array([206, 174, 250]),
#  'periwinkle blue': array([143, 153, 251]),
#  'light sky blue': array([198, 252, 255]),
#  'blurple': array([ 85,  57, 204]),
#  'green brown': array([84, 78,  3]),
#  'bluegreen': array([  1, 122, 121]),
#  'bright teal': array([  1, 249, 198]),
#  'brownish yellow': array([201, 176,   3]),
#  'pea soup': array([146, 153,   1]),
#  'forest': array([11, 85,  9]),
#  'barney purple': array([160,   4, 152]),
#  'ultramarine': array([ 32,   0, 177]),
#  'purplish': array([148,  86, 140]),
#  'puke yellow': array([194, 190,  14]),
#  'bluish grey': array([116, 139, 151]),
#  'dark periwinkle': array([102,  95, 209]),
#  'dark lilac': array([156, 109, 165]),
#  'reddish': array([196,  66,  64]),
#  'light maroon': array([162,  72,  87]),
#  'dusty purple': array([130,  95, 135]),
#  'terra cotta': array([201, 100,  59]),
#  'avocado': array([144, 177,  52]),
#  'marine blue': array([  1,  56, 106]),
#  'teal green': array([ 37, 163, 111]),
#  'slate grey': array([ 89, 101, 109]),
#  'lighter green': array([117, 253,  99]),
#  'electric green': array([ 33, 252,  13]),
#  'dusty blue': array([ 90, 134, 173]),
#  'golden yellow': array([254, 198,  21]),
#  'bright yellow': array([255, 253,   1]),
#  'light lavender': array([223, 197, 254]),
#  'umber': array([178, 100,   0]),
#  'poop': array([127,  94,   0]),
#  'dark peach': array([222, 126,  93]),
#  'jungle green': array([  4, 130,  67]),
#  'eggshell': array([255, 255, 212]),
#  'denim': array([ 59,  99, 140]),
#  'yellow brown': array([183, 148,   0]),
#  'dull purple': array([132,  89, 126]),
#  'chocolate brown': array([65, 25,  0]),
#  'wine red': array([123,   3,  35]),
#  'neon blue': array([  4, 217, 255]),
#  'dirty green': array([102, 126,  44]),
#  'light tan': array([251, 238, 172]),
#  'ice blue': array([215, 255, 254]),
#  'cadet blue': array([ 78, 116, 150]),
#  'dark mauve': array([135,  76,  98]),
#  'very light blue': array([213, 255, 255]),
#  'grey purple': array([130, 109, 140]),
#  'pastel pink': array([255, 186, 205]),
#  'very light green': array([209, 255, 189]),
#  'dark sky blue': array([ 68, 142, 228]),
#  'evergreen': array([ 5, 71, 42]),
#  'dull pink': array([213, 134, 157]),
#  'aubergine': array([61,  7, 52]),
#  'mahogany': array([74,  1,  0]),
#  'reddish orange': array([248,  72,  28]),
#  'deep green': array([ 2, 89, 15]),
#  'vomit green': array([137, 162,   3]),
#  'purple pink': array([224,  63, 216]),
#  'dusty pink': array([213, 138, 148]),
#  'faded green': array([123, 178, 116]),
#  'camo green': array([ 82, 101,  37]),
#  'pinky purple': array([201,  76, 190]),
#  'pink purple': array([219,  75, 218]),
#  'brownish red': array([158,  54,  35]),
#  'dark rose': array([181,  72,  93]),
#  'mud': array([115,  92,  18]),
#  'brownish': array([156, 109,  87]),
#  'emerald green': array([  2, 143,  30]),
#  'pale brown': array([177, 145, 110]),
#  'dull blue': array([ 73, 117, 156]),
#  'burnt umber': array([160,  69,  14]),
#  'medium green': array([ 57, 173,  72]),
#  'clay': array([182, 106,  80]),
#  'light aqua': array([140, 255, 219]),
#  'light olive green': array([164, 190,  92]),
#  'brownish orange': array([203, 119,  35]),
#  'dark aqua': array([  5, 105, 107]),
#  'purplish pink': array([206,  93, 174]),
#  'dark salmon': array([200,  90,  83]),
#  'greenish grey': array([150, 174, 141]),
#  'jade': array([ 31, 167, 116]),
#  'ugly green': array([122, 151,   3]),
#  'dark beige': array([172, 147,  98]),
#  'emerald': array([  1, 160,  73]),
#  'pale red': array([217,  84,  77]),
#  'light magenta': array([250,  95, 247]),
#  'sky': array([130, 202, 252]),
#  'light cyan': array([172, 255, 252]),
#  'yellow orange': array([252, 176,   1]),
#  'reddish purple': array([145,   9,  81]),
#  'reddish pink': array([254,  44,  84]),
#  'orchid': array([200, 117, 196]),
#  'dirty yellow': array([205, 197,  10]),
#  'orange red': array([253,  65,  30]),
#  'deep red': array([154,   2,   0]),
#  'orange brown': array([190, 100,   0]),
#  'cobalt blue': array([  3,  10, 167]),
#  'neon pink': array([254,   1, 154]),
#  'rose pink': array([247, 135, 154]),
#  'greyish purple': array([136, 113, 145]),
#  'raspberry': array([176,   1,  73]),
#  'aqua green': array([ 18, 225, 147]),
#  'salmon pink': array([254, 123, 124]),
#  'tangerine': array([255, 148,   8]),
#  'brownish green': array([106, 110,   9]),
#  'red brown': array([139,  46,  22]),
#  'greenish brown': array([105,  97,  18]),
#  'pumpkin': array([225, 119,   1]),
#  'pine green': array([10, 72, 30]),
#  'charcoal': array([52, 56, 55]),
#  'baby pink': array([255, 183, 206]),
#  'cornflower': array([106, 121, 247]),
#  'blue violet': array([ 93,   6, 233]),
#  'chocolate': array([61, 28,  2]),
#  'greyish green': array([130, 166, 125]),
#  'scarlet': array([190,   1,  25]),
#  'green yellow': array([201, 255,  39]),
#  'dark olive': array([55, 62,  2]),
#  'sienna': array([169,  86,  30]),
#  'pastel purple': array([202, 160, 255]),
#  'terracotta': array([202, 102,  65]),
#  'aqua blue': array([  2, 216, 233]),
#  'sage green': array([136, 179, 120]),
#  'blood red': array([152,   0,   2]),
#  'deep pink': array([203,   1,  98]),
#  'grass': array([ 92, 172,  45]),
#  'moss': array([118, 153,  88]),
#  'pastel blue': array([162, 191, 254]),
#  'bluish green': array([ 16, 166, 116]),
#  'green blue': array([  6, 180, 139]),
#  'dark tan': array([175, 136,  74]),
#  'greenish blue': array([ 11, 139, 135]),
#  'pale orange': array([255, 167,  86]),
#  'vomit': array([162, 164,  21]),
#  'forrest green': array([21, 68,  6]),
#  'dark lavender': array([133, 103, 152]),
#  'dark violet': array([52,  1, 63]),
#  'purple blue': array([ 99,  45, 233]),
#  'dark cyan': array([ 10, 136, 138]),
#  'olive drab': array([111, 118,  50]),
#  'pinkish': array([212, 106, 126]),
#  'cobalt': array([ 30,  72, 143]),
#  'neon purple': array([188,  19, 254]),
#  'light turquoise': array([126, 244, 204]),
#  'apple green': array([118, 205,  38]),
#  'dull green': array([116, 166,  98]),
#  'wine': array([128,   1,  63]),
#  'powder blue': array([177, 209, 252]),
#  'off white': array([255, 255, 228]),
#  'electric blue': array([  6,  82, 255]),
#  'dark turquoise': array([ 4, 92, 90]),
#  'blue purple': array([ 87,  41, 206]),
#  'azure': array([  6, 154, 243]),
#  'bright red': array([255,   0,  13]),
#  'pinkish red': array([241,  12,  69]),
#  'cornflower blue': array([ 81, 112, 215]),
#  'light olive': array([172, 191, 105]),
#  'grape': array([108,  52,  97]),
#  'greyish blue': array([ 94, 129, 157]),
#  'purplish blue': array([ 96,  30, 249]),
#  'yellowish green': array([176, 221,  22]),
#  'greenish yellow': array([205, 253,   2]),
#  'medium blue': array([ 44, 111, 187]),
#  'dusty rose': array([192, 115, 122]),
#  'light violet': array([214, 180, 252]),
#  'midnight blue': array([ 2,  0, 53]),
#  'bluish purple': array([112,  59, 231]),
#  'red orange': array([253,  60,   6]),
#  'dark magenta': array([150,   0,  86]),
#  'greenish': array([ 64, 163, 104]),
#  'ocean blue': array([  3, 113, 156]),
#  'coral': array([252,  90,  80]),
#  'cream': array([255, 255, 194]),
#  'reddish brown': array([127,  43,  10]),
#  'burnt sienna': array([176,  78,  15]),
#  'brick': array([160,  54,  35]),
#  'sage': array([135, 174, 115]),
#  'grey green': array([120, 155, 115]),
#  'white': array([255, 255, 255]),
#  "robin's egg blue": array([152, 239, 249]),
#  'moss green': array([101, 139,  56]),
#  'steel blue': array([ 90, 125, 154]),
#  'eggplant': array([56,  8, 53]),
#  'light yellow': array([255, 254, 122]),
#  'leaf green': array([ 92, 169,   4]),
#  'light grey': array([216, 220, 214]),
#  'puke': array([165, 165,   2]),
#  'pinkish purple': array([214,  72, 215]),
#  'sea blue': array([  4, 116, 149]),
#  'pale purple': array([183, 144, 212]),
#  'slate blue': array([ 91, 124, 153]),
#  'blue grey': array([ 96, 124, 142]),
#  'hunter green': array([11, 64,  8]),
#  'fuchsia': array([237,  13, 217]),
#  'crimson': array([140,   0,  15]),
#  'pale yellow': array([255, 255, 132]),
#  'ochre': array([191, 144,   5]),
#  'mustard yellow': array([210, 189,  10]),
#  'light red': array([255,  71,  76]),
#  'cerulean': array([  4, 133, 209]),
#  'pale pink': array([255, 207, 220]),
#  'deep blue': array([  4,   2, 115]),
#  'rust': array([168,  60,   9]),
#  'light teal': array([144, 228, 193]),
#  'slate': array([ 81, 101, 114]),
#  'goldenrod': array([250, 194,   5]),
#  'dark yellow': array([213, 182,  10]),
#  'dark grey': array([54, 55, 55]),
#  'army green': array([75, 93, 22]),
#  'grey blue': array([107, 139, 164]),
#  'seafoam': array([128, 249, 173]),
#  'puce': array([165, 126,  82]),
#  'spring green': array([169, 249, 113]),
#  'dark orange': array([198,  81,   2]),
#  'sand': array([226, 202, 118]),
#  'pastel green': array([176, 255, 157]),
#  'mint': array([159, 254, 176]),
#  'light orange': array([253, 170,  72]),
#  'bright pink': array([254,   1, 177]),
#  'chartreuse': array([193, 248,  10]),
#  'deep purple': array([54,  1, 63]),
#  'dark brown': array([52, 28,  2]),
#  'taupe': array([185, 162, 129]),
#  'pea green': array([142, 171,  18]),
#  'puke green': array([154, 174,   7]),
#  'kelly green': array([  2, 171,  46]),
#  'seafoam green': array([122, 249, 171]),
#  'blue green': array([ 19, 126, 109]),
#  'khaki': array([170, 166,  98]),
#  'burgundy': array([97,  0, 35]),
#  'dark teal': array([ 1, 77, 78]),
#  'brick red': array([143,  20,   2]),
#  'royal purple': array([ 75,   0, 110]),
#  'plum': array([88, 15, 65]),
#  'mint green': array([143, 255, 159]),
#  'gold': array([219, 180,  12]),
#  'baby blue': array([162, 207, 254]),
#  'yellow green': array([192, 251,  45]),
#  'bright purple': array([190,   3, 253]),
#  'dark red': array([132,   0,   0]),
#  'pale blue': array([208, 254, 254]),
#  'grass green': array([ 63, 155,  11]),
#  'navy': array([ 1, 21, 62]),
#  'aquamarine': array([  4, 216, 178]),
#  'burnt orange': array([192,  78,   1]),
#  'neon green': array([ 12, 255,  12]),
#  'bright blue': array([  1, 101, 252]),
#  'rose': array([207,  98, 117]),
#  'light pink': array([255, 209, 223]),
#  'mustard': array([206, 179,   1]),
#  'indigo': array([ 56,   2, 130]),
#  'lime': array([170, 255,  50]),
#  'sea green': array([ 83, 252, 161]),
#  'periwinkle': array([142, 130, 254]),
#  'dark pink': array([203,  65, 107]),
#  'olive green': array([103, 122,   4]),
#  'peach': array([255, 176, 124]),
#  'pale green': array([199, 253, 181]),
#  'light brown': array([173, 129,  80]),
#  'hot pink': array([255,   2, 141]),
#  'black': array([0, 0, 0]),
#  'lilac': array([206, 162, 253]),
#  'navy blue': array([ 0, 17, 70]),
#  'royal blue': array([  5,   4, 170]),
#  'beige': array([230, 218, 166]),
#  'salmon': array([255, 121, 108]),
#  'olive': array([110, 117,  14]),
#  'maroon': array([101,   0,  33]),
#  'bright green': array([  1, 255,   7]),
#  'dark purple': array([53,  6, 62]),
#  'mauve': array([174, 113, 129]),
#  'forest green': array([ 6, 71, 12]),
#  'aqua': array([ 19, 234, 201]),
#  'cyan': array([  0, 255, 255]),
#  'tan': array([209, 178, 111]),
#  'dark blue': array([ 0,  3, 91]),
#  'lavender': array([199, 159, 239]),
#  'turquoise': array([  6, 194, 172]),
#  'dark green': array([ 3, 53,  0]),
#  'violet': array([154,  14, 234]),
#  'light purple': array([191, 119, 246]),
#  'lime green': array([137, 254,   5]),
#  'grey': array([146, 149, 145]),
#  'sky blue': array([117, 187, 253]),
#  'yellow': array([255, 255,  20]),
#  'magenta': array([194,   0, 120]),
#  'light green': array([150, 249, 123]),
#  'orange': array([249, 115,   6]),
#  'teal': array([  2, 147, 134]),
#  'light blue': array([149, 208, 252]),
#  'red': array([229,   0,   0]),
#  'brown': array([101,  55,   0]),
#  'pink': array([255, 129, 192]),
#  'blue': array([  3,  67, 223]),
#  'green': array([ 21, 176,  26]),
#  'purple': array([126,  30, 156])}

# %%
colors['aqua'] - colors['blue']
# Out:
# array([ 16, 167, -22])

# %%
colors['blue']
# Out:
# array([  3,  67, 223])

# %%
(colors['white'] + colors['black']) / 2
# Out:
# array([127.5, 127.5, 127.5])

# %%
# !pip install simpleneighbors
# Out:
# Collecting simpleneighbors
#   Downloading https://files.pythonhosted.org/packages/a2/8e/b8ca38e4305bdf5c4cac5d9bf4b65022a2d3641a978b28ce92f9e4063c7b/simpleneighbors-0.0.1-py2.py3-none-any.whl
# Requirement already satisfied: annoy in /home/dangalf/anaconda3/lib/python3.6/site-packages (from simpleneighbors) (1.15.1)
# Installing collected packages: simpleneighbors
# Successfully installed simpleneighbors-0.0.1

# %%
from simpleneighbors import SimpleNeighbors

# %%
color_lookup = SimpleNeighbors(3, 'euclidean')
for name, vec in colors.items():
    color_lookup.add_one(name, vec)
color_lookup.build()

# %%
color_lookup.nearest(colors['red'])
# Out:
# ['red',
#  'fire engine red',
#  'bright red',
#  'tomato red',
#  'cherry red',
#  'scarlet',
#  'vermillion',
#  'orangish red',
#  'cherry',
#  'lipstick red',
#  'darkish red',
#  'neon red']

# %%
color_lookup.nearest([10, 133, 100])
# Out:
# ['dark sea green',
#  'blue green',
#  'viridian',
#  'dark aquamarine',
#  'bluegreen',
#  'deep turquoise',
#  'dark aqua',
#  'deep aqua',
#  'jungle green',
#  'greenish blue',
#  'bluish green',
#  'teal']

# %%
color_lookup.nearest(colors['purple'] - colors['red'])
# Out:
# ['cobalt blue',
#  'royal blue',
#  'darkish blue',
#  'true blue',
#  'royal',
#  'prussian blue',
#  'dark royal blue',
#  'deep blue',
#  'marine blue',
#  'deep sea blue',
#  'darkblue',
#  'twilight blue']

# %%
color_lookup.nearest(colors['green'] + colors['blue'])
# Out:
# ['bright turquoise',
#  'bright light blue',
#  'bright aqua',
#  'cyan',
#  'neon blue',
#  'aqua blue',
#  'bright cyan',
#  'bright sky blue',
#  'aqua',
#  'bright teal',
#  'aqua marine',
#  'greenish cyan']

# %%
color_lookup.nearest((colors['green'] + colors['blue']) /2)
# Out:
# ['deep aqua',
#  'bluegreen',
#  'deep turquoise',
#  'dark aquamarine',
#  'blue green',
#  'dark cyan',
#  'greenish blue',
#  'ocean',
#  'dark aqua',
#  'sea blue',
#  'teal',
#  'peacock blue']

# %%
 color_lookup.nearest(colors['pink'] * 0.5)
# Out:
# ['dark mauve',
#  'dirty purple',
#  'bruise',
#  'brownish purple',
#  'grape',
#  'purplish brown',
#  'light maroon',
#  'light eggplant',
#  'dull purple',
#  'dusky purple',
#  'light burgundy',
#  'purple brown']

# %% [markdown]
# ### meaning manipulated by arithmetic

# %%
relationship = colors['pink'] - colors['red']
color_lookup.nearest(relationship + colors['blue'])
# Out:
# ['neon blue',
#  'bright sky blue',
#  'bright light blue',
#  'cyan',
#  'bright cyan',
#  'bright turquoise',
#  'clear blue',
#  'azure',
#  'dodger blue',
#  'lightish blue',
#  'sky blue',
#  'aqua blue']

# %% [markdown]
# distributional semantics -- distributional principle
#
# linguistic items with similar characteristics have similar meanings
#
# vector is context the word appeared in (markov modeL)
#
# dimensionality reduction
#
# Glove vectors -- better than word2vec
#
# Spacy

# %%
import spacy

# %%
spacy
# Out:
# <module 'spacy' from '/home/dangalf/anaconda3/lib/python3.6/site-packages/spacy/__init__.py'>

# %%
nlp = spacy.load('en_core_web_md')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-36-614d6de0ab0f> in <module>
# ----> 1 nlp = spacy.load('en_core_web_md')
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      13     if depr_path not in (True, False, None):
#      14         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 15     return util.load_model(name, **overrides)
#      16
#      17
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     117     elif hasattr(name, 'exists'):  # Path or Path-like to model data
#     118         return load_model_from_path(name, **overrides)
# --> 119     raise IOError(Errors.E050.format(name=name))
#     120
#     121
#
# OSError: [E050] Can't find model 'en_core_web_md'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /home/dangalf/anaconda3/lib/python3.6/site-packages (2.0.12)
# Requirement already satisfied: numpy>=1.7 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (1.16.2)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (0.28.0)
# Requirement already satisfied: cymem<1.32,>=1.30 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (1.31.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: thinc<6.11.0,>=6.10.3 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (6.10.3)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: ujson>=1.35 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (1.35)
# Requirement already satisfied: dill<0.3,>=0.2 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (0.2.9)
# Collecting regex==2017.4.5 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/36/62/c0c0d762ffd4ffaf39f372eb8561b8d491a11ace5a7884610424a8b40f95/regex-2017.04.05.tar.gz (601kB)
#     100% |████████████████████████████████| 604kB 38.2MB/s ta 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from spacy) (2.21.0)
# Requirement already satisfied: msgpack<1.0.0,>=0.5.6 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (0.5.6)
# Requirement already satisfied: msgpack-numpy<1.0.0,>=0.4.1 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (0.4.3.2)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (0.9.0.1)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (1.10.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (4.31.1)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: toolz>=0.8.0 in /home/dangalf/anaconda3/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy) (0.9.0)
# Building wheels for collected packages: regex
#   Building wheel for regex (setup.py) ... done
#   Stored in directory: /home/dangalf/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# Successfully built regex
# Installing collected packages: regex
#   Found existing installation: regex 2018.7.11
#     Uninstalling regex-2018.7.11:
#       Successfully uninstalled regex-2018.7.11
# Successfully installed regex-2017.4.5

# %%
nlp = spacy.load('en_core_web_md')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-38-614d6de0ab0f> in <module>
# ----> 1 nlp = spacy.load('en_core_web_md')
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      13     if depr_path not in (True, False, None):
#      14         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 15     return util.load_model(name, **overrides)
#      16
#      17
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     117     elif hasattr(name, 'exists'):  # Path or Path-like to model data
#     118         return load_model_from_path(name, **overrides)
# --> 119     raise IOError(Errors.E050.format(name=name))
#     120
#     121
#
# OSError: [E050] Can't find model 'en_core_web_md'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %% [markdown]
# ## Sounds of Words

# %%
# !pip install pronouncing
# Out:
# Collecting pronouncing
# Collecting cmudict>=0.4.0 (from pronouncing)
#   Using cached https://files.pythonhosted.org/packages/42/bc/606843d7cfe4d82f5a21fc46d1ae8e364ac20c57e68d1ec4190bce4f2734/cmudict-0.4.2-py2.py3-none-any.whl
# Installing collected packages: cmudict, pronouncing
# Successfully installed cmudict-0.4.2 pronouncing-0.2.0

# %%
import pronouncing as pr

# %%
pr.phones_for_word("permit")
# Out:
# ['P ER0 M IH1 T', 'P ER1 M IH2 T']

# %%
phones = pr.phones_for_word("hello")
if len(phones) > 0:
    print(phones[0])
# Out:
# HH AH0 L OW1

# %% [markdown]
# ## find the most common phoneme in a text

# %%
from collections import Counter

# %%
words = open('txt/frost.txt').read().split()

# %%
for word in words:
    word = word.strip(".,").lower()
    phones = pr.phones_for_word(word)
    if len(phones)>0:
        print(word, phones[0].split())
# Out:
# two ['T', 'UW1']
# roads ['R', 'OW1', 'D', 'Z']
# diverged ['D', 'AY0', 'V', 'ER1', 'JH', 'D']
# in ['IH0', 'N']
# a ['AH0']
# yellow ['Y', 'EH1', 'L', 'OW0']
# wood ['W', 'UH1', 'D']
# and ['AH0', 'N', 'D']
# sorry ['S', 'AA1', 'R', 'IY0']
# i ['AY1']
# could ['K', 'UH1', 'D']
# not ['N', 'AA1', 'T']
# travel ['T', 'R', 'AE1', 'V', 'AH0', 'L']
# both ['B', 'OW1', 'TH']
# and ['AH0', 'N', 'D']
# be ['B', 'IY1']
# one ['W', 'AH1', 'N']
# traveler ['T', 'R', 'AE1', 'V', 'AH0', 'L', 'ER0']
# long ['L', 'AO1', 'NG']
# i ['AY1']
# stood ['S', 'T', 'UH1', 'D']
# and ['AH0', 'N', 'D']
# looked ['L', 'UH1', 'K', 'T']
# down ['D', 'AW1', 'N']
# one ['W', 'AH1', 'N']
# as ['AE1', 'Z']
# far ['F', 'AA1', 'R']
# as ['AE1', 'Z']
# i ['AY1']
# could ['K', 'UH1', 'D']
# to ['T', 'UW1']
# where ['W', 'EH1', 'R']
# it ['IH1', 'T']
# bent ['B', 'EH1', 'N', 'T']
# in ['IH0', 'N']
# the ['DH', 'AH0']
# then ['DH', 'EH1', 'N']
# took ['T', 'UH1', 'K']
# the ['DH', 'AH0']
# other ['AH1', 'DH', 'ER0']
# as ['AE1', 'Z']
# just ['JH', 'AH1', 'S', 'T']
# as ['AE1', 'Z']
# fair ['F', 'EH1', 'R']
# and ['AH0', 'N', 'D']
# having ['HH', 'AE1', 'V', 'IH0', 'NG']
# perhaps ['P', 'ER0', 'HH', 'AE1', 'P', 'S']
# the ['DH', 'AH0']
# better ['B', 'EH1', 'T', 'ER0']
# claim ['K', 'L', 'EY1', 'M']
# because ['B', 'IH0', 'K', 'AO1', 'Z']
# it ['IH1', 'T']
# was ['W', 'AA1', 'Z']
# grassy ['G', 'R', 'AE1', 'S', 'IY0']
# and ['AH0', 'N', 'D']
# wanted ['W', 'AO1', 'N', 'T', 'IH0', 'D']
# though ['DH', 'OW1']
# as ['AE1', 'Z']
# for ['F', 'AO1', 'R']
# that ['DH', 'AE1', 'T']
# the ['DH', 'AH0']
# passing ['P', 'AE1', 'S', 'IH0', 'NG']
# there ['DH', 'EH1', 'R']
# had ['HH', 'AE1', 'D']
# worn ['W', 'AO1', 'R', 'N']
# them ['DH', 'EH1', 'M']
# really ['R', 'IH1', 'L', 'IY0']
# about ['AH0', 'B', 'AW1', 'T']
# the ['DH', 'AH0']
# same ['S', 'EY1', 'M']
# and ['AH0', 'N', 'D']
# both ['B', 'OW1', 'TH']
# that ['DH', 'AE1', 'T']
# morning ['M', 'AO1', 'R', 'N', 'IH0', 'NG']
# equally ['IY1', 'K', 'W', 'AH0', 'L', 'IY0']
# lay ['L', 'EY1']
# in ['IH0', 'N']
# leaves ['L', 'IY1', 'V', 'Z']
# no ['N', 'OW1']
# step ['S', 'T', 'EH1', 'P']
# had ['HH', 'AE1', 'D']
# trodden ['T', 'R', 'AA1', 'D', 'AH0', 'N']
# black ['B', 'L', 'AE1', 'K']
# oh ['OW1']
# i ['AY1']
# kept ['K', 'EH1', 'P', 'T']
# the ['DH', 'AH0']
# first ['F', 'ER1', 'S', 'T']
# for ['F', 'AO1', 'R']
# another ['AH0', 'N', 'AH1', 'DH', 'ER0']
# yet ['Y', 'EH1', 'T']
# knowing ['N', 'OW1', 'IH0', 'NG']
# how ['HH', 'AW1']
# way ['W', 'EY1']
# leads ['L', 'IY1', 'D', 'Z']
# on ['AA1', 'N']
# to ['T', 'UW1']
# way ['W', 'EY1']
# i ['AY1']
# doubted ['D', 'AW1', 'T', 'IH0', 'D']
# if ['IH1', 'F']
# i ['AY1']
# should ['SH', 'UH1', 'D']
# ever ['EH1', 'V', 'ER0']
# come ['K', 'AH1', 'M']
# back ['B', 'AE1', 'K']
# i ['AY1']
# shall ['SH', 'AE1', 'L']
# be ['B', 'IY1']
# telling ['T', 'EH1', 'L', 'IH0', 'NG']
# this ['DH', 'IH1', 'S']
# with ['W', 'IH1', 'DH']
# a ['AH0']
# sigh ['S', 'AY1']
# somewhere ['S', 'AH1', 'M', 'W', 'EH2', 'R']
# ages ['EY1', 'JH', 'AH0', 'Z']
# and ['AH0', 'N', 'D']
# ages ['EY1', 'JH', 'AH0', 'Z']
# two ['T', 'UW1']
# roads ['R', 'OW1', 'D', 'Z']
# diverged ['D', 'AY0', 'V', 'ER1', 'JH', 'D']
# in ['IH0', 'N']
# a ['AH0']
# wood ['W', 'UH1', 'D']
# and ['AH0', 'N', 'D']
# i ['AY1']
# took ['T', 'UH1', 'K']
# the ['DH', 'AH0']
# one ['W', 'AH1', 'N']
# less ['L', 'EH1', 'S']
# travelled ['T', 'R', 'AE1', 'V', 'AH0', 'L', 'D']
# by ['B', 'AY1']
# and ['AH0', 'N', 'D']
# that ['DH', 'AE1', 'T']
# has ['HH', 'AE1', 'Z']
# made ['M', 'EY1', 'D']
# all ['AO1', 'L']
# the ['DH', 'AH0']
# difference ['D', 'IH1', 'F', 'ER0', 'AH0', 'N', 'S']

# %%
all_phonemes = []
for word in words:
    word = word.strip(".,").lower()
    phones = pr.phones_for_word(word)
    if len(phones)>0:
#         print(word, phones[0].split())
        all_phonemes.extend(phones[0].split())

# %%
all_phonemes
# Out:
# ['T',
#  'UW1',
#  'R',
#  'OW1',
#  'D',
#  'Z',
#  'D',
#  'AY0',
#  'V',
#  'ER1',
#  'JH',
#  'D',
#  'IH0',
#  'N',
#  'AH0',
#  'Y',
#  'EH1',
#  'L',
#  'OW0',
#  'W',
#  'UH1',
#  'D',
#  'AH0',
#  'N',
#  'D',
#  'S',
#  'AA1',
#  'R',
#  'IY0',
#  'AY1',
#  'K',
#  'UH1',
#  'D',
#  'N',
#  'AA1',
#  'T',
#  'T',
#  'R',
#  'AE1',
#  'V',
#  'AH0',
#  'L',
#  'B',
#  'OW1',
#  'TH',
#  'AH0',
#  'N',
#  'D',
#  'B',
#  'IY1',
#  'W',
#  'AH1',
#  'N',
#  'T',
#  'R',
#  'AE1',
#  'V',
#  'AH0',
#  'L',
#  'ER0',
#  'L',
#  'AO1',
#  'NG',
#  'AY1',
#  'S',
#  'T',
#  'UH1',
#  'D',
#  'AH0',
#  'N',
#  'D',
#  'L',
#  'UH1',
#  'K',
#  'T',
#  'D',
#  'AW1',
#  'N',
#  'W',
#  'AH1',
#  'N',
#  'AE1',
#  'Z',
#  'F',
#  'AA1',
#  'R',
#  'AE1',
#  'Z',
#  'AY1',
#  'K',
#  'UH1',
#  'D',
#  'T',
#  'UW1',
#  'W',
#  'EH1',
#  'R',
#  'IH1',
#  'T',
#  'B',
#  'EH1',
#  'N',
#  'T',
#  'IH0',
#  'N',
#  'DH',
#  'AH0',
#  'DH',
#  'EH1',
#  'N',
#  'T',
#  'UH1',
#  'K',
#  'DH',
#  'AH0',
#  'AH1',
#  'DH',
#  'ER0',
#  'AE1',
#  'Z',
#  'JH',
#  'AH1',
#  'S',
#  'T',
#  'AE1',
#  'Z',
#  'F',
#  'EH1',
#  'R',
#  'AH0',
#  'N',
#  'D',
#  'HH',
#  'AE1',
#  'V',
#  'IH0',
#  'NG',
#  'P',
#  'ER0',
#  'HH',
#  'AE1',
#  'P',
#  'S',
#  'DH',
#  'AH0',
#  'B',
#  'EH1',
#  'T',
#  'ER0',
#  'K',
#  'L',
#  'EY1',
#  'M',
#  'B',
#  'IH0',
#  'K',
#  'AO1',
#  'Z',
#  'IH1',
#  'T',
#  'W',
#  'AA1',
#  'Z',
#  'G',
#  'R',
#  'AE1',
#  'S',
#  'IY0',
#  'AH0',
#  'N',
#  'D',
#  'W',
#  'AO1',
#  'N',
#  'T',
#  'IH0',
#  'D',
#  'DH',
#  'OW1',
#  'AE1',
#  'Z',
#  'F',
#  'AO1',
#  'R',
#  'DH',
#  'AE1',
#  'T',
#  'DH',
#  'AH0',
#  'P',
#  'AE1',
#  'S',
#  'IH0',
#  'NG',
#  'DH',
#  'EH1',
#  'R',
#  'HH',
#  'AE1',
#  'D',
#  'W',
#  'AO1',
#  'R',
#  'N',
#  'DH',
#  'EH1',
#  'M',
#  'R',
#  'IH1',
#  'L',
#  'IY0',
#  'AH0',
#  'B',
#  'AW1',
#  'T',
#  'DH',
#  'AH0',
#  'S',
#  'EY1',
#  'M',
#  'AH0',
#  'N',
#  'D',
#  'B',
#  'OW1',
#  'TH',
#  'DH',
#  'AE1',
#  'T',
#  'M',
#  'AO1',
#  'R',
#  'N',
#  'IH0',
#  'NG',
#  'IY1',
#  'K',
#  'W',
#  'AH0',
#  'L',
#  'IY0',
#  'L',
#  'EY1',
#  'IH0',
#  'N',
#  'L',
#  'IY1',
#  'V',
#  'Z',
#  'N',
#  'OW1',
#  'S',
#  'T',
#  'EH1',
#  'P',
#  'HH',
#  'AE1',
#  'D',
#  'T',
#  'R',
#  'AA1',
#  'D',
#  'AH0',
#  'N',
#  'B',
#  'L',
#  'AE1',
#  'K',
#  'OW1',
#  'AY1',
#  'K',
#  'EH1',
#  'P',
#  'T',
#  'DH',
#  'AH0',
#  'F',
#  'ER1',
#  'S',
#  'T',
#  'F',
#  'AO1',
#  'R',
#  'AH0',
#  'N',
#  'AH1',
#  'DH',
#  'ER0',
#  'Y',
#  'EH1',
#  'T',
#  'N',
#  'OW1',
#  'IH0',
#  'NG',
#  'HH',
#  'AW1',
#  'W',
#  'EY1',
#  'L',
#  'IY1',
#  'D',
#  'Z',
#  'AA1',
#  'N',
#  'T',
#  'UW1',
#  'W',
#  'EY1',
#  'AY1',
#  'D',
#  'AW1',
#  'T',
#  'IH0',
#  'D',
#  'IH1',
#  'F',
#  'AY1',
#  'SH',
#  'UH1',
#  'D',
#  'EH1',
#  'V',
#  'ER0',
#  'K',
#  'AH1',
#  'M',
#  'B',
#  'AE1',
#  'K',
#  'AY1',
#  'SH',
#  'AE1',
#  'L',
#  'B',
#  'IY1',
#  'T',
#  'EH1',
#  'L',
#  'IH0',
#  'NG',
#  'DH',
#  'IH1',
#  'S',
#  'W',
#  'IH1',
#  'DH',
#  'AH0',
#  'S',
#  'AY1',
#  'S',
#  'AH1',
#  'M',
#  'W',
#  'EH2',
#  'R',
#  'EY1',
#  'JH',
#  'AH0',
#  'Z',
#  'AH0',
#  'N',
#  'D',
#  'EY1',
#  'JH',
#  'AH0',
#  'Z',
#  'T',
#  'UW1',
#  'R',
#  'OW1',
#  'D',
#  'Z',
#  'D',
#  'AY0',
#  'V',
#  'ER1',
#  'JH',
#  'D',
#  'IH0',
#  'N',
#  'AH0',
#  'W',
#  'UH1',
#  'D',
#  'AH0',
#  'N',
#  'D',
#  'AY1',
#  'T',
#  'UH1',
#  'K',
#  'DH',
#  'AH0',
#  'W',
#  'AH1',
#  'N',
#  'L',
#  'EH1',
#  'S',
#  'T',
#  'R',
#  'AE1',
#  'V',
#  'AH0',
#  'L',
#  'D',
#  'B',
#  'AY1',
#  'AH0',
#  'N',
#  'D',
#  'DH',
#  'AE1',
#  'T',
#  'HH',
#  'AE1',
#  'Z',
#  'M',
#  'EY1',
#  'D',
#  'AO1',
#  'L',
#  'DH',
#  'AH0',
#  'D',
#  'IH1',
#  'F',
#  'ER0',
#  'AH0',
#  'N',
#  'S']

# %%
Counter(all_phonemes).most_common(12)
# Out:
# [('D', 32),
#  ('AH0', 30),
#  ('T', 29),
#  ('N', 29),
#  ('AE1', 21),
#  ('DH', 19),
#  ('R', 18),
#  ('L', 17),
#  ('Z', 14),
#  ('EH1', 14),
#  ('W', 14),
#  ('S', 14)]

# %%
pr.search("IY1 K IY2")
# Out:
# ['beekeeper', 'beekeepers', 'beekeeping', 'iniki', 'speak-easy']

# %%
pr.search("IY. K IY.")
# Out:
# ['beekeeper',
#  'beekeepers',
#  'beekeeping',
#  'bochicchio',
#  'cheeky',
#  'creaky',
#  'dashiki',
#  'freaky',
#  'geeky',
#  'iniki',
#  'kiki',
#  'koninklijke',
#  'leakey',
#  'leaky',
#  'micciche',
#  'minichiello',
#  'siddiqi',
#  'sneaky',
#  'speak-easy',
#  'squeaky',
#  'tiki',
#  'toshiki',
#  'varricchio',
#  'waikiki',
#  'yeakey']

# %%
#caret is beginning
pr.search("^S")
# Out:
# ['c',
#  "c'est",
#  "c'est",
#  "c's",
#  'c-code',
#  'c-codes',
#  'c-span',
#  "c-span's",
#  'c.',
#  "c.'s",
#  'c.d.s',
#  'c.o.d.',
#  'c.s',
#  'ca',
#  'cabo',
#  'cac',
#  'cacld',
#  'caesar',
#  "caesar's",
#  'caesars',
#  "caesars'",
#  'cama',
#  'cb',
#  'cbc',
#  'cbs',
#  'cc',
#  'ccd',
#  'ccs',
#  'ccs',
#  'cctv',
#  'cd',
#  'cdc',
#  'cdebaca',
#  'cdrom',
#  'cdroms',
#  'cds',
#  'ce',
#  'cea',
#  'cea',
#  'ceara',
#  'cearley',
#  'ceasar',
#  'cease',
#  'cease-fire',
#  'ceased',
#  'ceasefire',
#  'ceasefires',
#  'ceaseless',
#  'ceaselessly',
#  'ceaser',
#  'ceases',
#  'ceasing',
#  'ceballos',
#  'cebu',
#  "cebu's",
#  'cecchi',
#  'cece',
#  'cecelia',
#  'cech',
#  'ceci',
#  'cecil',
#  "cecil's",
#  'cecile',
#  'cecilia',
#  'cecin',
#  'ceco',
#  'cecola',
#  'cecos',
#  'cedar',
#  'cedar-rapids',
#  'cedar-rapids',
#  'cedars',
#  'cede',
#  'ceded',
#  'ceded',
#  'ceder',
#  'cederberg',
#  'cedergren',
#  'cederholm',
#  'cederquist',
#  'cederquist',
#  'cedes',
#  'ceding',
#  'cedras',
#  'cedras',
#  "cedras'",
#  "cedras'",
#  "cedras's",
#  "cedras's",
#  'cedric',
#  'cedric',
#  'cedrone',
#  'cees',
#  'ceiling',
#  'ceilings',
#  'ceja',
#  'cel',
#  'cel',
#  'cela',
#  'celadon',
#  'celandine',
#  'celanese',
#  'celaya',
#  'cele',
#  'celeb',
#  'celebate',
#  'celebrant',
#  'celebrants',
#  'celebrate',
#  'celebrated',
#  'celebrates',
#  'celebrating',
#  'celebration',
#  'celebrations',
#  'celebratory',
#  'celebre',
#  'celebrities',
#  'celebrity',
#  "celebrity's",
#  'celebs',
#  'celerity',
#  'celeron',
#  'celery',
#  'celesta',
#  'celeste',
#  'celestial',
#  'celestin',
#  'celestory',
#  'celia',
#  'celibacy',
#  'celibate',
#  'celica',
#  'celie',
#  'celimene',
#  'celina',
#  'celine',
#  'celio',
#  'celis',
#  'celium',
#  'cell',
#  "cell's",
#  'cella',
#  'cellar',
#  'cellars',
#  'celled',
#  'cellmark',
#  "cellmark's",
#  'cellnet',
#  'cellophane',
#  'cellphone',
#  'cellphones',
#  'cellpro',
#  'cells',
#  "cells'",
#  'cellstar',
#  'cellular',
#  "cellular's",
#  'celluloid',
#  'cellulosa',
#  'cellulose',
#  'celmer',
#  'celnik',
#  'celo',
#  'celo',
#  'celo',
#  'cels',
#  'celsius',
#  'celso',
#  'celt',
#  'celtic',
#  'celtics',
#  "celtics'",
#  'celts',
#  'cement',
#  'cement',
#  'cemented',
#  'cemented',
#  'cementing',
#  'cementos',
#  'cemeteries',
#  'cemetery',
#  'cemetery',
#  'cemp',
#  'cencall',
#  'cencor',
#  'cendejas',
#  'cenergy',
#  'ceniceros',
#  'cenith',
#  "cenith's",
#  'cenozoic',
#  'censer',
#  'censor',
#  'censored',
#  'censoring',
#  'censors',
#  'censorship',
#  'censure',
#  'censured',
#  'census',
#  'censuses',
#  'cent',
#  'centanni',
#  'centaur',
#  "centaur's",
#  'centauri',
#  'centaurs',
#  'centavos',
#  'centel',
#  "centel's",
#  'centenarian',
#  'centenarians',
#  'centenary',
#  'centennial',
#  "centennial's",
#  'centeno',
#  'center',
#  'center',
#  "center's",
#  "center's",
#  'centerbanc',
#  'centerbank',
#  'centered',
#  'centerfielder',
#  'centerfold',
#  'centering',
#  'centerior',
#  'centerpiece',
#  'centerre',
#  "centerre's",
#  'centers',
#  'centers',
#  "centers'",
#  "centers'",
#  'centerville',
#  'centex',
#  'centigrade',
#  'centigram',
#  'centime',
#  'centimes',
#  'centimeter',
#  'centimeters',
#  'centimetre',
#  'centimetres',
#  'centipede',
#  'centner',
#  'centocor',
#  "centocor's",
#  'centoxin',
#  'central',
#  "central's",
#  'centrale',
#  'centralia',
#  'centralism',
#  'centralists',
#  'centrality',
#  'centralization',
#  'centralize',
#  'centralized',
#  'centralizing',
#  'centrally',
#  'centram',
#  'centre',
#  'centrella',
#  'centres',
#  'centrex',
#  'centrifugal',
#  'centrifuge',
#  'centrifuges',
#  'centrist',
#  'centrists',
#  'centro',
#  'centromin',
#  'centronics',
#  'centrust',
#  "centrust's",
#  'cents',
#  'cents',
#  'centuri',
#  'centuries',
#  'centurion',
#  'century',
#  "century's",
#  'cenvill',
#  'ceo',
#  'cep',
#  'cepeda',
#  'cepero',
#  'cephalon',
#  'cephalopod',
#  'cephalosporin',
#  'cephas',
#  'cephus',
#  'cera',
#  'ceraceous',
#  'ceradyne',
#  'ceramic',
#  'ceramics',
#  'cerankosky',
#  'cereal',
#  'cereals',
#  'cerebral',
#  'cerebral',
#  'cerebrally',
#  'ceredase',
#  'ceremonial',
#  'ceremonies',
#  'ceremony',
#  'cereno',
#  'ceres',
#  'cerezo',
#  'cerezo',
#  'cerf',
#  'ceridian',
#  'cerise',
#  'cern',
#  'cerney',
#  'cernuda',
#  "cernuda's",
#  'cerny',
#  'cero',
#  'cerra',
#  'cerritos',
#  'cerro',
#  'cerruti',
#  'cerska',
#  'cert',
#  'certain',
#  'certainly',
#  'certainteed',
#  'certainties',
#  'certainty',
#  'certificate',
#  'certificates',
#  'certification',
#  'certifications',
#  'certified',
#  "certified's",
#  'certifies',
#  'certify',
#  'certifying',
#  'certitude',
#  'certron',
#  'cerus',
#  'cervantes',
#  'cervantez',
#  'cerveceria',
#  'cervenka',
#  'cervesato',
#  'cerveza',
#  'cerveza',
#  'cervical',
#  'cervical',
#  'cervix',
#  'ceryl',
#  'cesar',
#  'cesarz',
#  'cesium',
#  'cespedes',
#  'cessation',
#  'cessna',
#  'cessna',
#  "cessna's",
#  "cessna's",
#  'cesspool',
#  'ceta',
#  'ceta',
#  'cetacean',
#  'cetacean',
#  'cetec',
#  'cetera',
#  'cetus',
#  "cetus's",
#  'cevallos',
#  'cevaxs',
#  'ceylon',
#  'ceylon',
#  'cezanne',
#  "cezanne's",
#  'cfo',
#  'cgi',
#  'cia',
#  'ciaccia',
#  'cialis',
#  'ciba',
#  'ciba',
#  "ciba's",
#  "ciba's",
#  'cibro',
#  'cicada',
#  'cicadas',
#  'cicala',
#  'ciccarone',
#  'cicco',
#  'cicely',
#  'cicero',
#  'cicerone',
#  'cichocki',
#  'cichon',
#  'cichy',
#  'cicio',
#  'cicippio',
#  'cid',
#  'cider',
#  'cie',
#  'cie',
#  'ciel',
#  'ciera',
#  'cieri',
#  'cifelli',
#  'cifra',
#  'cifuentes',
#  'ciga',
#  'cigar',
#  'cigarette',
#  "cigarette's",
#  'cigarettes',
#  'cigars',
#  'cigna',
#  "cigna's",
#  'cihak',
#  'cihlar',
#  'cilag',
#  'cilantro',
#  'cilcorp',
#  'cilento',
#  'ciliates',
#  'cilicia',
#  'ciller',
#  'cilley',
#  'cillo',
#  'cilluffo',
#  'cilva',
#  'cimaglia',
#  'cimarron',
#  'ciments',
#  'ciminero',
#  'cinch',
#  'cinched',
#  'cincinnati',
#  "cincinnati's",
#  'cinco',
#  'cinder',
#  'cinderella',
#  'cinders',
#  'cindie',
#  'cindric',
#  'cindy',
#  "cindy's",
#  'cinelli',
#  'cinema',
#  "cinema's",
#  'cinemark',
#  'cinemas',
#  'cinematic',
#  'cinematographer',
#  'cinematography',
#  'cinemax',
#  'cineplex',
#  "cineplex's",
#  'cinergy',
#  'cingular',
#  'cinnabar',
#  'cinnabon',
#  'cinnaminson',
#  'cinnamon',
#  'cinnamonson',
#  'cinq',
#  'cinque',
#  'cinram',
#  'cinthie',
#  'cintron',
#  'cio',
#  'cipher',
#  'cipolla',
#  'cipollone',
#  'cipollone',
#  'cipri',
#  'cira',
#  'ciraulo',
#  'circa',
#  'circadian',
#  'circle',
#  "circle's",
#  'circled',
#  'circles',
#  'circling',
#  'circling',
#  'circon',
#  'circuit',
#  "circuit's",
#  'circuited',
#  'circuitous',
#  'circuitry',
#  'circuits',
#  'circular',
#  'circularize',
#  'circularizing',
#  'circularly',
#  'circulars',
#  'circulate',
#  'circulated',
#  'circulates',
#  'circulating',
#  'circulation',
#  'circulations',
#  'circulatory',
#  'circumcise',
#  'circumcised',
#  'circumcision',
#  'circumference',
#  'circumnavigate',
#  'circumscribe',
#  'circumscribed',
#  'circumspect',
#  'circumspection',
#  'circumstance',
#  'circumstances',
#  'circumstances',
#  'circumstantial',
#  'circumstantially',
#  'circumvene',
#  'circumvent',
#  'circumvented',
#  'circumventing',
#  'circumvention',
#  'circumvents',
#  'circus',
#  "circus's",
#  'circuses',
#  'cirelli',
#  'ciresi',
#  'ciriaco',
#  'ciriello',
#  'cirigliano',
#  'cirillo',
#  'cirincione',
#  'cirino',
#  'cirkin',
#  'cirone',
#  'ciros',
#  'cirque',
#  'cirrhosis',
#  'cirrincione',
#  'cirrus',
#  'cisar',
#  'cisco',
#  "cisco's",
#  'ciskei',
#  'cisler',
#  'cisler',
#  'cisneros',
#  'cisney',
#  'cissell',
#  'cissie',
#  'cissna',
#  'cist',
#  'cistercian',
#  'cistern',
#  'cisterns',
#  'cit',
#  'citadel',
#  "citadel's",
#  'citation',
#  'citations',
#  'cite',
#  'cited',
#  'cited',
#  'cites',
#  'citgo',
#  'citi',
#  'citibank',
#  "citibank's",
#  'citic',
#  'citicorp',
#  "citicorp's",
#  'citicorps',
#  "citicorps'",
#  'cities',
#  "cities'",
#  'citing',
#  'citisteel',
#  'citizen',
#  'citizen',
#  "citizen's",
#  'citizenry',
#  "citizenry's",
#  'citizens',
#  'citizens',
#  "citizens'",
#  'citizenship',
#  'citric',
#  'citrin',
#  'citrine',
#  'citrix',
#  'citro',
#  'citroen',
#  'citron',
#  'citron',
#  "citron's",
#  "citron's",
#  'citronella',
#  'citrosuco',
#  'citrucel',
#  "citrucel's",
#  'citrus',
#  "citrus's",
#  "citrus's",
#  'city',
#  "city's",
#  'cityfed',
#  'cityplace',
#  'citysearch',
#  'cityside',
#  'citytrust',
#  'citywide',
#  'ciudad',
#  'civet',
#  'civic',
#  'civics',
#  'civil',
#  'civiletti',
#  'civilian',
#  'civilians',
#  'civility',
#  'civilization',
#  'civilizations',
#  'civilize',
#  'civilized',
#  'civilly',
#  'cizik',
#  'cizneros',
#  'clo',
#  'cluj',
#  'cmos',
#  'cmos',
#  'cmu',
#  'cmudict',
#  "cnbc's",
#  'cnet',
#  'cnn',
#  "cnn's",
#  'cnn.com',
#  'cnnfn',
#  'cod',
#  'coelacanth',
#  'cps',
#  'cpu',
#  'crm',
#  'crnkovich',
#  'csi',
#  'cspan',
#  'cspi',
#  'csv',
#  'cus',
#  'cv',
#  'cxc',
#  'cxc',
#  'cy',
#  'cyacq',
#  'cyan',
#  'cyanamid',
#  "cyanamid's",
#  'cyanazine',
#  'cyanide',
#  'cyanide',
#  'cyanuric',
#  'cyb',
#  'cyb',
#  'cyber',
#  'cybercash',
#  'cyberporn',
#  'cybersex',
#  'cyberspace',
#  "cyberspace's",
#  'cybertrend',
#  'cybertrends',
#  'cybill',
#  'cyborg',
#  'cyborgs',
#  'cycads',
#  'cycare',
#  'cyclades',
#  'cyclades',
#  'cyclamen',
#  'cycle',
#  'cycled',
#  'cycles',
#  'cyclic',
#  'cyclical',
#  'cyclical',
#  'cyclicality',
#  'cyclicals',
#  'cycling',
#  'cycling',
#  'cyclist',
#  'cyclist',
#  'cyclists',
#  'cyclists',
#  'cyclists',
#  'cyclists',
#  'cyclohexane',
#  'cyclone',
#  'cyclones',
#  'cyclopean',
#  'cyclops',
#  "cyclops's",
#  'cyclosporine',
#  'cyclostome',
#  'cyclostomes',
#  'cyclotron',
#  'cycolor',
#  'cyd',
#  'cydonia',
#  'cydrome',
#  'cyert',
#  'cygan',
#  'cygne',
#  'cygnus',
#  'cyhexatin',
#  'cylinder',
#  'cylinder',
#  'cylinders',
#  'cylindrical',
#  'cylindrical',
#  'cymbal',
#  'cymbals',
#  'cymrot',
#  'cyndi',
#  'cynic',
#  'cynical',
#  'cynically',
#  'cynically',
#  'cynicism',
#  'cynics',
#  'cynosure',
#  'cynric',
#  'cynth',
#  'cynthia',
#  "cynthia's",
#  'cynthie',
#  'cynwyd',
#  'cypert',
#  'cypher',
#  'cyphers',
#  'cyphert',
#  'cypress',
#  'cypress',
#  "cypress's",
#  'cyprian',
#  'cypriot',
#  'cypriot',
#  'cypriots',
#  'cypriots',
#  'cypris',
#  'cyprus',
#  'cyr',
#  'cyrano',
#  'cyrenius',
#  'cyril',
#  'cyrilla',
#  'cyrillic',
#  'cyrix',
#  'cyrix',
#  "cyrix's",
#  "cyrix's",
#  'cyrofin',
#  'cyrus',
#  'cyst',
#  'cystic',
#  'cysts',
#  'cytherea',
#  'cytogen',
#  'cytology',
#  'cytomegalovirus',
#  'cytoplasm',
#  'cytoplasmic',
#  'cytotech',
#  'cytotechs',
#  'czartoryski',
#  'psalm',
#  'psalm',
#  'psalms',
#  'psalms',
#  'psalter',
#  'psalters',
#  'psarouthakis',
#  'psencik',
#  'pseudo',
#  'pseudomonas',
#  'pseudonym',
#  'pseudonyms',
#  'pseudopodial',
#  'pseudoscience',
#  'pseudoscientific',
#  'psi',
#  'psilocybin',
#  'psoriasis',
#  'psych',
#  'psyche',
#  'psyched',
#  'psychedelic',
#  'psyches',
#  'psychiatric',
#  'psychiatrist',
#  "psychiatrist's",
#  'psychiatrists',
#  'psychiatry',
#  'psychiatry',
#  'psychic',
#  'psychical',
#  'psychics',
#  'psycho',
#  'psycho-social',
#  'psychoanalysis',
#  'psychoanalysis',
#  'psychoanalyst',
#  'psychoanalytic',
#  'psychobabble',
#  'psychodynamic',
#  'psychogenic',
#  'psychokinesis',
#  'psychological',
#  'psychologically',
#  'psychologist',
#  'psychologists',
#  'psychology',
#  'psychopath',
#  'psychopathic',
#  'psychopathologies',
#  'psychopathology',
#  'psychopaths',
#  'psychopathy',
#  'psychosis',
#  'psychosocial',
#  'psychosomatic',
#  'psychotherapeutic',
#  'psychotherapist',
#  'psychotherapists',
#  'psychotherapy',
#  'psychotic',
#  'psyllium',
#  'sa',
#  'saab',
#  "saab's",
#  'saad',
#  'saal',
#  'saam',
#  'saamstaan',
#  'saar',
#  'saari',
#  'saarinen',
#  'saarinen',
#  'saas',
#  'saatchi',
#  "saatchi's",
#  'saathoff',
#  'saavedra',
#  "sab's",
#  'saba',
#  'sabah',
#  'sabala',
#  'sabalan',
#  'saban',
#  'sabas',
#  'sabat',
#  'sabatine',
#  'sabatini',
#  'sabatino',
#  'sabatista',
#  "sabatista's",
#  'sabatistas',
#  "sabatistas'",
#  'sabatka',
#  'sabato',
#  'sabaudia',
#  'sabb',
#  'sabbagh',
#  'sabbath',
#  'sabbaths',
#  'sabbatical',
#  'sabbaticals',
#  'sabedra',
#  'sabel',
#  'sabella',
#  'sabena',
#  'saber',
#  'saberbein',
#  "saberbein's",
#  'sabers',
#  'sabertech',
#  'sabey',
#  'sabia',
#  'sabin',
#  'sabina',
#  'sabine',
#  "sabine's",
#  'sabino',
#  'sabins',
#  'sabir',
#  'sabir',
#  'sablan',
#  'sable',
#  'sables',
#  'sabo',
#  'sabol',
#  "sabol's",
#  'sabortech',
#  'sabotage',
#  'sabotaged',
#  'sabotaging',
#  'saboteur',
#  'saboteurs',
#  'saboteurs',
#  'sabourin',
#  'sabra',
#  'sabre',
#  'sabres',
#  'sabretech',
#  'sabrina',
#  'sabry',
#  'sabta',
#  'sabunuma',
#  'sac',
#  'sacca',
#  'saccharin',
#  'saccharine',
#  'sacco',
#  "sacco's",
#  'saccoccio',
#  'saccomanno',
#  'saccone',
#  'saccule',
#  'sacha',
#  'sachdev',
#  'sacher',
#  'sacher',
#  'sachet',
#  'sachi',
#  'sachin',
#  'sachs',
#  'sachs',
#  "sachs'",
#  "sachs's",
#  'sachse',
#  'sacilor',
#  'sacirbey',
#  "sacirbey's",
#  'sack',
#  'sacked',
#  'sackett',
#  'sacking',
#  'sackler',
#  'sackman',
#  'sackmann',
#  'sackrider',
#  'sacks',
#  'sacksteder',
#  'sackville',
#  'saco',
#  'sacra',
#  'sacrament',
#  'sacramental',
#  'sacramento',
#  "sacramento's",
#  'sacraments',
#  'sacred',
#  'sacred',
#  'sacredness',
#  'sacrifice',
#  'sacrificed',
#  'sacrifices',
#  'sacrificial',
#  'sacrificing',
#  'sacrilege',
#  'sacrilegious',
#  'sacrosanct',
#  'sacs',
#  'sad',
#  'sada',
#  'sadaka',
#  'sadako',
#  'sadao',
#  'sadat',
#  'sadat',
#  "sadat's",
#  "sadat's",
#  'saddam',
#  'saddam',
#  "saddam's",
#  "saddam's",
#  'sadden',
#  'saddened',
#  'saddening',
#  'saddening',
#  'saddens',
#  'sadder',
#  'saddest',
#  'saddle',
#  'saddlebag',
#  ...]

# %%
# $ is end
pr.search("B AH. L$")
# Out:
# ['abel',
#  'abell',
#  'able',
#  'abominable',
#  'acceptable',
#  'acceptable',
#  'accessible',
#  'accountable',
#  'accountable',
#  'achievable',
#  'acknowledgeable',
#  'actionable',
#  'adabelle',
#  'adaptable',
#  'addressable',
#  'adjustable',
#  'admirable',
#  'admirable',
#  'admissible',
#  'adoptable',
#  'adorabelle',
#  'adorable',
#  'advisable',
#  'affable',
#  'affordable',
#  'agreeable',
#  'agregable',
#  'allowable',
#  'amabelle',
#  'amabile',
#  'amble',
#  'amenable',
#  'amenable',
#  'amendable',
#  'amiable',
#  'amicable',
#  'anable',
#  'analyzable',
#  'anibal',
#  'annabelle',
#  'annable',
#  'answerable',
#  'appealable',
#  'applicable',
#  'appreciable',
#  'approachable',
#  'approvable',
#  'arable',
#  'arbel',
#  'arguable',
#  'assemble',
#  'attainable',
#  'attributable',
#  'aubel',
#  'auble',
#  'audible',
#  'augmentable',
#  'available',
#  'avitabile',
#  'avoidable',
#  'babble',
#  'babel',
#  'bankable',
#  'bauble',
#  'bearable',
#  'believable',
#  'berkebile',
#  'bible',
#  'biddable',
#  'biebel',
#  'billable',
#  'biodegradable',
#  'bobble',
#  'brackbill',
#  'bramble',
#  'breakable',
#  'brechbill',
#  'bubble',
#  'bubel',
#  'buildable',
#  'bumble',
#  'burble',
#  'burnable',
#  'cable',
#  'callable',
#  'cambell',
#  'campbell',
#  'cannibal',
#  'capable',
#  'cauble',
#  'chaebol',
#  'changeable',
#  'chargeable',
#  'charitable',
#  'charitable',
#  'chasuble',
#  'chernobyl',
#  'clarabelle',
#  'classifiable',
#  'cobble',
#  'coble',
#  'collapsible',
#  'collectible',
#  'combinable',
#  'combustable',
#  'comfortable',
#  'commendable',
#  'communicable',
#  'comparable',
#  'comparable',
#  'comparable',
#  'compatible',
#  'compensable',
#  'comprehensible',
#  'conable',
#  'conceivable',
#  'confirmable',
#  'considerable',
#  'consolable',
#  'constable',
#  'consumable',
#  'contemptible',
#  'contestable',
#  'contibel',
#  'controllable',
#  'convertible',
#  'copyrightable',
#  'corabelle',
#  'corbel',
#  'corrigible',
#  'corruptible',
#  'countable',
#  'crabill',
#  'crable',
#  'credible',
#  'creditable',
#  'cristobal',
#  'crucible',
#  'crumble',
#  'culpable',
#  'curable',
#  'customizable',
#  'cymbal',
#  'dabble',
#  'debatable',
#  'deductible',
#  'defensible',
#  'definable',
#  'degradable',
#  'deibel',
#  'delectable',
#  'deliverable',
#  'deliverable',
#  'demonstrable',
#  'denoble',
#  'dependable',
#  'deplorable',
#  'deployable',
#  'depreciable',
#  'describable',
#  'desirable',
#  'desirable',
#  'despicable',
#  'destructable',
#  'detachable',
#  'detachable',
#  'detectable',
#  'determinable',
#  'deubel',
#  'developable',
#  'dibble',
#  'dible',
#  'diboll',
#  'diebel',
#  'digestible',
#  'disable',
#  'disagreeable',
#  'disassemble',
#  'discernible',
#  'discountable',
#  'discoverable',
#  'discoverable',
#  'dishonorable',
#  'dispensable',
#  'disposable',
#  'disputable',
#  'disreputable',
#  'dissemble',
#  'distinguishable',
#  'divisible',
#  'doable',
#  'doble',
#  'double',
#  'drabble',
#  'dribble',
#  'drinkable',
#  'drivable',
#  'dulcibelle',
#  'durable',
#  'eatable',
#  'ebel',
#  'eble',
#  'edible',
#  'electable',
#  'eligible',
#  'eligible',
#  'embraceable',
#  'employable',
#  'enable',
#  'enable',
#  'enfeeble',
#  'enforceable',
#  'enjoyable',
#  'ennoble',
#  'ensemble',
#  'enviable',
#  'equable',
#  'equitable',
#  'equitable',
#  'eradicable',
#  'erasable',
#  'erasable',
#  'erodible',
#  'estimable',
#  'exchangeable',
#  'excitable',
#  'excludable',
#  'excusable',
#  'execrable',
#  'exercisable',
#  'expandable',
#  'expendable',
#  'explainable',
#  'explicable',
#  'exportable',
#  'extendable',
#  'extendible',
#  'extricable',
#  'fabel',
#  'fable',
#  'fallible',
#  'fashionable',
#  'fashionable',
#  'fathomable',
#  'faubel',
#  'fauble',
#  'favorable',
#  'favorable',
#  'feasible',
#  'feeble',
#  'fissionable',
#  'fixable',
#  'flammable',
#  'flexible',
#  'fobel',
#  'foible',
#  'forcible',
#  'foreseeable',
#  'forfeitable',
#  'forgettable',
#  'forgettable',
#  'forgivable',
#  'forgivable',
#  'formidable',
#  'formidable',
#  'forseeable',
#  'forseeable',
#  'fowble',
#  'frable',
#  'friebel',
#  'fumble',
#  'fungible',
#  'fusible',
#  'gable',
#  'gaebel',
#  'gamble',
#  'garble',
#  'gebel',
#  'geibel',
#  'gibble',
#  'giebel',
#  'gimbel',
#  'global',
#  'gobble',
#  'gobel',
#  'goble',
#  'goebel',
#  'grabel',
#  'grable',
#  'graybeal',
#  'grenoble',
#  'greubel',
#  'gribble',
#  'griebel',
#  'grumble',
#  'gullible',
#  'gumbel',
#  'habel',
#  'habitable',
#  'hable',
#  'hannibal',
#  'hardscrabble',
#  'harvestable',
#  'hebel',
#  'heibel',
#  'herbal',
#  'herbal',
#  'herbel',
#  'heritable',
#  'hobble',
#  'honorable',
#  'honourable',
#  'horrible',
#  'hospitable',
#  'hubbell',
#  'hubble',
#  'huebel',
#  'humble',
#  'huxtable',
#  'hybl',
#  'identifiable',
#  'ignoble',
#  'illegible',
#  'imaginable',
#  'imitable',
#  'immeasurable',
#  'immiscible',
#  'immobile',
#  'immovable',
#  'immutable',
#  'impassable',
#  'impeachable',
#  'impeccable',
#  'impenetrable',
#  'imperceptible',
#  'impermissible',
#  'implacable',
#  'implantable',
#  'implausible',
#  'imponderable',
#  'impossible',
#  'impracticable',
#  'impregnable',
#  'impressionable',
#  'improbable',
#  'inaccessible',
#  'inadmissible',
#  'inadmissible',
#  'inadvisable',
#  'inadvisable',
#  'inalienable',
#  'inapplicable',
#  'inaudible',
#  'incalculable',
#  'incapable',
#  'incomparable',
#  'incompatible',
#  'incomprehensible',
#  'incompressible',
#  'inconceivable',
#  'incontrovertible',
#  'incorrigible',
#  'incredible',
#  'incurable',
#  'indefatigable',
#  'indefeasible',
#  'indefensible',
#  'indefinable',
#  'indelible',
#  'indescribable',
#  'indestructible',
#  'indispensable',
#  'indispensible',
#  'indisputable',
#  'indistinguishable',
#  'indivisible',
#  'indomitable',
#  'inedible',
#  'ineffable',
#  'ineligible',
#  'ineluctible',
#  'inequitable',
#  'ineradicable',
#  'inescapable',
#  'inevitable',
#  'inexcusable',
#  'inexhaustible',
#  'inexorable',
#  'inexplicable',
#  'inextricable',
#  'infallible',
#  'infeasible',
#  'inflammable',
#  'inflatable',
#  'inflexible',
#  'inhalable',
#  'inheritable',
#  'inhospitable',
#  'inhospitable',
#  'inimitable',
#  'initable',
#  'injectable',
#  'innumerable',
#  'inoperable',
#  'insatiable',
#  'inscrutable',
#  'insensible',
#  'inseparable',
#  'insoluble',
#  'insufferable',
#  'insupportable',
#  'insurmountable',
#  'intangible',
#  'intelligible',
#  'intercable',
#  'interchangeable',
#  'interchangeable',
#  'interminable',
#  'interruptible',
#  'intertribal',
#  'intolerable',
#  'intractable',
#  'invaluable',
#  'invariable',
#  'investable',
#  'invincible',
#  'inviolable',
#  'invisible',
#  'invulnerable',
#  'iqbal',
#  'irascible',
#  'irreconcilable',
#  'irrefutable',
#  'irremediable',
#  'irreparable',
#  'irreplaceable',
#  'irrepressible',
#  'irresistible',
#  'irresponsible',
#  'irreversible',
#  'irrevocable',
#  'irritable',
#  'issuable',
#  'jumble',
#  'justifiable',
#  'kabel',
#  'kable',
#  'kauble',
#  'keeble',
#  'kembel',
#  'kemble',
#  'kerbel',
#  'kibbel',
#  'kibble',
#  'kibell',
#  'kimball',
#  'kimbel',
#  'kimble',
#  'knable',
#  'knebel',
#  'knobel',
#  'knoble',
#  'knoebel',
#  'knowledgeable',
#  'kobel',
#  'koble',
#  'koebel',
#  'korbel',
#  'krabill',
#  'krahenbuhl',
#  'kriebel',
#  'kumble',
#  'label',
#  'laible',
#  'lamentable',
#  'laudable',
#  'laughable',
#  'leasable',
#  'lebel',
#  'leble',
#  'legible',
#  'leibel',
#  'liable',
#  'libel',
#  'liebel',
#  'liebl',
#  'likable',
#  'likeable',
#  'livable',
#  'lobel',
#  'loibl',
#  'lovable',
#  'luckenbill',
#  'luginbill',
#  'luginbuhl',
#  'mabel',
#  'mabile',
#  'mable',
#  'malleable',
#  'manageable',
#  'mandible',
#  'mandible',
#  'maneuverable',
#  'marable',
#  'marble',
#  'marketable',
#  'mccampbell',
#  'measurable',
#  'mehitabel',
#  'mehitabel',
#  'mehitabelle',
#  'memorable',
#  'microwavable',
#  'mirabal',
#  'mirabile',
#  'miscible',
#  'miscible',
#  'miserable',
#  'miserable',
#  'mislabel',
#  'mobil',
#  'mobile',
#  'moldable',
#  'movable',
#  'mumble',
#  'mutable',
#  'navigable',
#  'nebel',
#  'negligible',
#  'negligible',
#  'negotiable',
#  'nibble',
#  'nimble',
#  'nobile',
#  'noble',
#  'non-callable',
#  'non-convertible',
#  'non-deductible',
#  'non-durable',
#  'non-negotiable',
#  'non-refundable',
#  'non-renewable',
#  'non-taxable',
#  'non-transferable',
#  'non-verbal',
#  'noncallable',
#  'nonconvertible',
#  'nondeductible',
#  'nondurable',
#  'nonnegotiable',
#  'nonrefundable',
#  'nonrenewable',
#  'nontaxable',
#  'nontransferable',
#  'nonverbal',
#  'notable',
#  'noticeable',
#  'objectionable',
#  'observable',
#  'obtainable',
#  'offshorable',
#  'operable',
#  'orabelle',
#  'ostensible',
#  'otomobil',
#  'palatable',
#  'palpable',
#  'parable',
#  'passable',
#  'patentable',
#  'payable',
#  'peaceable',
#  'pebble',
#  'pemble',
#  'perceptible',
#  'perishable',
#  'permeable',
#  'permissible',
#  'personable',
#  'persuadable',
#  'pitiable',
#  'plausible',
#  'pleasurable',
#  'pliable',
#  'portable',
#  'possible',
#  'potable',
#  'practicable',
#  'preamble',
#  'prebble',
#  'preble',
#  'predictable',
#  'predictable',
#  'preferable',
#  'preferable',
#  'presentable',
#  'preventable',
#  'preventable',
#  'pribble',
#  'pribyl',
#  'printable',
#  'probable',
#  'profitable',
#  'programmable',
#  'prosecutable',
#  'provable',
#  'przybyl',
#  'psychobabble',
#  'punishable',
#  'puttable',
#  'questionable',
#  'quibble',
#  'quotable',
#  'rabble',
#  'rabel',
#  'raible',
#  'ramble',
#  'reachable',
#  'readable',
#  'realisable',
#  'realizable',
#  'reasonable',
#  'reasonable',
#  'reassemble',
#  'rebel',
#  'receivable',
#  'rechargeable',
#  'recognizable',
#  'recordable',
#  'recoverable',
#  'recyclable',
#  'redeemable',
#  'redouble',
#  'redoubtable',
#  'reducible',
#  'refundable',
#  'regrettable',
#  'reibel',
#  'relabel',
#  'reliable',
#  'reliable',
#  'reloadable',
#  'remarkable',
#  'remarkable',
#  'removable',
#  'renewable',
#  'renovatable',
#  'rentable',
#  'repairable',
#  'repayable',
#  'repeatable',
#  'replaceable',
#  'reportable',
#  'reprehensible',
#  'reputable',
#  'resealable',
#  'resemble',
#  'resemble',
#  'resettable',
#  'respectable',
#  'respectable',
#  'responsible',
#  'retractable',
#  'returnable',
#  'reusable',
#  'reversible',
#  'reversible',
#  'revocable',
#  'ribble',
#  'ridable',
#  'riebel',
#  'robel',
#  'robl',
#  'roble',
#  'rosabelle',
#  'rouble',
#  'roundtable',
#  'roybal',
#  'rubble',
#  'rubel',
#  'rubell',
#  'ruble',
#  'ruebel',
#  'rumble',
#  'ruybal',
#  'sable',
#  'salable',
#  'saleable',
#  'salvageable',
#  'scalable',
#  'schabel',
#  'schaible',
#  'schauble',
#  'scheibel',
#  'scheible',
#  'schiebel',
#  'schnabel',
#  'schobel',
#  'schubel',
#  'schwebel',
#  'scrabble',
#  'scramble',
#  'scribble',
#  'seasonable',
#  'seibel',
#  'sensible',
#  'serviceable',
#  'shamble',
#  'sibil',
#  'sible',
#  'sibyl',
#  'siebel',
#  'sizable',
#  'sizeable',
#  'snabel',
#  'sobel',
#  'sobil',
#  'soble',
#  'sobol',
#  'sociable',
#  'soluble',
#  'solvable',
#  'spendable',
#  'squabble',
#  'stable',
#  'stibel',
#  'stiebel',
#  'strebel',
#  'strobel',
#  'strobl',
#  'stroble',
#  'stroebel',
#  'strubel',
#  'struble',
#  'stubble',
#  'stumble',
#  'submersible',
#  'suggestible',
#  'suitable',
#  'supportable',
#  'survivable',
#  'susceptible',
#  'sustainable',
#  'syllable',
#  'symbol',
#  'table',
#  'talkable',
#  'tangible',
#  'taxable',
#  'teachable',
#  'telecable',
#  'tenable',
#  'terminable',
#  'terrible',
#  'thimble',
#  'timetable',
#  'tolerable',
#  'touchable',
#  'traceable',
#  'tractable',
#  'tractebel',
#  'tradable',
#  'tradeable',
#  'trainable',
#  'tramble',
#  'transferable',
#  'transferrable',
#  'transmittable',
#  'transportable',
#  'treatable',
#  'treble',
#  'tremble',
#  'tribal',
#  'tribble',
#  'trible',
#  'tribull',
#  'trimble',
#  'tromble',
#  'trouble',
#  'trumble',
#  'trumbull',
#  'tubal',
#  'tumble',
#  'tunable',
#  'turntable',
#  'typeable',
#  'uebel',
#  'umbel',
#  'umble',
#  'unable',
#  'unacceptable',
#  'unaccountable',
#  'unadjustable',
#  'unaffordable',
#  'unalienable',
#  'unalienable',
#  'unallowable',
#  'unalterable',
#  'unanswerable',
#  'unapproachable',
#  'unassailable',
#  'unattainable',
#  'unavailable',
#  'unavoidable',
#  'unbearable',
#  'unbeatable',
#  'unbelievable',
#  'unbreakable',
#  'unbuildable',
#  'uncollectable',
#  'uncollectible',
#  'uncomfortable',
#  'unconscionable',
#  'uncontrollable',
#  'undeniable',
#  'understandable',
#  'undesirable',
#  'undetectable',
#  'unelectable',
#  'unemployable',
#  'unenforceable',
#  'unenviable',
#  'unexplainable',
#  'unfashionable',
#  'unfathomable',
#  'unfavorable',
#  'unfeasible',
#  'unflappable',
#  'unforeseeable',
#  'unforgettable',
#  'unforgivable',
#  'ungovernable',
#  'unimaginable',
#  'unimpeachable',
#  'uninhabitable',
#  'uninsurable',
#  'unintelligible',
#  'uninterruptible',
#  'uninterruptible',
#  'unjustifiable',
#  'unknowable',
#  'unlivable',
#  'unmanageable',
#  'unmentionable',
#  'unmistakable',
#  'unobtainable',
#  'unpalatable',
#  'unpayable',
#  'unpredictable',
#  'unprintable',
#  'unprofitable',
#  'unquestionable',
#  'unreachable',
#  'unreadable',
#  'unreadable',
#  'unreasonable',
#  'unrecognizable',
#  'unreliable',
#  'unreliable',
#  'unremarkable',
#  'unsalable',
#  'unsaleable',
#  'unscramble',
#  'unserviceable',
#  'unserviceable',
#  'unshakable',
#  'unshakeable',
#  'unsinkable',
#  'unsolvable',
#  'unspeakable',
#  'unstable',
#  'unstoppable',
#  'unsuitable',
#  'unsupportable',
#  'unsustainable',
#  'untenable',
#  'unthinkable',
#  'untouchable',
#  'untraceable',
#  'untreatable',
#  'unusable',
#  'unverifiable',
#  'unwinnable',
#  'unworkable',
#  'usable',
#  'valable',
#  'valuable',
#  'valuable',
#  'varble',
#  'variable',
#  'vegetable',
#  'venable',
#  'venerable',
#  'verbal',
#  'verble',
#  'verifiable',
#  'veritable',
#  'viable',
#  'violable',
#  'visible',
#  'voluble',
#  'vontobel',
#  'vrabel',
#  'vulnerable',
#  'waibel',
#  'waibel',
#  'wamble',
#  'warble',
#  'washable',
#  'wearable',
#  'weibel',
#  'weible',
#  'wible',
#  'winnable',
#  'wobble',
#  'womble',
#  'workable',
#  'wrobel',
#  'wrubel',
#  'wyble',
#  'zabel',
#  'zeeble',
#  'zeibel',
#  'zirbel',
#  'zobel',
#  'zweibel',
#  'zwiebel']

# %% [markdown]
# ## meter and syllable count

# %%
#returns stress pattern
pr.stresses(pr.phones_for_word("snappiest")[0])
# Out:
# '102'

# %%
pr.syllable_count(pr.phones_for_word("informational")[0])
# Out:
# 5

# %%
pr.search_stresses("010202")
# Out:
# ['environmentalism', 'environmentalism', 'hypersensitivity', 'phenomenology']

# %%
pr.search_stresses("^001000$")
# Out:
# ['autoradiograph',
#  'dehumidifier',
#  'internationalized',
#  'internationalized',
#  'parenthetically',
#  'reindustrialize',
#  'unambiguously',
#  'uncooperative',
#  'uncoordinated',
#  'unequivocably']

# %%
pr.rhyming_part(pr.phones_for_word("internal")[0])
# Out:
# 'ER1 N AH0 L'

# %%
pr.rhymes("internal")
# Out:
# ['bernal',
#  'burnell',
#  'colonel',
#  'diurnal',
#  'durnell',
#  'durnil',
#  'eternal',
#  'eternal',
#  'external',
#  'fraternal',
#  'infernal',
#  'journal',
#  'kernel',
#  'maternal',
#  'nocturnal',
#  'paternal',
#  'pernell',
#  'purnell',
#  'vernal']

# %%
from collections import defaultdict

# %%
rhymes = defaultdict(list)
for line in open("txt/sonnets.txt"):
    line = line.strip("\n.,;:?!")
    words = line.split()
    if len(words)>0:
        last_word = words[-1]
        phones = pr.phones_for_word(last_word)
        if len(phones)>0:
                rhyming_part = pr.rhyming_part(phones[0])
#                 print(rhyming_part, "/", line)
                rhymes[rhyming_part].append(line)
#         print(last_word)

# %%
rhymes
# Out:
# defaultdict(list,
#             {'IY1 S': ['From fairest creatures we desire increase',
#               'But as the riper should by time decease',
#               'Herein lives wisdom, beauty, and increase',
#               'If all were minded so, the times should cease',
#               'So should that beauty which you hold in lease',
#               "Yourself again, after yourself's decease",
#               'When I perceive that men as plants increase',
#               'Vaunt in their youthful sap, at height decrease',
#               'The teeming autumn, big with rich increase',
#               "Like widow'd wombs after their lords' decease",
#               'Why so large cost, having so short a lease'],
#              'AY1': ["That thereby beauty's rose might never die",
#               'Lifts up his burning head, each under eye',
#               "Is it for fear to wet a widow's eye",
#               'Ah! if thou issueless shalt hap to die',
#               "  She carv'd thee for her seal, and meant thereby",
#               '  Thou shouldst print more, not let that copy die',
#               'Cheered and checked even by the self-same sky',
#               "But as the marigold at the sun's eye",
#               'For at a frown they in their glory die',
#               "Hath dear religious love stol'n from mine eye",
#               "But things remov'd that hidden in thee lie",
#               'Flatter the mountain tops with sovereign eye',
#               'But the defendant doth that plea deny',
#               'And scarcely greet me with that sun, thine eye',
#               'The canker blooms have full as deep a dye',
#               'So far from home into my deeds to pry',
#               'Sin of self-love possesseth all mine eye',
#               'Tired with all these, for restful death I cry',
#               'Unless you would devise some virtuous lie',
#               'And hang more praise upon deceased I',
#               'That on the ashes of his youth doth lie',
#               "Consum'd with that which it was nourish'd by",
#               'And heavy ignorance aloft to fly',
#               'Though I, once gone, to all the world must die',
#               "When you entombed in men's eyes shall lie",
#               'Since that my life on thy revolt doth lie',
#               'Happy to have thy love, happy to die',
#               'For there can live no hatred in thine eye',
#               'Though to itself, it only live and die',
#               'As from my soul which in thy breast doth lie',
#               'Those lines that I before have writ do lie',
#               'Yet then my judgment knew no reason why',
#               'Thy registers and thee I both defy',
#               'For thy records and what we see doth lie',
#               "  For I have sworn thee fair; more perjur'd I",
#               '  To swear against the truth so foul a lie',
#               'This brand she quenched in a cool well by'],
#              'EH1 M ER0 IY0': ['His tender heir might bear his memory',
#               'And wear their brave state out of memory',
#               'The living record of your memory',
#               'That he shall never cut from memory',
#               'Of mouthed graves will give thee memory',
#               "Full character'd with lasting memory"],
#              'AY1 Z': ['But thou contracted to thine own bright eyes',
#               'Making a famine where abundance lies',
#               'Then being asked, where all thy beauty lies',
#               'To say, within thine own deep sunken eyes',
#               'If I could write the beauty of your eyes',
#               "The age to come would say 'This poet lies",
#               "To find where your true image pictur'd lies",
#               'That hath his windows glazed with thine eyes',
#               "When in disgrace with fortune and men's eyes",
#               'And trouble deaf heaven with my bootless cries',
#               'And says in him thy fair appearance lies',
#               '  So, till the judgment that yourself arise',
#               "  You live in this, and dwell in lovers' eyes",
#               '  There lives more life in one of your fair eyes',
#               '  Than both your poets can in praise devise',
#               'And for they looked but with divining eyes',
#               "For why should others' false adulterate eyes",
#               'Or on my frailties why are frailer spies',
#               'Thou blind fool, Love, what dost thou to mine eyes',
#               'They know what beauty is, see where it lies',
#               'I do believe her though I know she lies',
#               "But 'tis my heart that loves what they despise",
#               'That is so proud thy service to despise',
#               'Commanded by the motion of thine eyes',
#               '  But found no cure, the bath for my help lies',
#               "  Where Cupid got new fire; my mistress' eyes"],
#              'UW1 AH0 L': ["Feed'st thy light's flame with self-substantial fuel",
#               'Thy self thy foe, to thy sweet self too cruel',
#               'As those whose beauties proudly make them cruel',
#               'Thou art the fairest and most precious jewel'],
#              'AO1 R N AH0 M AH0 N T': ["Thou that art now the world's fresh ornament"],
#              'IH1 NG': ['And only herald to the gaudy spring',
#               'Who, all in one, one pleasing note do sing',
#               'O! how thy worth with manners may I sing',
#               'What can mine own praise to mine own self bring',
#               "And all those beauties whereof now he's king",
#               'Thine eyes, that taught the dumb on high to sing',
#               "Have added feathers to the learned's wing",
#               'From you have I been absent in the spring',
#               'Hath put a spirit of youth in every thing',
#               'Our love was new, and then but in the spring',
#               "As Philomel in summer's front doth sing",
#               'They had not skill enough your worth to sing'],
#              'AA1 N T EH0 N T': ['Within thine own bud buriest thy content',
#               "  So I return rebuk'd to my content"],
#              'IY1': ['  Pity the world, or else this glutton be',
#               "  To eat the world's due, by the grave and thee",
#               "Thou art thy mother's glass and she in thee",
#               'So thou through windows of thine age shalt see',
#               "  But if thou live, remember'd not to be",
#               '  Die single and thine image dies with thee',
#               'And being frank she lends to those are free',
#               '  Thy unused beauty must be tombed with thee',
#               "  Which, used, lives th' executor to be",
#               "That's for thy self to breed another thee",
#               "If ten of thine ten times refigur'd thee",
#               '  Make thee another self for love of me',
#               '  That beauty still may live in thine or thee',
#               '  So long as men can breathe, or eyes can see',
#               '  So long lives this, and this gives life to thee',
#               'For all that beauty that doth cover thee',
#               'Which in thy breast doth live, as thine in me',
#               'Mine eyes have drawn thy shape, and thine for me',
#               '  Then may I dare to boast how I do love thee',
#               '  Till then, not show my head where thou mayst prove me',
#               'Intend a zealous pilgrimage to thee',
#               'Looking on darkness which the blind do see',
#               'Do in consent shake hands to torture me',
#               "  Their images I lov'd, I view in thee",
#               '  And thou--all they--hast all the all of me',
#               '  That I an accessary needs must be',
#               '  To that sweet thief which sourly robs from me',
#               'I may not evermore acknowledge thee',
#               'Nor thou with public kindness honour me',
#               '  Look what is best, that best I wish in thee',
#               '  This wish I have; then ten times happy me',
#               'O! give thy self the thanks, if aught in me',
#               "For who's so dumb that cannot write to thee",
#               'When thou art all the better part of me',
#               "And what is't but mine own when I praise thee",
#               '  Hers by thy beauty tempting her to thee',
#               '  Thine by thy beauty being false to me',
#               'Loving offenders thus I will excuse ye',
#               'And for my sake even so doth she abuse me',
#               'When most I wink, then do mine eyes best see',
#               'But when I sleep, in dreams they look on thee',
#               '  All days are nights to see till I see thee',
#               '  And nights bright days when dreams do show thee me',
#               "Upon the farthest earth remov'd from thee",
#               'As soon as think the place where he would be',
#               'In tender embassy of love to thee',
#               "By those swift messengers return'd from thee",
#               'Of thy fair health, recounting it to me',
#               'Thy self away, art present still with me',
#               'And I am still with them, and they with thee',
#               'Plods dully on, to bear that weight in me',
#               "His rider lov'd not speed, being made from thee",
#               'So am I as the rich, whose blessed key',
#               'Let this sad interim like the ocean be',
#               'Come daily to the banks, that when they see',
#               "Is it thy spirit that thou send'st from thee",
#               'To find out shames and idle hours in me',
#               'Since brass, nor stone, nor earth, nor boundless sea',
#               'How with this rage shall beauty hold a plea',
#               'The very part was consecrate to thee',
#               'My spirit is thine, the better part of me',
#               'Whose influence is thine, and born of thee',
#               'And arts with thy sweet graces graced be',
#               'For bending all my loving thoughts on thee',
#               'Doing thee vantage, double-vantage me',
#               'Thy love is better than high birth to me',
#               'Of more delight than hawks and horses be',
#               'But heaven in thy creation did decree',
#               "Whate'er thy thoughts, or thy heart's workings be",
#               'Which for their habitation chose out thee',
#               'And all things turns to fair that eyes can see',
#               "Yet this abundant issue seem'd to me",
#               'For summer and his pleasures wait on thee',
#               '  More flowers I noted, yet I none could see',
#               "  But sweet, or colour it had stol'n from thee",
#               "Excuse not silence so, for't lies in thee",
#               "And to be prais'd of ages yet to be",
#               'Since all alike my songs and praises be',
#               '  Pity me then, dear friend, and I assure ye',
#               '  Even that your pity is enough to cure me',
#               '  But that your trespass now becomes a fee',
#               '  Mine ransoms yours, and yours must ransom me',
#               '  To keep an adjunct to remember thee',
#               '  Were to import forgetfulness in me',
#               '  This I do vow and this shall ever be',
#               '  I will be true despite thy scythe and thee',
#               'And take thou my oblation, poor but free',
#               'But mutual render, only me for thee',
#               '  Her audit (though delayed) answered must be',
#               '  And her quietus is to render thee',
#               'Thine eyes I love, and they, as pitying me',
#               'Have put on black and loving mourners be',
#               'For that deep wound it gives my friend and me',
#               "But slave to slavery my sweet'st friend must be",
#               '  And yet thou wilt; for I, being pent in thee',
#               '  Perforce am thine, and all that is in me',
#               'But thou wilt not, nor he will not be free',
#               "He learn'd but surety-like to write for me",
#               '  Him have I lost; thou hast both him and me',
#               '  He pays the whole, and yet am I not free',
#               "Though in thy store's account I one must be",
#               'That nothing me, a something sweet to thee',
#               'That they behold, and see not what they see',
#               'Yet what the best is take the worst to be',
#               '  Therefore I lie with her, and she with me',
#               "  And in our faults by lies we flatter'd be",
#               'And in my madness might speak ill of thee',
#               'Mad slanderers by mad ears believed be',
#               'Dissuade one foolish heart from serving thee',
#               "Thy proud heart's slave and vassal wretch to be",
#               'Whom thine eyes woo as mine importune thee',
#               'Thy pity may deserve to pitied be',
#               'But if thou catch thy hope, turn back to me',
#               "  If thy unworthiness rais'd love in me",
#               "  More worthy I to be belov'd of thee",
#               'But rising at thy name doth point out thee',
#               'He is contented thy poor drudge to be',
#               'For all my vows are oaths but to misuse thee',
#               'Or made them swear against the thing they see'],
#              'AW1': ['When forty winters shall besiege thy brow',
#               "Thy youth's proud livery so gazed on now",
#               "O! carve not with thy hours my love's fair brow",
#               'Him in thy course untainted do allow',
#               'With all triumphant splendour on my brow',
#               "The region cloud hath mask'd him from me now",
#               "And delves the parallels in beauty's brow",
#               'Against my love shall be as I am now',
#               "When hours have drain'd his blood and fill'd his brow",
#               'When beauty lived and died as flowers do now',
#               'Or durst inhabit on a living brow',
#               'Then hate me when thou wilt; if ever, now',
#               'Join with the spite of fortune, make me bow',
#               '  Then do thy office, Muse; I teach thee how',
#               '  To make him seem long hence as he shows now',
#               'Not that the summer is less pleasant now',
#               'But that wild music burthens every bough',
#               'Of hand, of foot, of lip, of eye, of brow',
#               'Even such a beauty as you master now',
#               "Which vulgar scandal stamp'd upon my brow",
#               "So you o'er-green my bad, my good allow",
#               'That you were once unkind befriends me now',
#               'Needs must I under my transgression bow'],
#              'IY1 L D': ["And dig deep trenches in thy beauty's field"],
#              'EY1 Z': ['Were an all-eating shame, and thriftless praise',
#               '  If my slight muse do please these curious days',
#               '  The pain be mine, but thine shall be the praise',
#               '  O! sure I am the wits of former days',
#               '  To subjects worse have given admiring praise',
#               "  'Tis thee,--myself,--that for myself I praise",
#               '  Painting my age with beauty of thy days',
#               'Against the wrackful siege of battering days',
#               'Nor gates of steel so strong but Time decays',
#               'Thou hast passed by the ambush of young days',
#               'Yet this thy praise cannot be so thy praise',
#               'Finding thy worth a limit past my praise',
#               'Some fresher stamp of the time-bettering days',
#               'That tongue that tells the story of thy days',
#               'Cannot dispraise, but in a kind of praise',
#               'When I was wont to greet it with my lays',
#               'And stops her pipe in growth of riper days',
#               '  For we, which now behold these present days',
#               '  Have eyes to wonder, but lack tongues to praise'],
#              'UW1 S': ["How much more praise deserv'd thy beauty's use",
#               'Then, beauteous niggard, why dost thou abuse',
#               'Profitless usurer, why dost thou use',
#               'Who heaven itself for ornament doth use',
#               'As every alien pen hath got my use',
#               'The dedicated words which writers use',
#               "Thou usurer, that putt'st forth all to use",
#               'So him I lose through my unkind abuse'],
#              'AY1 N': ["If thou couldst answer 'This fair child of mine",
#               'Proving his beauty by succession thine',
#               'Duty so great, which wit so poor as mine',
#               'But that I hope some good conceit of thine',
#               'Even so my sun one early morn did shine',
#               'But out! alack! he was but one hour mine',
#               'Methinks no face so gracious is as mine',
#               'And for myself mine own worth do define',
#               "  But when your countenance fill'd up his line",
#               '  Then lacked I matter; that enfeebled mine',
#               'For term of life thou art assured mine',
#               'Nothing, sweet boy; but yet, like prayers divine',
#               "So, now I have confess'd that he is thine",
#               "Myself I'll forfeit, so that other mine",
#               'Not once vouchsafe to hide my will in thine',
#               'And in my will no fair acceptance shine',
#               "And seal'd false bonds of love as oft as mine"],
#              'OW1 L D': ['  This were to be new made when thou art old',
#               "  And see thy blood warm when thou feel'st it cold",
#               'Which husbandry in honour might uphold',
#               "And barren rage of death's eternal cold",
#               'My glass shall not persuade me I am old',
#               "But when in thee time's furrows I behold",
#               'That time of year thou mayst in me behold',
#               'Upon those boughs which shake against the cold',
#               '  For as the sun is daily new and old',
#               '  So is my love still telling what is told',
#               'To me, fair friend, you never can be old',
#               'Such seems your beauty still. Three winters cold',
#               'That poor retention could not so much hold',
#               'Therefore to give them from me was I bold',
#               'What thou dost foist upon us that is old',
#               'Than think that we before have heard them told',
#               'Yet, in good faith, some say that thee behold',
#               'To say they err I dare not be so bold',
#               'Then in the number let me pass untold',
#               'For nothing hold me, so it please thee hold',
#               'And wherefore say not I that I am old',
#               'And age in love, loves not to have years told'],
#              'AH1 DH ER0': ['Now is the time that face should form another',
#               'Thou dost beguile the world, unbless some mother',
#               'Mark how one string, sweet husband to another',
#               'Resembling sire and child and happy mother',
#               'And each doth good turns now unto the other',
#               'Or heart in love with sighs himself doth smother'],
#              'UW1 M': ["For where is she so fair whose unear'd womb",
#               'Or who is he so fond will be the tomb',
#               'Though yet heaven knows it is but as a tomb',
#               'Shall you pace forth; your praise shall still find room',
#               'That wear this world out to the ending doom',
#               'When others would give life, and bring a tomb',
#               'To make him much outlive a gilded tomb',
#               "Supposed as forfeit to a confin'd doom",
#               'But bears it out even to the edge of doom',
#               "Was us'd in giving gentle doom"],
#              'AH1 Z B AH0 N D R IY0': ['Disdains the tillage of thy husbandry'],
#              'AY1 M': ['Calls back the lovely April of her prime',
#               'Despite of wrinkles this thy golden time',
#               'When I do count the clock that tells the time',
#               'When I behold the violet past prime',
#               'Make war upon this bloody tyrant, Time',
#               'With means more blessed than my barren rhyme',
#               '  But were some child of yours alive that time',
#               '  You should live twice,--in it, and in my rhyme',
#               "And do whate'er thou wilt, swift-footed Time",
#               'But I forbid thee one most heinous crime',
#               "Compare them with the bett'ring of the time",
#               'Reserve them for my love, not for their rhyme',
#               'Of princes, shall outlive this powerful rhyme',
#               "Than unswept stone, besmear'd with sluttish time",
#               'That you yourself may privilage your time',
#               'Yourself to pardon of self-doing crime',
#               "Thy worth the greater being woo'd of time",
#               "And thou present'st a pure unstained prime",
#               "And yet this time removed was summer's time",
#               'Bearing the wanton burden of the prime',
#               'When in the chronicle of wasted time',
#               'And beauty making beautiful old rime',
#               'Now with the drops of this most balmy time',
#               "Since, spite of him, I'll live in this poor rime",
#               "As I by yours, you've pass'd a hell of time",
#               "To weigh how once I suffer'd in your crime",
#               '  To this I witness call the fools of time',
#               '  Which die for goodness, who have lived for crime'],
#              'EH1 N D': ['Unthrifty loveliness, why dost thou spend',
#               "Nature's bequest gives nothing, but doth lend",
#               'Look! what an unthrift in the world doth spend',
#               "But beauty's waste hath in the world an end",
#               '  But if the while I think on thee, dear friend',
#               "  All losses are restor'd and sorrows end",
#               "When what I seek, my weary travel's end",
#               'That millions of strange shadows on you tend',
#               'And you but one, can every shadow lend',
#               'Being your slave what should I do but tend',
#               'I have no precious time at all to spend',
#               'So do our minutes hasten to their end',
#               'In sequent toil all forwards do contend',
#               'Want nothing that the thought of hearts can mend',
#               'Uttering bare truth, even so as foes commend',
#               'What strained touches rhetoric can lend',
#               'In true plain words, by thy true-telling friend',
#               'When in the least of them my life hath end',
#               'Than that which on thy humour doth depend',
#               'Were it not sinful then, striving to mend',
#               'For to no other pass my verses tend',
#               'Now all is done, save what shall have no end',
#               'On newer proof, to try an older friend',
#               'But being both from me, both to each friend',
#               "'I hate' she alter'd with an end",
#               'Dost thou upon thy fading mansion spend',
#               "Eat up thy charge? Is this thy body's end",
#               'Who hateth thee that I do call my friend',
#               "Nay, if thou lour'st on me, do I not spend"],
#              'EH1 G AH0 S IY0': ["Upon thy self thy beauty's legacy"],
#              'IH1 V': ['The bounteous largess given thee to give',
#               'And your sweet semblance to some other give',
#               'Who all their parts of me to thee did give',
#               'Whilst that this shadow doth such substance give',
#               'That by this separation I may give',
#               'By that sweet ornament which truth doth give',
#               'From thy behaviour; beauty doth he give'],
#              'AY1 V': ['So great a sum of sums, yet canst not live',
#               'No longer yours, than you your self here live',
#               'But from thine eyes my knowledge I derive',
#               "As 'Truth and beauty shall together thrive",
#               'Thou art the grave where buried love doth live',
#               'And by a part of all thy glory live',
#               'Even for this, let us divided live',
#               'For that sweet odour, which doth in it live',
#               'Ah! wherefore with infection should he live',
#               'You are my all-the-world, and I must strive',
#               'None else to me, nor I to none alive'],
#              'OW1 N': ['For having traffic with thy self alone',
#               'Which happies those that pay the willing loan',
#               'The sad account of fore-bemoaned moan',
#               'That due of many now is thine alone',
#               'Without thy help, by me be borne alone',
#               "That due to thee which thou deserv'st alone",
#               '  Sweet flattery! then she loves but me alone',
#               "I must attend, time's leisure with my moan",
#               'My life, being made of four, with two alone',
#               'Which heavily he answers with a groan',
#               '  Save that, to die, I leave my love alone',
#               'But those same tongues, that give thee so thine own',
#               'By seeing farther than the eye hath shown',
#               '  Lest the wise world should look into your moan',
#               'Now counting best to be with you alone',
#               'Who, moving others, are themselves as stone',
#               "  Fair, kind, and true, have often liv'd alone",
#               'At my abuses reckon up their own',
#               'By their rank thoughts, my deeds must not be shown',
#               'Thy face hath not the power to make love groan',
#               'Although I swear it to myself alone',
#               'Beshrew that heart that makes my heart to groan',
#               "Is't not enough to torture me alone",
#               'Nor tender feeling, to base touches prone',
#               'To any sensual feast with thee alone',
#               'Revenge upon myself with present moan'],
#              'IY1 V': ['Thou of thy self thy sweet self dost deceive',
#               'What acceptable audit canst thou leave',
#               'Were it not thy sour leisure gave sweet leave',
#               'That sin by him advantage should achieve'],
#              'AO1 N': ['Then how when nature calls thee to be gone',
#               'Sap checked with frost, and lusty leaves quite gone',
#               'Then can I grieve at grievances foregone',
#               'Hung with the trophies of my lovers gone',
#               'To leap large lengths of miles when thou art gone',
#               'For when these quicker elements are gone',
#               "  Tir'd with all these, from these would I be gone",
#               '  And mock you with me after I am gone',
#               'Now proud as an enjoyer, and anon'],
#              'EY1 M': ['Those hours, that with gentle work did frame',
#               'Will play the tyrants to the very same',
#               'Lest my bewailed guilt should do thee shame',
#               'Unless thou take that honour from thy name',
#               'To this composed wonder of your frame',
#               'Why write I still all one, ever the same',
#               'That every word doth almost tell my name',
#               'Knowing a better spirit doth use your name',
#               'To make me tongue-tied speaking of your fame',
#               'How sweet and lovely dost thou make the shame',
#               'Doth spot the beauty of thy budding name',
#               "I must each day say o'er the very same",
#               "Even as when first I hallow'd thy fair name",
#               "Or if it were, it bore not beauty's name",
#               "And beauty slander'd with a bastard shame",
#               'The expense of spirit in a waste of shame',
#               "Is perjur'd, murderous, bloody, full of blame"],
#              'EH1 L': ['The lovely gaze where every eye doth dwell',
#               'And that unfair which fairly doth excel',
#               'Nor can I fortune to brief minutes tell',
#               'Or say with princes if it shall go well',
#               '  Let them say more that like of hearsay well',
#               '  I will not praise that purpose not to sell',
#               '  I am to wait, though waiting so be hell',
#               '  Not blame your pleasure be it ill or well',
#               'Than you shall hear the surly sullen bell',
#               'From this vile world with vilest worms to dwell',
#               'Lean penury within that pen doth dwell',
#               'But he that writes of you, if he can tell',
#               'Thy sweet beloved name no more shall dwell',
#               'That in thy face sweet love should ever dwell',
#               'Thy looks should nothing thence, but sweetness tell',
#               'Yet nor the lays of birds, nor the sweet smell',
#               "Could make me any summer's story tell",
#               'To mar the subject that before was well',
#               'Than of your graces and your gifts to tell',
#               '  All this the world well knows; yet none knows well',
#               '  To shun the heaven that leads men to this hell',
#               'Suspect I may, yet not directly tell',
#               "I guess one angel in another's hell"],
#              'AA1 N': ['For never-resting time leads summer on',
#               'The bloody spur cannot provoke him on',
#               "On whom frown'st thou that I do fawn upon"],
#              'EH1 R': ['To hideous winter, and confounds him there',
#               "Beauty o'er-snowed and bareness every where",
#               "  Be not self-will'd, for thou art much too fair",
#               "  To be death's conquest and make worms thine heir",
#               'Against this coming end you should prepare',
#               'So should the lines of life that life repair',
#               'Neither in inward worth nor outward fair',
#               "With April's first-born flowers, and all things rare",
#               'And then believe me, my love is as fair',
#               "As those gold candles fix'd in heaven's air",
#               'How many a holy and obsequious tear',
#               'Authorizing thy trespass with compare',
#               'Who lead thee in their riot even there',
#               'Thou best of dearest, and mine only care',
#               'Therefore are feasts so solemn and so rare',
#               '  Or call it winter, which being full of care',
#               "  Makes summer's welcome, thrice more wished, more rare",
#               "For slander's mark was ever yet the fair",
#               "A crow that flies in heaven's sweetest air",
#               'Thy glass will show thee how thy beauties wear',
#               "These vacant leaves thy mind's imprint will bear",
#               'The humble as the proudest sail doth bear',
#               'Making his style admired every where',
#               "And buds of marjoram had stol'n thy hair",
#               'One blushing shame, another white despair',
#               'If Time have any wrinkle graven there',
#               "And make time's spoils despised every where",
#               "The owner's tongue doth publish every where",
#               "Alas! 'tis true, I have gone here and there",
#               'In so profound abysm I throw all care',
#               'In the old age black was not counted fair',
#               "But now is black beauty's successive heir",
#               '  And yet by heaven, I think my love as rare',
#               '  As any she belied with false compare',
#               'And to be sure that is not false I swear',
#               "One on another's neck, do witness bear",
#               'And will, thy soul knows, is admitted there',
#               'Two loves I have of comfort and despair',
#               'The better angel is a man right fair',
#               'Past cure I am, now Reason is past care'],
#              'EH1 F T': ["Then were not summer's distillation left",
#               "Beauty's effect with beauty were bereft"],
#              'AE1 S': ['A liquid prisoner pent in walls of glass',
#               'Against that time when thou shalt strangely pass'],
#              'AA1 Z': ['Nor it, nor no remembrance what it was',
#               'When love, converted from the thing it was',
#               '  Since why to love I can allege no cause'],
#              'IY1 T': ["  But flowers distill'd, though they with winter meet",
#               '  Leese but their show; their substance still lives sweet',
#               'Mine own true love that doth my rest defeat',
#               "The summer's flower is to the summer sweet",
#               'But if that flower with base infection meet',
#               'Chiding that tongue that ever sweet',
#               'And taught it thus anew to greet'],
#              'EY1 S': ["Then let not winter's ragged hand deface",
#               'Make sweet some vial; treasure thou some place',
#               'With ugly rack on his celestial face',
#               'To dry the rain on my storm-beaten face',
#               'That heals the wound, and cures not the disgrace',
#               'Then can no horse with my desire keep pace',
#               'Shall neigh--no dull flesh--in his fiery race',
#               'My verse alone had all thy gentle grace',
#               'And my sick Muse doth give an other place',
#               "Like a deceived husband; so love's face",
#               'Thy looks with me, thy heart in other place',
#               'Look in your glass, and there appears a face',
#               'Dulling my lines, and doing me disgrace',
#               "So that eternal love in love's fresh case",
#               'Nor gives to necessary wrinkles place',
#               "Fairing the foul with Art's false borrowed face",
#               "But is profan'd, if not lives in disgrace",
#               'A thousand groans, but thinking on thy face',
#               "Thy black is fairest in my judgment's place",
#               'As those two mourning eyes become thy face',
#               'To mourn for me since mourning doth thee grace',
#               "Which my heart knows the wide world's common place",
#               'To put fair truth upon so foul a face',
#               'Whilst her neglected child holds her in chase',
#               'To follow that which flies before her face'],
#              'UW1 ZH ER0 IY0': ['That use is not forbidden usury'],
#              'AH1 N': ['Or ten times happier, be it ten for one',
#               "  Unlook'd, on diest unless thou get a son",
#               '  Whose speechless song being many, seeming one',
#               'Now see what good turns eyes for eyes have done',
#               'Are windows to my breast, where-through the sun',
#               "No more be griev'd at that which thou hast done",
#               'Clouds and eclipses stain both moon and sun',
#               'Although our undivided loves are one',
#               'And our dear love lose name of single one',
#               'Gentle thou art, and therefore to be won',
#               "And when a woman woos, what woman's son",
#               "  But here's the joy; my friend and I are one",
#               'Even of five hundred courses of the sun',
#               'Since mind at first in character was done',
#               'They that have power to hurt, and will do none',
#               '  Which three till now, never kept seat in one',
#               "My mistress' eyes are nothing like the sun",
#               'If snow be white, why then her breasts are dun',
#               'Ay, fill it full with wills, and my will one',
#               "Among a number one is reckon'd none"],
#              'AA1 R T': ['Ten times thy self were happier than thou art',
#               'Then what could death do if thou shouldst depart',
#               'And constant stars in them I read such art',
#               'Is but the seemly raiment of my heart',
#               'How can I then be elder than thou art',
#               'Who with his fear is put beside his part',
#               "Whose strength's abundance weakens his own heart",
#               "Thy beauty's form in table of my heart",
#               "And perspective it is best painter's art",
#               '  Yet eyes this cunning want to grace their art',
#               '  They draw but what they see, know not the heart',
#               'When I am sometime absent from thy heart',
#               'For still temptation follows where thou art',
#               'A quest of thoughts, all tenants to the heart',
#               "The clear eye's moiety, and the dear heart's part",
#               "  As thus; mine eye's due is thy outward part",
#               "  And my heart's right, thy inward love of heart",
#               'And to the painted banquet bids my heart',
#               'And in his thoughts of love doth share a part',
#               'Save where thou art not, though I feel thou art',
#               'From whence at pleasure thou mayst come and part',
#               '  In all external grace you have some part',
#               '  But you like none, none you, for constant heart',
#               'And all my soul, and all my every part',
#               'It is so grounded inward in my heart',
#               'Than niggard truth would willingly impart',
#               'O! never say that I was false of heart',
#               'As easy might I from my self depart',
#               'For it no form delivers to the heart',
#               'Or, at the least, so long as brain and heart',
#               "Till each to raz'd oblivion yield his part",
#               'No; let me be obsequious in thy heart',
#               "Which is not mix'd with seconds, knows no art",
#               "For well thou know'st to my dear doting heart",
#               'O! let it then as well beseem thy heart',
#               'And suit thy pity like in every part',
#               'That thy unkindness lays upon my heart',
#               'Use power with power, and slay me not by art'],
#              'EH1 R AH0 T IY0': ['Leaving thee living in posterity',
#               'Even in the eyes of all posterity'],
#              'AY1 T': ['Lo! in the orient when the gracious light',
#               'Doth homage to his new-appearing sight',
#               'And see the brave day sunk in hideous night',
#               'Sets you most rich in youth before my sight',
#               'To change your day of youth to sullied night',
#               'O! let me, true in love, but truly write',
#               "As any mother's child, though not so bright",
#               "The perfect ceremony of love's rite",
#               'The painful warrior famoused for fight',
#               'Is from the book of honour razed quite',
#               "Save that my soul's imaginary sight",
#               'Which, like a jewel (hung in ghastly night',
#               'How can I then return in happy plight',
#               "When day's oppression is not eas'd by night",
#               'I tell the day, to please him thou art bright',
#               "So flatter I the swart-complexion'd night",
#               "For precious friends hid in death's dateless night",
#               "And moan the expense of many a vanish'd sight",
#               'Though in our lives a separable spite',
#               "Yet doth it steal sweet hours from love's delight",
#               'As a decrepit father takes delight',
#               "So I, made lame by Fortune's dearest spite",
#               'Worthy perusal stand against thy sight',
#               'Then thou, whose shadow shadows doth make bright',
#               'To the clear day with thy much clearer light',
#               'How to divide the conquest of thy sight',
#               'My heart mine eye the freedom of that right',
#               '  Or, if they sleep, thy picture in my sight',
#               "  Awakes my heart, to heart's and eye's delight",
#               'To-morrow sharpened in his former might',
#               'Nativity, once in the main of light',
#               "Crooked eclipses 'gainst his glory fight",
#               'My heavy eyelids to the weary night',
#               'While shadows like to thee do mock my sight',
#               "Hath travell'd on to age's steepy night",
#               'Are vanishing, or vanished out of sight',
#               '  O! none, unless this miracle have might',
#               '  That in black ink my love may still shine bright',
#               'O! lest the world should task you to recite',
#               'After my death,--dear love, forget me quite',
#               'Sometime all full with feasting on your sight',
#               'Possessing or pursuing no delight',
#               'O! how I faint when I of you do write',
#               'And in the praise thereof spends all his might',
#               'Was it his spirit, by spirits taught to write',
#               'No, neither he, nor his compeers by night',
#               "When thou shalt be dispos'd to set me light",
#               "Upon thy side, against myself I'll fight",
#               'When other petty griefs have done their spite',
#               "At first the very worst of fortune's might",
#               "Nor did I wonder at the lily's white",
#               'They were but sweet, but figures of delight',
#               'To speak of that which gives thee all thy might',
#               'Darkening thy power to lend base subjects light',
#               'Than when her mournful hymns did hush the night',
#               'And sweets grown common lose their dear delight',
#               'O! blame me not, if I no more can write',
#               "For if it see the rud'st or gentlest sight",
#               'The mountain or the sea, the day or night',
#               "And given to time your own dear-purchas'd right",
#               'Which should transport me farthest from your sight',
#               'Thy pyramids built up with newer might',
#               'They are but dressings of a former sight',
#               "I have seen roses damask'd, red and white",
#               'And in some perfumes is there more delight',
#               "Tell me thou lov'st elsewhere; but in my sight",
#               "What need'st thou wound with cunning, when thy might",
#               '  For I have sworn thee fair, and thought thee bright',
#               '  Who art as black as hell, as dark as night',
#               'Which have no correspondence with true sight',
#               'O! from what power hast thou this powerful might',
#               'To make me give the lie to my true sight'],
#              'IH1 L': ["And having climb'd the steep-up heavenly hill",
#               'Yet mortal looks adore his beauty still',
#               '  To give away yourself, keeps yourself still',
#               '  And you must live, drawn by your own sweet skill',
#               'As I, not for myself, but for thee will',
#               'As tender nurse her babe from faring ill',
#               'For through the painter must you see his skill',
#               "Which in my bosom's shop is hanging still",
#               'So, love, be thou, although to-day thou fill',
#               'To-morrow see again, and do not kill',
#               '  So true a fool is love, that in your will',
#               '  Though you do anything, he thinks no ill',
#               'And folly--doctor-like--controlling skill',
#               'And captive good attending captain ill',
#               'My tongue-tied Muse in manners holds her still',
#               'Reserve their character with golden quill',
#               'Thou canst not love disgrace me half so ill',
#               "As I'll myself disgrace; knowing thy will",
#               'Some glory in their birth, some in their skill',
#               'Some in their garments though new-fangled ill',
#               'Your love and pity doth the impression fill',
#               'She keeps thee to this purpose, that her skill',
#               'May time disgrace and wretched minutes kill',
#               "And I my self am mortgag'd to thy will",
#               'Thou wilt restore to be my comfort still',
#               "More than enough am I that vex'd thee still",
#               'The sea, all water, yet receives rain still',
#               "  Let no unkind 'No' fair beseechers kill",
#               'Thus far for love, my love-suit, sweet, fulfil',
#               '  Make but my name thy love, and love that still',
#               '  If thou turn back and my loud crying still',
#               'Which like two spirits do suggest me still',
#               "The worser spirit a woman colour'd ill",
#               'My love is as a fever longing still',
#               'Feeding on that which doth preserve the ill',
#               'Whence hast thou this becoming of things ill',
#               'There is such strength and warrantise of skill'],
#              'EY1 JH': ['Resembling strong youth in his middle age',
#               "So should my papers, yellow'd with their age",
#               "And your true rights be term'd a poet's rage",
#               'As an unperfect actor on the stage',
#               'Or some fierce thing replete with too much rage',
#               "'Had my friend's Muse grown with this growing age",
#               'The rich-proud cost of outworn buried age',
#               'And brass eternal slave to mortal rage',
#               'And peace proclaims olives of endless age',
#               'Weighs not the dust and injury of age',
#               'But makes antiquity for aye his page'],
#              'IH1 L G R AH0 M AH0 JH': ['Attending on his golden pilgrimage'],
#              'AA1 R': ['But when from highmost pitch, with weary car',
#               "The eyes, 'fore duteous, now converted are",
#               'O! that you were your self; but, love you are',
#               'Excusing thy sins more than thy sins are',
#               "Mine eye my heart thy picture's sight would bar",
#               'But thou, to whom my jewels trifles are',
#               'Like stones of worth they thinly placed are',
#               'To critic and to flatterer stopped are',
#               "My thoughts and my discourse as madmen's are"],
#              'EY1': ['Like feeble age, he reeleth from the day',
#               'From his low tract, and look another way',
#               'Without this folly, age, and cold decay',
#               'And threescore year would make the world away',
#               'Who lets so fair a house fall to decay',
#               "Against the stormy gusts of winter's day",
#               'Then the conceit of this inconstant stay',
#               'Where wasteful Time debateth with decay',
#               'But wherefore do not you a mightier way',
#               'And fortify your self in your decay',
#               "Shall I compare thee to a summer's day",
#               'Rough winds do shake the darling buds of May',
#               'So I, for fear of trust, forget to say',
#               "And in mine own love's strength seem to decay",
#               'If thou survive my well-contented day',
#               'Why didst thou promise such a beauteous day',
#               "To let base clouds o'ertake me in my way",
#               'By looking on thee in the living day',
#               'Through heavy sleep on sightless eyes doth stay',
#               'Injurious distance should not stop my way',
#               'From limits far remote, where thou dost stay',
#               'How careful was I when I took my way',
#               'That to my use it might unused stay',
#               'How heavy do I journey on the way',
#               'Doth teach that ease and that repose to say',
#               'The which he will not every hour survey',
#               'That I might see what the old world could say',
#               "Wh'r we are mended, or wh'r better they",
#               'Or state itself confounded, to decay',
#               'The right of sepulchres, were shorn away',
#               'When I perhaps compounded am with clay',
#               'But let your love even with my life decay',
#               "In me thou see'st the twilight of such day",
#               'Which by and by black night doth take away',
#               'Without all bail shall carry me away',
#               'Which for memorial still with thee shall stay',
#               '  Thus do I pine and surfeit day by day',
#               '  Or gluttoning on all, or all away',
#               '  Then thank him not for that which he doth say',
#               '  Since what he owes thee, thou thyself dost pay',
# ...
#              'IY1 F EH0 K T': ["That thou art blam'd shall not be thy defect",
#               'When all my best doth worship thy defect'],
#              'AA1 T': ['Nay, if you read this line, remember not',
#               'That I in your sweet thoughts would be forgot',
#               "  But what's so blessed-fair that fears no blot",
#               '  Thou mayst be false, and yet I know it not',
#               'O! what a mansion have those vices got',
#               "Where beauty's veil doth cover every blot",
#               'Why should my heart think that a several plot',
#               'Or mine eyes, seeing this, say this is not',
#               'Canst thou, O cruel! say I love thee not',
#               'Do I not think on thee, when I forgot'],
#              'AE1 NG': ['When yellow leaves, or none, or few, do hang',
#               "Bare ruin'd choirs, where late the sweet birds sang"],
#              'AY1 R': ['As the death-bed, whereon it must expire',
#               'Our dates are brief, and therefore we admire'],
#              'IH1 N T R AH0 S T': ['My life hath in this line some interest'],
#              'EH1 M B ER0 D': ['Too base of thee to be remembered'],
#              'EY1 N JH': ['So far from variation or quick change',
#               'To new-found methods, and to compounds strange',
#               'To set a form upon desired change',
#               'I will acquaintance strangle, and look strange',
#               'Therefore in that I cannot know thy change',
#               'No, Time, thou shalt not boast that I do change',
#               'To me are nothing novel, nothing strange'],
#              'AA1 R G Y AH0 M AH0 N T': ['And you and love are still my argument',
#               'I grant, sweet love, thy lovely argument',
#               'And gives thy pen both skill and argument',
#               "'Fair, kind, and true,' is all my argument"],
#              'ER1 N AH0 T IY0': ["Time's thievish progress to eternity",
#               'Beyond all date; even to eternity',
#               'Or laid great bases for eternity'],
#              'AE1 JH AH0 S T IY0': ['And given grace a double majesty'],
#              'AY1 L': ['Yet be most proud of that which I compile',
#               "In others' works thou dost but mend the style"],
#              'AE1 N S': ['  But thou art all my art, and dost advance'],
#              'IH1 G N ER0 AH0 N S': ['  As high as learning, my rude ignorance'],
#              'AO1 R D': ['And found it in thy cheek: he can afford'],
#              'OW1 T': ['Your shallowest help will hold me up afloat',
#               "Or, being wrack'd, I am a worthless boat",
#               'For they in thee a thousand errors note',
#               'Who, in despite of view, is pleased to dote',
#               'If that be fair whereon my false eyes dote',
#               'If it be not, then love doth well denote'],
#              'AA1 T AH0 N': ['Or you survive when I in earth am rotten',
#               'Although in me each part will be forgotten'],
#              'AE1 V': ['Your name from hence immortal life shall have'],
#              'UW1 T': ['This silence for my sin you did impute',
#               'For I impair not beauty being mute',
#               "But hope of orphans, and unfather'd fruit",
#               'And, thou away, the very birds are mute'],
#              'AO1 R IY0': ['That to his subject lends not some small glory',
#               'That you are you, so dignifies his story',
#               'Upon thy part I can set down a story'],
#              'ER1 D Z': ['I think good thoughts, whilst others write good words',
#               "'Fair, kind, and true,' varying to other words"],
#              'AO1 R D Z': ['To every hymn that able spirit affords',
#               'Three themes in one, which wondrous scope affords'],
#              'AA1 N IH0 SH T': ['Giving him aid, my verse astonished'],
#              'EH1 L AH0 JH AH0 N S': ['Which nightly gulls him with intelligence'],
#              'EH1 S IH0 NG': ['Farewell! thou art too dear for my possessing'],
#              'EH1 S T AH0 M AH0 T': ["And like enough thou know'st thy estimate"],
#              'IY1 S IH0 NG': ['The charter of thy worth gives thee releasing'],
#              'AE1 N T IH0 NG': ['For how do I hold thee but by thy granting'],
#              'ER1 V IH0 NG': ['And for that riches where is my deserving'],
#              'AA1 N T IH0 NG': ['The cause of this fair gift in me is wanting'],
#              'OW1 IH0 NG': ["Thy self thou gav'st, thy own worth then not knowing",
#               'So thy great gift, upon misprision growing'],
#              'EY1 K IH0 NG': ["Or me to whom thou gav'st it, else mistaking",
#               'Comes home again, on better judgement making'],
#              'AE1 T ER0': ['  Thus have I had thee, as a dream doth flatter',
#               '  In sleep a king, but waking no such matter'],
#              'AO1 L T': ['Say that thou didst forsake me for some fault',
#               'Speak of my lameness, and I straight will halt'],
#              'AA1 R OW0': ["Ah! do not, when my heart hath 'scap'd this sorrow",
#               'Give not a windy night a rainy morrow'],
#              'OW2': ["To linger out a purpos'd overthrow"],
#              'AO1 R S': ["Some in their wealth, some in their body's force",
#               'Some in their hawks and hounds, some in their horse'],
#              'AA1 S T S': ["Richer than wealth, prouder than garments' costs"],
#              'AO1 NG Z': ['Then need I not to fear the worst of wrongs',
#               'I see a better state to me belongs'],
#              'IH1 S T ER0 IY0': ["In many's looks, the false heart's history"],
#              'EY1 S AH0 Z': ['They are the lords and owners of their faces'],
#              'EH1 K S AH0 L AH0 N S': ['Others, but stewards of their excellence',
#               'Still constant in a wondrous excellence'],
#              'IH1 V L AH0 JH': ['  Take heed, dear heart, of this large privilege'],
#              'EH1 JH': ["  The hardest knife ill-us'd doth lose his edge"],
#              'EH1 S': ["Both grace and faults are lov'd of more and less",
#               'Be wise as thou art cruel; do not press',
#               'Lest sorrow lend me words, and words express'],
#              'IH1 N': ['How like a winter hath my absence been',
#               "  If it be poison'd, 'tis the lesser sin",
#               '  That mine eye loves it and doth first begin',
#               "Distill'd from limbecks foul as hell within",
#               'Still losing when I saw myself to win'],
#              'IH1 M': ["When proud-pied April, dress'd in all his trim",
#               "That heavy Saturn laugh'd and leap'd with him"],
#              'EH1 L Z': ['Sweet thief, whence didst thou steal thy sweet that smells',
#               'Which on thy soft cheek for complexion dwells'],
#              'OW1 TH': ["A third, nor red nor white, had stol'n of both",
#               'But, for his theft, in pride of all his growth '],
#              'EH1 TH': ["And to his robbery had annex'd thy breath",
#               'A vengeful canker eat him up to death'],
#              'EH1 N D Z': ['O truant Muse what shall be thy amends',
#               'Both truth and beauty on my love depends'],
#              'AY2 D': ['So dost thou too, and therein dignified'],
#              'IY1 M IH0 NG': ["My love is strengthen'd, though more weak in seeming"],
#              'AA1 L AH0 T R IY0': ["Let not my love be call'd idolatry"],
#              'IH1 F ER0 AH0 N S': ['One thing expressing, leaves out difference'],
#              'AY1 T S': ['In praise of ladies dead and lovely knights'],
#              'AA1 F AH0 S IY0 Z': ['So all their praises are but prophecies'],
#              'OW1 L': ['Not mine own fears, nor the prophetic soul',
#               '  Hence, thou suborned informer! a true soul',
#               "  When most impeach'd, stands least in thy control"],
#              'EH1 S IH0 JH': ['And the sad augurs mock their own presage'],
#              'AY1 B Z': ['My love looks fresh, and Death to me subscribes',
#               "While he insults o'er dull and speechless tribes"],
#              'AA1 N Y UW0 M AH0 N T': ['  And thou in this shalt find thy monument'],
#              'EH1 R IH0 K T ER0': ["What's in the brain, that ink may character"],
#              'IH1 R AH0 T': ["Which hath not figur'd to thee my true spirit"],
#              'EH1 JH IH0 S T ER0': ["What's new to speak, what now to register"],
#              'EH1 R AH0 T': ['That may express my love, or thy dear merit'],
#              'UH1 D': ['To leave for nothing all thy sum of good',
#               'Which in their wills count bad what I think good'],
#              'IH1 NG K': ['Whilst, like a willing patient, I will drink',
#               'No bitterness that I will bitter think'],
#              'EH1 K SH AH0 N': ["Potions of eisel 'gainst my strong infection",
#               'Nor double penance, to correct correction'],
#              'AE1 CH': ['Of bird, of flower, or shape which it doth latch',
#               'Nor his own vision holds what it doth catch',
#               'Lo, as a careful housewife runs to catch',
#               'Sets down her babe, and makes all swift dispatch'],
#              'IY1 CH ER0': ["The most sweet favour or deformed'st creature",
#               'The crow, or dove, it shapes them to your feature'],
#              'AE1 T ER0 IY0': ["Drink up the monarch's plague, this flattery"],
#              'EH1 M B AH0 L': ['Such cherubins as your sweet self resemble',
#               'As fast as objects to his beams assemble'],
#              'IY1 IH0 NG': ["O! 'tis the first, 'tis flattery in my seeing",
#               'When not to be receives reproach of being',
#               "Not by our feeling, but by others' seeing"],
#              'AH1 P': ['And my great mind most kingly drinks it up',
#               'And to his palate doth prepare the cup'],
#              'IH1 R ER0': ['Even those that said I could not love you dearer',
#               'My most full flame should afterwards burn clearer'],
#              'AE1 K S AH0 D AH0 N T S': ["But reckoning Time, whose million'd accidents"],
#              'EH1 N T S': ["Tan sacred beauty, blunt the sharp'st intents",
#               "Robb'd others' beds' revenues of their rents"],
#              'IH1 R AH0 N IY0': ["Alas! why fearing of Time's tyranny"],
#              'AY1 N D Z': ['Let me not to the marriage of true minds',
#               'Which alters when it alteration finds',
#               'That I have frequent been with unknown minds'],
#              'AA1 R K': ['O, no! it is an ever-fixed mark',
#               'It is the star to every wandering bark'],
#              'EY1 K AH0 N': ['That looks on tempests and is never shaken',
#               "Whose worth's unknown, although his height be taken",
#               'For if you were by my unkindness shaken',
#               'And I, a tyrant, have no leisure taken',
#               'Me from myself thy cruel eye hath taken',
#               'Of him, myself, and thee I am forsaken'],
#              'IY1 K S': ["Love's not Time's fool, though rosy lips and cheeks",
#               'Love alters not with his brief hours and weeks',
#               'But no such roses see I in her cheeks',
#               'Than in the breath that from my mistress reeks'],
#              'IH1 N D Z': ['That I have hoisted sail to all the winds'],
#              'AW1 N': ['Book both my wilfulness and errors down',
#               'Bring me within the level of your frown'],
#              'ER1 JH': ['With eager compounds we our palate urge',
#               'We sicken to shun sickness when we purge'],
#              'IY1 T N AH0 S': ["Even so, being full of your ne'er-cloying sweetness"],
#              'IY1 D IH0 NG': ['To bitter sauces did I frame my feeding',
#               "To be diseas'd, ere that there was true needing"],
#              'EH1 R Z': ['What potions have I drunk of Siren tears',
#               'That is so vexed with watching and with tears'],
#              'IH1 R Z': ['Applying fears to hopes, and hopes to fears',
#               'The sun itself sees not, till heaven clears'],
#              'IH1 T IH0 D': ['What wretched errors hath my heart committed'],
#              'EH1 V ER0': ['Whilst it hath thought itself so blessed never'],
#              'IH1 T AH0 D': ['How have mine eyes out of their spheres been fitted'],
#              'IY1 V ER0': ['In the distraction of this madding fever'],
#              'EH1 T ER0': ['That better is, by evil still made better'],
#              'EY1 T ER0': ['Grows fairer than at first, more strong, far greater'],
#              'IY1 L': ['And for that sorrow, which I then did feel',
#               "Unless my nerves were brass or hammer'd steel"],
#              'EH1 V AH0 L': ['No, I am that I am, and they that level',
#               'I may be straight though they themselves be bevel',
#               'And would corrupt my saint to be a devil'],
#              'IH1 S T': ['Have faculty by nature to subsist'],
#              'AE1 K S AH0 D AH0 N T': ['No, it was builded far from accident'],
#              'AO1 L Z': ['It suffers not in smiling pomp, nor falls',
#               "Whereto th' inviting time our fashion calls"],
#              'EH1 R AH0 T IH0 K': ['It fears not policy, that heretic'],
#              'AE1 N AH0 P IY0': ["Were't aught to me I bore the canopy"],
#              'UW1 IH0 N IH0 NG': ['Which proves more short than waste or ruining'],
#              'EY1 V ER0': ['Have I not seen dwellers on form and favour'],
#              'IH1 P S': ['And situation with those dancing chips',
#               "Making dead wood more bless'd than living lips"],
#              'EY1 L': ["But then my friend's heart let my poor heart bail",
#               'Thou canst not then use rigour in my jail'],
#              'AA1 R D': ["Whoe'er keeps me, let my heart be his guard"],
#              'AH1 S': ['To thy sweet will making addition thus'],
#              'EY1 SH AH0 S': ['Wilt thou, whose will is large and spacious',
#               'Shall will in others seem right gracious'],
#              'UH1 K S': ["Why of eyes' falsehood hast thou forged hooks"],
#              'AH1 T AH0 L T IY0 Z': ["Unlearned in the world's false subtleties"],
#              'EH1 N AH0 M IY0 Z': ['Her pretty looks have been mine enemies'],
#              'IH1 N JH ER0 IY0 Z': ['That they elsewhere might dart their injuries'],
#              'AY1 T AH0 D': ["Nor are mine ears with thy tongue's tune delighted",
#               'Nor taste, nor smell, desire to be invited'],
#              'AE1 N': ['But my five wits nor my five senses can',
#               "Who leaves unsway'd the likeness of a man"],
#              'AO1 R N AH0 M AH0 N T S': ["That have profan'd their scarlet ornaments"],
#              'IY1 V AH0 L': ['To win me soon to hell, my female evil'],
#              'IY1 N D': ["And whether that my angel be turn'd fiend",
#               'Doth follow night, who like a fiend'],
#              'EH2 S': ['Shall worms, inheritors of this excess'],
#              'IY1 Z': ['For that which longer nurseth the disease',
#               'The uncertain sickly appetite to please'],
#              'EH1 P T': ['Angry that his prescriptions are not kept',
#               'Desire is death, which physic did except'],
#              'IY1 Z AH0 N': ["My nobler part to my gross body's treason",
#               'Triumph in love; flesh stays no farther reason'],
#              'EH1 R IH0 NG': ['But thou art twice forsworn, to me love swearing',
#               'In vowing new hate after new love bearing'],
#              'AO1 S T': ['And all my honest faith in thee is lost'],
#              'AY1 N D N AH0 S': ['For I have sworn deep oaths of thy deep kindness',
#               'And, to enlighten thee, gave eyes to blindness'],
#              'AA1 N S T AH0 N S IY0': ['Oaths of thy love, thy truth, thy constancy'],
#              'UH1 R': ['A dateless lively heat, still to endure',
#               'Against strange maladies a sovereign cure'],
#              'AY1 ER0 D': ['I, sick withal, the help of bath desired'],
#              'EH1 CH UW0 AH0 L': ["Which from Love's fire took heat perpetual"]})

# %%
import random
rhyme = random.choice(list(rhymes.keys()))
random.sample(rhymes[rhyme], 2)
# Out:
# ['Applying fears to hopes, and hopes to fears',
#  'The sun itself sees not, till heaven clears']
